# %% [markdown]
# ## Projektstruktur
#
# Ausgehend von einem beliebigen Wurzelordner liegt dem Projekt folgende Ordnerstruktur zugrunde:
#
# - **master_cloud** [Sciebo-Ordner]
#   - ... externer Code, Tutorials etc.
#   - *corpora*
#     - ... diverse rohe Corpora
#     - hpc [backup der ETL und NLP Pipeline Resultate auf dem HPC]
#     - *preprocessed* [corpora nach ETL Pipeline]
#       - *nlp* [corpora nach NLP Pipeline]
#         - spacy_model
#           - vocab
#     - scrapy
#       - faz
#       - focus
#     + German_datasets.ods [s.u.]
#
# - **topiclabeling**
#   - data
#     - feeds [Rohoutput der scrapy feeds]
#     + IWNLP.Lemmatizer_20170501.json
#   - logs
#   - *src* [Git Projektordner, Python code und Notebooks]
#     - scrapy [code]
#   + ToDo.txt

# %%
from os import listdir
from os.path import isfile, join

from constants import DATA_BASE, ETL_PATH, NLP_PATH, HASH
import pandas as pd
import ezodf

pd.set_option('display.precision',10)

# %% [markdown]
# ## German Corpora Overview
#
# Übersicht über deutschsprachige Corpora, die zur Verfügung stehen. Die ersten 6 fallen hierbei in die engere Wahl. Die gecrawlten News-Corpora von FAZ und Focus können auch als ein gemeinsamer Corpus betrachten werden, ebenso könnten auch weitere Newsseiten hinzugenommen werden. Das Parsing des Wikipedia-Corpus ist noch nicht abgeschlossen. Der dewac-Corpus ist aufgrund seiner Größe noch nicht vollständig durch die NLP-Pipeline gegangen.

# %%
def read_ods(filename, sheet_no=0, header=0):
    tab = ezodf.opendoc(filename=filename).sheets[sheet_no]
    return pd.DataFrame({col[header].value:[x.value for x in col[header+1:]]
                         for col in tab.columns()}).iloc[:,:-1].dropna(how='all')

def highlight(s):
    if s.Selected:
        col = '#dd3355' if s.name%2 else '#cc2244'
        return ['color: %s' % col]*len(s)
    return ['']*len(s)

df = read_ods(join(DATA_BASE, 'German_datasets.ods'))
df.style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
#     #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col0 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col1 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col2 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col3 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col4 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col5 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col6 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col7 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col8 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col9 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow0_col10 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col0 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col1 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col2 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col3 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col4 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col5 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col6 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col7 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col8 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col9 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow1_col10 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col0 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col1 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col2 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col3 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col4 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col5 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col6 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col7 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col8 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col9 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow2_col10 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col0 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col1 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col2 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col3 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col4 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col5 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col6 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col7 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col8 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col9 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow3_col10 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col0 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col1 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col2 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col3 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col4 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col5 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col6 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col7 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col8 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col9 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow4_col10 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col0 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col1 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col2 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col3 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col4 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col5 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col6 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col7 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col8 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col9 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow5_col10 {
#             color:  #dd3355;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col0 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col1 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col2 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col3 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col4 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col5 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col6 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col7 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col8 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col9 {
#             color:  #cc2244;
#         }    #T_ee292fa2_b9fe_11e8_89b5_c86000dd86cfrow6_col10 {
#             color:  #cc2244;
#         }</style>
# <table id="T_ee292fa2_b9fe_11e8_89b5_c86000dd86cf" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Category</th>
#         <th class="col_heading level0 col1" >Name</th>
#         <th class="col_heading level0 col2" >Date</th>
#         <th class="col_heading level0 col3" >Content</th>
#         <th class="col_heading level0 col4" >#documents</th>
#         <th class="col_heading level0 col5" >#sentences</th>
#         <th class="col_heading level0 col6" >#tokens</th>
#         <th class="col_heading level0 col7" >Size
# (unzipped +
# unprocessed)</th>
#         <th class="col_heading level0 col8" >Remarks</th>
#         <th class="col_heading level0 col9" >Link</th>
#         <th class="col_heading level0 col10" >Selected</th>
#     </tr></t

# %%
def read(f):
     return pd.read_pickle(f)

# %% [markdown]
# ## Scrapy spiders
#
# Unter ```../../topiclabeling/src/scrapy``` sind derzeit zwei Spiders für die FAZ und den Focus lauffähig. Der Crawler lässt sich von dort aufrufen durch
#
# ```scrapy crawl [-a categories="politik|kultur|panorama|digital"] focus```
#
# Die Categories beziehen sich auf die möglichen Rubriken der jeweiligen News-Seite. Ohne ihre Angabe werden als Default-Kategorien Politik und Wirtschaft gecrawlt.

# %% [markdown]
# ## ETL Pipeline
#
# Die rohen Corpora wurden durch [ETL_pipeline.ipynb](ETL_pipeline.ipynb) geladen, wenn nötig geparst und in ein einheitliches Datenschema gebracht, wobei unter 'Load' hier das Speichern als pandas DataFrame im pickle-Format zu verstehen ist. Der Output der Pipeline befindet sich im Ordner ```../../master_cloud/corpora/preprocessed```.

# %%
read(join(ETL_PATH, 'dewiki.pickle'))

# %% [markdown]
# ## NLP Pipeline
#
# Nachdem die Corpora in ein einheitliches Format gebracht wurden durchlaufen sie die Spacy Pipeline für das 'de' language model. s. [NLP_pipeline.ipynb](NLP_pipeline.ipynb)
#
# Die Tokenisierung ist nicht optimal und könnte durch Definition einiger Sonderfälle noch verbessert werden. Dies betrifft insbesondere den Forums-Corpus der Online-Partizipation. Hier macht es sich nachteilig bemerkbar, dass das Sprachmodell auf einem orthographisch korrekten Corpus trainiert wurde.
#
# Die Lemmatisierung wird durch IWNLP durchgeführt. Um einige merkwürdige Ergebnisse abzufangen, habe ich hier einen Wrapper herum gebaut, der bestimmte Sonderfälle abfängt, bzw. bestimmte Wortarten nicht durch IWNLP parsen lässt. Zusätzlich überprüfe ich Suffixe von zusammengesetzten Nomen auf Lemmata. Wo IWNLP keine Ergebnisse findet, wird die Lemmatisierung des Spacy Modells verwendet, ansonsten das ursprüngliche Token. Für IWNLP verwende ich die XML-Datenbank von 2017. Der Versuch, das aktuelle Wiktionary neu zu parsen, schlug nach wenigen Wörtern mit einer OutOfMemory Exception fehl (Build sowohl unter Mono als auch Visual Studio). Die Lemmatisierung ist noch anfällig für Fehler, insbesondere wenn das POS-Tagging nicht korrekt war. Named Entities sind ein Problem, wenn sie von Spacy nicht als solche erkannt wurden.
#
# Der Output der Pipeline befindet sich im Ordner ```../../master_cloud/corpora/preprocessed/nlp```. Das spacy vocabulary wird mit gespeichert.

# %%
read(join(NLP_PATH, 'FAZ_nlp.pickle'))

# %% [markdown]
# ## Phrase detection
#
# Zu den Token des Corpus versuche ich Phrasen-Token zu generieren. Die Phrase-Detection von Gensim erwies sich dabei als eher problematisch. Die Ergebnisse sind zu willkürlich. Die Named Entities von Spacy liefern zu wenige Ergebnisse. Einigermaßen brauchbar (nach etwas Überarbeitung) sind Spacy's noun chunks. Interessant wäre hier ein Dictionary basierter Ansatz, z.B. auf Basis von Wikipedia-Titeln. Dies könnte aber rechenintensiv werden.

# %% [markdown]
# ## Topic Modeling
#
# Für das topic modeling werden nur die Tags NOUN, PROPN (Entities) und Phrasen verwendet. Zur Erstellung der Models wird Gensims LDAModel verwendet. Hier muss noch mit den Parametern experimentiert werden. Für das Topic Labeling wäre es wünschenswert möglichst exklusive Topics zu haben, d.h. mit hoher Wahrscheinlichkeitsmasse an den Rändern der Dirichlet-Verteilung, z.B. durch niedrige $\alpha$-Werte. Hier besteht auf jeden Fall noch Experimentierbedarf.
#
# [Gensim_topic_modeling.ipynb](Gensim_topic_modeling.ipynb)

# %% [markdown]
# -----
#
# ### Appendix: Corpus metrics

# %%
path = NLP_PATH

files = sorted([f for f in listdir(path) if isfile(join(path, f))
                # and f[:4] == 'dewa'
                # and f[:4] == 'dewi'
                # and f[:3] == 'Onl'
                # and f[:3] == 'Eur'
                # and f[:3] == 'FAZ'
                # and f[:3] == 'FOC'
                # and f[:3] == 'Pol'
               ])

dfs = [(name, read(join(path, name))) for name in files]

# %%
overview_list = [(name, df.groupby(HASH).ngroups, df.groupby([HASH, 'sent_idx']).ngroups, df.shape[0]) 
                 for name, df in dfs]
overview = pd.DataFrame(overview_list, columns=['dataset', '#documents', '#sentences', '#tokens'])
overview
