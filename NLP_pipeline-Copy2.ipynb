# %%
import re
from os import listdir, makedirs
from os.path import isfile, join
from time import time
import importlib

import constants
import project_logging
import nlp_processor

from constants import *
from project_logging import log
from nlp_processor import NLPProcessor

# %%
importlib.reload(constants)
importlib.reload(project_logging)
importlib.reload(nlp_processor)

log("##### START #####")


### --- run ---

t0 = time()

LOCAL_PATH = ETL_BASE
FULL_PATH = join(DATA_BASE, LOCAL_PATH)

files = sorted([f for f in listdir(FULL_PATH) if isfile(join(FULL_PATH, f))])
# filter for certain file prefixes if file_prefix is set
file_prefix = 'Onl'
files = filter(lambda x: x[:len(file_prefix)] == file_prefix if file_prefix else True, files)
processor = NLPProcessor(spacy_path=DE)

for name in files:
    corpus = re.split(r'\.|_', name)[0]
    fname = join(FULL_PATH, name)
    df = processor.read_process_load(fname, corpus, spacy_to_disk=True, size=200)

t1 = int(time() - t0)
log("finished in {:02d}:{:02d}:{:02d} minutes".format(t1//3600, t1//60, t1 % 60))

df
# Out:
# ##### START #####
# loading spacy
# reading vocab from ../../master_cloud/corpora/preprocessed/nlp/spacy_model/vocab
# loading IWNLPWrapper
# reading corpus from ../../master_cloud/corpora/preprocessed/OnlineParticipation.pickle
# processing OnlineParticipation
# 0%: 0 documents processed
# savingOnlineParticipation_nlp to ../../master_cloud/corpora/preprocessed/nlp/OnlineParticipation_nlp.pickle
# writing spacy model to disk: ../../master_cloud/corpora/preprocessed/nlp
# finished in 00:00:20 minutes
#                       hash  index                    text  \
# 0       492819066359988780      0        Nebentätigkeiten
# 1       492819066359988780      1                     von
# 2       492819066359988780      2                      OB
# 3       492819066359988780      3                     und
# 4       492819066359988780      4         Kommunalpoilter
# 5       492819066359988780      5                       -
# 6       492819066359988780      6            öffentliches
# 7       492819066359988780      7                Ehrenamt
# 8       492819066359988780      8                       .
# 9       492819066359988780      9                      \n
# 10      492819066359988780     10                   Durch
# 11      492819066359988780     11                     das
# 12      492819066359988780     12  sogenannte"öffentliche
# 13      492819066359988780     13                Ehrenamt
# 14      492819066359988780     14                       "
# 15      492819066359988780     15
# 16      492819066359988780     16               verdienen
# 17      492819066359988780     17                  manche
# 18      492819066359988780     18        Komunalpolitiker
# 19      492819066359988780     19                     und
# 20      492819066359988780     20                    OB`s
# 21      492819066359988780     21
# 22      492819066359988780     22                      in
# 23      492819066359988780     23                     den
# 24      492819066359988780     24        Verwaltungsräten
# 25      492819066359988780     25                     und
# 26      492819066359988780     26          Aufsichtsräten
# 27      492819066359988780     27                    viel
# 28      492819066359988780     28                    Geld
# 29      492819066359988780     29                       (
# ...                    ...    ...                     ...
# 25230 -7565318661053746624     49                       ,
# 25231 -7565318661053746624     50                      da
# 25232 -7565318661053746624     51                     von
# 25233 -7565318661053746624     52            Brennnesseln
# 25234 -7565318661053746624     53                    fast
# 25235 -7565318661053746624     54             überwuchert
# 25236 -7565318661053746624     55                       .
# 25237 -7565318661053746624     56                     Oft
# 25238 -7565318661053746624     57                   schon
# 25239 -7565318661053746624     58                    habe
# 25240 -7565318661053746624     59                     ich
# 25241 -7565318661053746624     60                     der
# 25242 -7565318661053746624     61                   Stadt
# 25243 -7565318661053746624     62                     das
# 25244 -7565318661053746624     63              mitgeteilt
# 25245 -7565318661053746624     64                       ,
# 25246 -7565318661053746624     65                    aber
# 25247 -7565318661053746624     66                     das
# 25248 -7565318661053746624     67                     Tal
# 25249 -7565318661053746624     68                 scheint
# 25250 -7565318661053746624     69                   nicht
# 25251 -7565318661053746624     70                  häufig
# 25252 -7565318661053746624     71                     vom
# 25253 -7565318661053746624     72                     Amt
# 25254 -7565318661053746624     73                     für
# 25255 -7565318661053746624     74               Stadtgrün
# 25256 -7565318661053746624     75                 besucht
# 25257 -7565318661053746624     76                      zu
# 25258 -7565318661053746624     77                  werden
# 25259 -7565318661053746624     78                       .
#
#                               token    POS
# 0                    Nebentätigkeit   NOUN
# 1                               Von    ADP
# 2                                OB   NOUN
# 3                               und   CONJ
# 4                   Kommunalpoilter   NOUN
# 5                                 -  PUNCT
# 6                        öffentlich    ADJ
# 7                          Ehrenamt   NOUN
# 8                                 .  PUNCT
# 9      Blaugestiefelter Schleimkopf  SPACE
# 10                            durch    ADP
# 11                              das    DET
# 12           sogenannte"öffentliche    ADJ
# 13                         Ehrenamt   NOUN
# 14                                "  PUNCT
# 15     Blaugestiefelter Schleimkopf  SPACE
# 16                        verdienen   VERB
# 17                            manch    DET
# 18                 Komunalpolitiker   NOUN
# 19                              und   CONJ
# 20                             OB`s  PROPN
# 21     Blaugestiefelter Schleimkopf  SPACE
# 22                               IN    ADP
# 23                        Adsorbens    DET
# 24                   Verwaltungsrat   NOUN
# 25                              und   CONJ
# 26                     Aufsichtsrat   NOUN
# 27                             viel    DET
# 28                             Geld   NOUN
# 29                                (  PUNCT
# ...                             ...    ...
# 25230                             ,  PUNCT
# 25231                            DA  SCONJ
# 25232                           Von    ADP
# 25233                   Brennnessel   NOUN
# 25234                         fasen    ADV
# 25235                   überwuchern   VERB
# 25236                             .  PUNCT
# 25237                           oft    ADV
# 25238                         schon    ADV
# 25239                         haben    AUX
# 25240                           Ich   PRON
# 25241                     Adsorbens    DET
# 25242                         Stadt   NOUN
# 25243                           das    DET
# 25244                     mitteilen   VERB
# 25245                             ,  PUNCT
# 25246                          Aber   CONJ
# 25247                           das    DET
# 25248                           Tal   NOUN
# 25249                      scheinen   VERB
# 25250                         nicht   PART
# 25251                        häufig    ADJ
# 25252                           vom    ADP
# 25253                           Amt   NOUN
# 25254                           Für    ADP
# 25255                     Stadtgrün   NOUN
# 25256                      besuchen   VERB
# 25257                            zu   PART
# 25258                        werden    AUX
# 25259                             .  PUNCT
#
# [25260 rows x 5 columns]

# %%
processor.read('/home/andreas/workspace/master_cloud/corpora/preprocessed/nlp/OnlineParticipation_nlp.pickle')
# Out:
# reading corpus from /home/andreas/workspace/master_cloud/corpora/preprocessed/nlp/OnlineParticipation_nlp.pickle
#                       hash  index                    text  \
# 0       492819066359988780      0        Nebentätigkeiten
# 1       492819066359988780      1                     von
# 2       492819066359988780      2                      OB
# 3       492819066359988780      3                     und
# 4       492819066359988780      4         Kommunalpoilter
# 5       492819066359988780      5                       -
# 6       492819066359988780      6            öffentliches
# 7       492819066359988780      7                Ehrenamt
# 8       492819066359988780      8                       .
# 9       492819066359988780      9                      \n
# 10      492819066359988780     10                   Durch
# 11      492819066359988780     11                     das
# 12      492819066359988780     12  sogenannte"öffentliche
# 13      492819066359988780     13                Ehrenamt
# 14      492819066359988780     14                       "
# 15      492819066359988780     15
# 16      492819066359988780     16               verdienen
# 17      492819066359988780     17                  manche
# 18      492819066359988780     18        Komunalpolitiker
# 19      492819066359988780     19                     und
# 20      492819066359988780     20                    OB`s
# 21      492819066359988780     21
# 22      492819066359988780     22                      in
# 23      492819066359988780     23                     den
# 24      492819066359988780     24        Verwaltungsräten
# 25      492819066359988780     25                     und
# 26      492819066359988780     26          Aufsichtsräten
# 27      492819066359988780     27                    viel
# 28      492819066359988780     28                    Geld
# 29      492819066359988780     29                       (
# ...                    ...    ...                     ...
# 25230 -7565318661053746624     49                       ,
# 25231 -7565318661053746624     50                      da
# 25232 -7565318661053746624     51                     von
# 25233 -7565318661053746624     52            Brennnesseln
# 25234 -7565318661053746624     53                    fast
# 25235 -7565318661053746624     54             überwuchert
# 25236 -7565318661053746624     55                       .
# 25237 -7565318661053746624     56                     Oft
# 25238 -7565318661053746624     57                   schon
# 25239 -7565318661053746624     58                    habe
# 25240 -7565318661053746624     59                     ich
# 25241 -7565318661053746624     60                     der
# 25242 -7565318661053746624     61                   Stadt
# 25243 -7565318661053746624     62                     das
# 25244 -7565318661053746624     63              mitgeteilt
# 25245 -7565318661053746624     64                       ,
# 25246 -7565318661053746624     65                    aber
# 25247 -7565318661053746624     66                     das
# 25248 -7565318661053746624     67                     Tal
# 25249 -7565318661053746624     68                 scheint
# 25250 -7565318661053746624     69                   nicht
# 25251 -7565318661053746624     70                  häufig
# 25252 -7565318661053746624     71                     vom
# 25253 -7565318661053746624     72                     Amt
# 25254 -7565318661053746624     73                     für
# 25255 -7565318661053746624     74               Stadtgrün
# 25256 -7565318661053746624     75                 besucht
# 25257 -7565318661053746624     76                      zu
# 25258 -7565318661053746624     77                  werden
# 25259 -7565318661053746624     78                       .
#
#                               token    POS
# 0                    Nebentätigkeit   NOUN
# 1                               Von    ADP
# 2                                OB   NOUN
# 3                               und   CONJ
# 4                   Kommunalpoilter   NOUN
# 5                                 -  PUNCT
# 6                        öffentlich    ADJ
# 7                          Ehrenamt   NOUN
# 8                                 .  PUNCT
# 9      Blaugestiefelter Schleimkopf  SPACE
# 10                            durch    ADP
# 11                              das    DET
# 12           sogenannte"öffentliche    ADJ
# 13                         Ehrenamt   NOUN
# 14                                "  PUNCT
# 15     Blaugestiefelter Schleimkopf  SPACE
# 16                        verdienen   VERB
# 17                            manch    DET
# 18                 Komunalpolitiker   NOUN
# 19                              und   CONJ
# 20                             OB`s  PROPN
# 21     Blaugestiefelter Schleimkopf  SPACE
# 22                               IN    ADP
# 23                        Adsorbens    DET
# 24                   Verwaltungsrat   NOUN
# 25                              und   CONJ
# 26                     Aufsichtsrat   NOUN
# 27                             viel    DET
# 28                             Geld   NOUN
# 29                                (  PUNCT
# ...                             ...    ...
# 25230                             ,  PUNCT
# 25231                            DA  SCONJ
# 25232                           Von    ADP
# 25233                   Brennnessel   NOUN
# 25234                         fasen    ADV
# 25235                   überwuchern   VERB
# 25236                             .  PUNCT
# 25237                           oft    ADV
# 25238                         schon    ADV
# 25239                         haben    AUX
# 25240                           Ich   PRON
# 25241                     Adsorbens    DET
# 25242                         Stadt   NOUN
# 25243                           das    DET
# 25244                     mitteilen   VERB
# 25245                             ,  PUNCT
# 25246                          Aber   CONJ
# 25247                           das    DET
# 25248                           Tal   NOUN
# 25249                      scheinen   VERB
# 25250                         nicht   PART
# 25251                        häufig    ADJ
# 25252                           vom    ADP
# 25253                           Amt   NOUN
# 25254                           Für    ADP
# 25255                     Stadtgrün   NOUN
# 25256                      besuchen   VERB
# 25257                            zu   PART
# 25258                        werden    AUX
# 25259                             .  PUNCT
#
# [25260 rows x 5 columns]
