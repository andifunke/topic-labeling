# %% [markdown]
# ### Default Imports

# %%
import spacy
import pandas as pd
import sys
import re
from os import listdir, makedirs
from os.path import isfile, join, exists
# from iwnlp.iwnlp_wrapper import IWNLPWrapper
from spacy_iwnlp import spaCyIWNLP
import gensim
from time import time

# %%
### --- default constants definitions ---

DATA_BASE = "../../master_cloud/corpora"
ETL_BASE = "preprocessed"
ETL_PATH = join(DATA_BASE, ETL_BASE)
NLP_BASE = "preprocessed/nlp"
NLP_PATH = join(DATA_BASE, NLP_BASE)
SPACY_PATH = join(NLP_PATH, 'spacy_model')
VOCAB_PATH = join(SPACY_PATH, 'vocab')

# standard meta data fields
DATASET = 'dataset'
SUBSET = 'subset'
ID = 'doc_id'
ID2 = 'doc_subid'
TITLE = 'title'
TAGS = 'tags'
TIME = 'date_time'
# AUTHOR
# SUBTITLE
# CATEGORY
META = [DATASET, SUBSET, ID, ID2, TITLE, TAGS, TIME]
TEXT = 'text'
HASH = 'hash'

### --- additional constants

# tags
PUNCT = 'PUNCT'
DET = 'DET'
PHRASE = 'PHRASE'

# keys
IWNLP = 'IWNLP'
POS = 'POS'
INDEX = 'index'
START = 'start'
NOUN = 'NOUN'
PROPN = 'PROPN'
LEMMA = 'lemma'
TAG = 'tag'
STOP = 'stop'
ENT_TYPE = 'ent_type'
ENT_IOB = 'ent_iob'
KNOWN = 'known'

# %%
### --- load spacy and iwnlp ---

if len(sys.argv) > 1 and sys.argv[1] == '--hpc':
    print('on hpc')
    de = '/home/funkea/.local/lib/python3.4/site-packages/de_core_news_sm/de_core_news_sm-2.0.0'
else:
    de = 'de'

print("loading spacy")
nlp = spacy.load(de)  # <-- load with dependency parser (slower)
# nlp = spacy.load(de, disable=['parser'])

if exists(VOCAB_PATH):
    print("reading vocab from", VOCAB_PATH)
    nlp.vocab.from_disk(VOCAB_PATH)

print("loading IWNLPWrapper")
# lemmatizer = IWNLPWrapper(lemmatizer_path='../data/IWNLP.Lemmatizer_20170501.json')
iwnlp = spaCyIWNLP(lemmatizer_path='../data/IWNLP.Lemmatizer_20170501.json')
nlp.add_pipe(iwnlp)
# Out:
# loading spacy
# reading vocab from ../../master_cloud/corpora/preprocessed/nlp/spacy_model/vocab
# loading IWNLPWrapper

# %%
def iwnlp_plus(doc: spacy.tokens.Doc) -> spacy.tokens.Doc:
    """ 
    This function uses the IWNLP lemmatizer with a few enhancements for compund nouns and nouns 
    with uncommon capitalization. Can also be used to lemmatize tokens with different POS-tags.
    Do not use this function to lemmatize phrases.
    :param token: white space stripped single token (str)
    :param pos:   string constant, one of Universal tagset.
    :return: tuple of type (str, bool)
           value[0]: The lemma of the token if a lemma can be derived, else None.
           value[1]: True if the token can be retrieved from the Wiktionary database as is, else False.
    """
    
    :param token: white space stripped single token (str)
    :param pos:   string constant, one of Universal tagset.
    token = d
    for item in doc:
        token = item.text.strip()
        pos = item.pos_
    
        lemm = lemmatizer.lemmatize(token, pos)
        # default lemmatization ok?
        if lemm:
            return lemm[0], True

        # some rules to derive a lemma from the original token (nouns only)
        # TODO: define rules for hyphenated nouns
        if pos == NOUN or pos == PROPN:
            # first try default noun capitalization
            lemm = lemmatizer.lemmatize(token.title(), pos)
            if lemm:
                return lemm[0], False

        # still no results: try noun suffixes
            for i in range(1, len(token)-1):
                token_edit = token[i:].title()
                lemm = lemmatizer.lemmatize_plain(token_edit, ignore_case=True)
                if lemm:
                    lemm = lemm[0]
                    lemm = token[:i].title() + lemm.lower()
                    return lemm, False
    


nlp.add_pipe(iwnlp_plus, name='iwnlp_plus')

# %%
stopwords = nlp.Defaults.stop_words

# %%
# --- run notebook ---

LOCAL_PATH = ETL_BASE
FULL_PATH = join(DATA_BASE, LOCAL_PATH)

files = sorted([f for f in listdir(FULL_PATH) if isfile(join(FULL_PATH, f))])

def read(f):
    """ reads a dataframe from pickle format """
    print("reading corpus from", f)
    return pd.read_pickle(f)

def process_docs(series, size=None):
    """ main function for sending the dataframes from the ETL pipeline to the NLP pipeline """
    length = len(series)
    steps = 100
    step_len = 100//steps
    percent = length//steps
    done = 0
    yield essential_token, phrase_lookup

for name in files:
    if name[:3] != 'Onl':
        continue
    corpus = re.split(r'\.|_', name)[0]
    fname = join(FULL_PATH, name)
    df = read(fname)
# Out:
# reading corpus from ../../master_cloud/corpora/preprocessed/OnlineParticipation.pickle

# %%
t0 = time()
docs = [nlp(text) for text in df[TEXT]]
df['doc'] = docs
t1 = int(time() - t0)
print("finished in {:02d}:{:02d}:{:02d}".format(t1//3600, t1//60, t1 % 60))
df
# finished in 00:05:36 minutes
# Out:
# finished in 00:05:36 minutes
#                                   dataset          subset doc_id  doc_subid  \
# hash
#  492819066359988780   OnlineParticipation        bonn2017    985          0
#  4402470584618071095  OnlineParticipation        bonn2017    988          0
#  6280350261461137971  OnlineParticipation        bonn2017    986          0
# -3466298431331063864  OnlineParticipation        bonn2017    987          0
# -7971046904978124907  OnlineParticipation        bonn2017    983          0
# -5464475141879722540  OnlineParticipation        bonn2017    979          0
# -3377659701997023543  OnlineParticipation        bonn2017    980          0
# -9081569078624867654  OnlineParticipation        bonn2017    982          0
# -6681834770025936415  OnlineParticipation        bonn2017    984          0
#  5437548212583122831  OnlineParticipation        bonn2017    990          0
# -7583605623074273787  OnlineParticipation        bonn2017    941          0
# -5464319664140523355  OnlineParticipation        bonn2017    948          0
# -5788904644317865118  OnlineParticipation        bonn2017    948       4863
# -3078748361664229079  OnlineParticipation        bonn2017    942          0
#  7436848703089573130  OnlineParticipation        bonn2017    942       4870
# -2393745017980416918  OnlineParticipation        bonn2017    957          0
#  323660551489142748   OnlineParticipation        bonn2017    940          0
#  6121891870271679895  OnlineParticipation        bonn2017    949          0
# -2731752165060716664  OnlineParticipation        bonn2017    975          0
# -5222543903791805856  OnlineParticipation        bonn2017    959          0
#  5963311242915317913  OnlineParticipation        bonn2017    959       4862
# -5306458750461174737  OnlineParticipation        bonn2017    978          0
#  4514813816041113023  OnlineParticipation        bonn2017    977          0
#  1718629525785233234  OnlineParticipation        bonn2017    977       4866
# -7297202107877194955  OnlineParticipation        bonn2017    921          0
# -4483786331694335797  OnlineParticipation        bonn2017    921       4780
#  5871064806466408833  OnlineParticipation        bonn2017    925          0
#  2320403075463752097  OnlineParticipation        bonn2017    925       4801
#  2566852176210875826  OnlineParticipation        bonn2017    925       4828
#  1067449746628595721  OnlineParticipation        bonn2017    923          0
# ...                                   ...             ...    ...        ...
#  1973698535830369582  OnlineParticipation  raddialog-bonn   3928       2374
#  6223618517403548089  OnlineParticipation  raddialog-bonn   3920          0
# -7384580095283128086  OnlineParticipation  raddialog-bonn   3920       2427
# -2033902179901282955  OnlineParticipation  raddialog-bonn   3930          0
#  608546312043052308   OnlineParticipation  raddialog-bonn   3929          0
#  5805553366814824688  OnlineParticipation  raddialog-bonn   3940          0
#  1372842031231755247  OnlineParticipation  raddialog-bonn   3932          0
#  6969913009477104879  OnlineParticipation  raddialog-bonn   3932       2408
# -8799723294478368571  OnlineParticipation  raddialog-bonn   3941          0
#  3026491433871526936  OnlineParticipation  raddialog-bonn   3939          0
#  168334671709879618   OnlineParticipation  raddialog-bonn   3938          0
# -2472311367726675903  OnlineParticipation  raddialog-bonn   3935          0
#  8108152969676924882  OnlineParticipation  raddialog-bonn   3934          0
#  9079875249134115471  OnlineParticipation  raddialog-bonn   3933          0
# -3612135372463688021  OnlineParticipation  raddialog-bonn   3937          0
# -4692037805737303007  OnlineParticipation  raddialog-bonn   3937       2425
#  1826807881673744810  OnlineParticipation  raddialog-bonn   3943          0
# -7905666796425105576  OnlineParticipation  raddialog-bonn   3947          0
#  6969377119120050145  OnlineParticipation  raddialog-bonn   3951          0
#  8514051167344148298  OnlineParticipation  raddialog-bonn   3952          0
#  1108464921862587069  OnlineParticipation  raddialog-bonn   3950          0
# -5111453943405348232  OnlineParticipation  raddialog-bonn   3950       2407
# -1872486901262230403  OnlineParticipation  raddialog-bonn   3953          0
# -1638961252413740021  OnlineParticipation  raddialog-bonn   3953       2450
# -8234950261182669133  OnlineParticipation  raddialog-bonn   3944          0
# -3527666862567484508  OnlineParticipation  raddialog-bonn   3946          0
#  8078892133457975991  OnlineParticipation  raddialog-bonn   3945          0
# -7408600361765941107  OnlineParticipation  raddialog-bonn   3945       2424
#  3859407009916834403  OnlineParticipation  raddialog-bonn   3948          0
# -5770120604532882743  OnlineParticipation  raddialog-bonn   3949          0
#
#                                                                   title  \
# hash
#  492819066359988780   Nebentätigkeiten von OB und Kommunalpoilter - ...
#  4402470584618071095                            Wache (Gabi) im Bahnhof
#  6280350261461137971                              Monetäre Sparmaßnahme
# -3466298431331063864  Kosteneinsparung bei Friedhof-/Parkanlagen in ...
# -7971046904978124907                                          Leerstand
# -5464475141879722540  Minusstunden bei der Feuerwehr; Öffnungszeiten...
# -3377659701997023543           Stadtverwaltung und Einsparmöglichkeiten
# -9081569078624867654                       Aufsichtsrat Stadtwerke Bonn
# -6681834770025936415   Sparkasse Köln Bonn und Ausschüttung der Gewinne
#  5437548212583122831  Beendigung der Unterstützung der Kunst!Rasen-V...
# -7583605623074273787          Mehr Geld für Bonner staatliche Gymnasien
# -5464319664140523355                      Bürgerbestimmung Großprojekte
# -5788904644317865118                                       Großprojekte
# -3078748361664229079     Patenschaften für Gräber auf Bonner Friedhöfen
#  7436848703089573130                        Friedhöfe in Ordnung halten
# -2393745017980416918          Verkehrs- Umwelt- und Gesundheits-Konzept
#  323660551489142748   Weihnachtsbaumabholung durch Bonn Orange einst...
#  6121891870271679895  Alternative Nutzung für leer stehende Pützchen...
# -2731752165060716664                             Mehr Geld für den ÖPNV
# -5222543903791805856                                        Gelbe Säcke
#  5963311242915317913                       Was hat dieser Vorschlag mit
# -5306458750461174737  Reitwege im Gebiet Vinxel / Niederholtdorf/ Pa...
#  4514813816041113023                                             Sparen
#  1718629525785233234                                    Fahrradzaehlung
# -7297202107877194955   Anreizsystem für Übernahme von Grünpatenschaften
# -4483786331694335797                                  Sehr schöne Idee!
#  5871064806466408833  Verlängerung der Straßenbahn 61 62 bis Godesbe...
#  2320403075463752097                        Sollte, vorausgesetzt, Bonn
#  2566852176210875826                                              Nord?
#  1067449746628595721               SWB Straßenbahnvorrang an Kreuzungen
# ...                                                                 ...
#  1973698535830369582             Ampel dann auch radfreundlich schalten
#  6223618517403548089  Kreuzung Roemerstrasse - Kaiser-Karl-Ring Nord...
# -7384580095283128086                                        Ihr Beitrag
# -2033902179901282955        Überweg für Radfahrer und Fußgänger trennen
#  608546312043052308                Einfahrt in die Kölnstraße freigaben
#  5805553366814824688                   Ampelschaltung Höhe Museum König
#  1372842031231755247     Bettelampel an der B 56 / Reinold-Hagen-Straße
#  6969913009477104879                                        Ihr Beitrag
# -8799723294478368571           Rathenauufer sollte Fahrradstraße werden
#  3026491433871526936                    Ampelschaltung am Endenicher Ei
#  168334671709879618                                  Süd-Ost-Verbindung
# -2472311367726675903                    Poller entfernen auf Popp.Allee
#  8108152969676924882                         Wurzelaufbrüche beseitigen
#  9079875249134115471                          Linksabbiegen ermöglichen
# -3612135372463688021           Radweg zwischen Fahrbahn und Parkplätzen
# -4692037805737303007                                        Ihr Beitrag
#  1826807881673744810            Parker auf Radstreifen Sternenburgallee
# -7905666796425105576  Busfahrer missachtet entgegenkommenden Radverkehr
#  6969377119120050145           Bei Baustellen Radfahrer berücksichtigen
#  8514051167344148298           Bodenwelle bei Auffahrt zur Reuterbrücke
#  1108464921862587069             Ollenhauerstr / Fnroedrich Ebert Allee
# -5111453943405348232                                        Ihr Beitrag
# -1872486901262230403                          Gefahrenstelle Tankstelle
# -1638961252413740021                                        Ihr Beitrag
# -8234950261182669133        Schlechter Straßenbelag, viele Schlaglöcher
# -3527666862567484508  Einbahnstraße und nicht den Bürgersteig freigeben
#  8078892133457975991  Fehlender Fahrradweg an der Franz-Josef-Strauß...
# -7408600361765941107                                        Ihr Beitrag
#  3859407009916834403           Radweg in beide Richtungen am Busbahnhof
# -5770120604532882743                 Normale Kreuzung oder Kreisverkehr
#
#                                                                    tags  \
# hash
#  492819066359988780                                                None
#  4402470584618071095                                               None
#  6280350261461137971                           Finanzen und Beteiligung
# -3466298431331063864                           Finanzen und Beteiligung
# -7971046904978124907                                               None
# -5464475141879722540                                               None
# -3377659701997023543                                               None
# -9081569078624867654                                               None
# -6681834770025936415                                               None
#  5437548212583122831                                 Freizeit und Sport
# -7583605623074273787                               Bildung und Soziales
# -5464319664140523355                           Finanzen und Beteiligung
# -5788904644317865118                           Finanzen und Beteiligung
# -3078748361664229079  Finanzen und Beteiligung       Verwaltung und ...
#  7436848703089573130  Finanzen und Beteiligung       Verwaltung und ...
# -2393745017980416918                                               None
#  323660551489142748                        Verwaltung und Bürgerservice
#  6121891870271679895                                 Freizeit und Sport
# -2731752165060716664                               Verkehr-Bauen-Umwelt
# -5222543903791805856                       Verwaltung und Bürgerservice
#  5963311242915317913                       Verwaltung und Bürgerservice
# -5306458750461174737                                 Freizeit und Sport
#  4514813816041113023  Kultur und Veranstaltungen       Verkehr-Bauen...
#  1718629525785233234  Kultur und Veranstaltungen       Verkehr-Bauen...
# -7297202107877194955                               Verkehr-Bauen-Umwelt
# -4483786331694335797                               Verkehr-Bauen-Umwelt
#  5871064806466408833                               Verkehr-Bauen-Umwelt
#  2320403075463752097                               Verkehr-Bauen-Umwelt
#  2566852176210875826                               Verkehr-Bauen-Umwelt
#  1067449746628595721                           Finanzen und Beteiligung
# ...                                                                 ...
#  1973698535830369582                                             Ampeln
#  6223618517403548089                                     Radwegqualität
# -7384580095283128086                                     Radwegqualität
# -2033902179901282955                                 Radverkehrsführung
#  608546312043052308                                  Radverkehrsführung
#  5805553366814824688                                             Ampeln
#  1372842031231755247                                             Ampeln
#  6969913009477104879                                             Ampeln
# -8799723294478368571                                 Radverkehrsführung
#  3026491433871526936                                             Ampeln
#  168334671709879618                                  Radverkehrsführung
# -2472311367726675903                                        Hindernisse
#  8108152969676924882                                     Radwegqualität
#  9079875249134115471                                 Radverkehrsführung
# -3612135372463688021                                     Radwegqualität
# -4692037805737303007                                     Radwegqualität
#  1826807881673744810                                          Sonstiges
# -7905666796425105576                                          Sonstiges
#  6969377119120050145                                        Hindernisse
#  8514051167344148298                                     Radwegqualität
#  1108464921862587069                                             Ampeln
# -5111453943405348232                                             Ampeln
# -1872486901262230403                                      Beschilderung
# -1638961252413740021                                      Beschilderung
# -8234950261182669133                                     Radwegqualität
# -3527666862567484508                                 Radverkehrsführung
#  8078892133457975991                                 Radverkehrsführung
# -7408600361765941107                                 Radverkehrsführung
#  3859407009916834403                                 Radverkehrsführung
# -5770120604532882743                                      Beschilderung
#
#                                 date_time  \
# hash
#  492819066359988780   2016-10-06 00:00:00
#  4402470584618071095  2016-10-06 00:00:00
#  6280350261461137971  2016-10-06 00:00:00
# -3466298431331063864  2016-10-06 00:00:00
# -7971046904978124907  2016-10-06 00:00:00
# -5464475141879722540  2016-10-06 00:00:00
# -3377659701997023543  2016-10-06 00:00:00
# -9081569078624867654  2016-10-06 00:00:00
# -6681834770025936415  2016-10-06 00:00:00
#  5437548212583122831  2016-10-06 00:00:00
# -7583605623074273787  2016-10-04 00:00:00
# -5464319664140523355  2016-10-05 00:00:00
# -5788904644317865118  2016-10-06 19:47:00
# -3078748361664229079  2016-10-05 00:00:00
#  7436848703089573130  2016-10-06 21:14:00
# -2393745017980416918  2016-10-06 00:00:00
#  323660551489142748   2016-10-04 00:00:00
#  6121891870271679895  2016-10-05 00:00:00
# -2731752165060716664  2016-10-06 00:00:00
# -5222543903791805856  2016-10-06 00:00:00
#  5963311242915317913  2016-10-06 12:45:00
# -5306458750461174737  2016-10-06 00:00:00
#  4514813816041113023  2016-10-06 00:00:00
#  1718629525785233234  2016-10-06 20:15:00
# -7297202107877194955  2016-09-17 00:00:00
# -4483786331694335797  2016-09-17 12:47:00
#  5871064806466408833  2016-09-21 00:00:00
#  2320403075463752097  2016-09-28 08:58:00
#  2566852176210875826  2016-10-04 11:54:00
#  1067449746628595721  2016-09-19 00:00:00
# ...                                   ...
#  1973698535830369582  2017-10-18 22:32:00
#  6223618517403548089  2017-10-18 00:00:00
# -7384580095283128086  2017-10-26 11:56:00
# -2033902179901282955  2017-10-18 00:00:00
#  608546312043052308   2017-10-18 00:00:00
#  5805553366814824688  2017-10-18 00:00:00
#  1372842031231755247  2017-10-18 00:00:00
#  6969913009477104879  2017-10-20 23:06:00
# -8799723294478368571  2017-10-18 00:00:00
#  3026491433871526936  2017-10-18 00:00:00
#  168334671709879618   2017-10-18 00:00:00
# -2472311367726675903  2017-10-18 00:00:00
#  8108152969676924882  2017-10-18 00:00:00
#  9079875249134115471  2017-10-18 00:00:00
# -3612135372463688021  2017-10-18 00:00:00
# -4692037805737303007  2017-10-26 11:50:00
#  1826807881673744810  2017-10-18 00:00:00
# -7905666796425105576  2017-10-18 00:00:00
#  6969377119120050145  2017-10-18 00:00:00
#  8514051167344148298  2017-10-18 00:00:00
#  1108464921862587069  2017-10-18 00:00:00
# -5111453943405348232  2017-10-20 22:59:00
# -1872486901262230403  2017-10-18 00:00:00
# -1638961252413740021  2017-11-03 13:09:00
# -8234950261182669133  2017-10-18 00:00:00
# -3527666862567484508  2017-10-18 00:00:00
#  8078892133457975991  2017-10-18 00:00:00
# -7408600361765941107  2017-10-26 11:47:00
#  3859407009916834403  2017-10-18 00:00:00
# -5770120604532882743  2017-10-18 00:00:00
#
#                                                                    text  \
# hash
#  492819066359988780   Nebentätigkeiten von OB und Kommunalpoilter - ...
#  4402470584618071095  Wache (Gabi) im Bahnhof .\nDiese wurde vor ca....
#  6280350261461137971  Monetäre Sparmaßnahme .\nAblösung aller Kredit...
# -3466298431331063864  Kosteneinsparung bei Friedhof-/Parkanlagen in ...
# -7971046904978124907  Leerstand .\nSiehe Leerstandsmelder und eigene...
# -5464475141879722540  Minusstunden bei der Feuerwehr; Öffnungszeiten...
# -3377659701997023543  Stadtverwaltung und Einsparmöglichkeiten .\nÜb...
# -9081569078624867654  Aufsichtsrat Stadtwerke Bonn .\nIst es wirklic...
# -6681834770025936415  Sparkasse Köln Bonn und Ausschüttung der Gewin...
#  5437548212583122831  Beendigung der Unterstützung der Kunst!Rasen-V...
# -7583605623074273787  Mehr Geld für Bonner staatliche Gymnasien .\nV...
# -5464319664140523355  Bürgerbestimmung Großprojekte .\nBei großen Ba...
# -5788904644317865118  Großprojekte .\nKein Großprojekt in Bonn bis d...
# -3078748361664229079  Patenschaften für Gräber auf Bonner Friedhöfen...
#  7436848703089573130  Friedhöfe in Ordnung halten .\nEs gibt z. B. i...
# -2393745017980416918  Verkehrs- Umwelt- und Gesundheits-Konzept .\nV...
#  323660551489142748   Weihnachtsbaumabholung durch Bonn Orange einst...
#  6121891870271679895  Alternative Nutzung für leer stehende Pützchen...
# -2731752165060716664  Mehr Geld für den ÖPNV .\nSeit vielen Jahren s...
# -5222543903791805856  Gelbe Säcke .\nDie Bestellung der Gelbe Säcke ...
#  5963311242915317913  Was hat dieser Vorschlag mit .\nWas hat dieser...
# -5306458750461174737  Reitwege im Gebiet Vinxel / Niederholtdorf/ Pa...
#  4514813816041113023  Sparen .\nEs könnten sehr viele Ampeln von 22 ...
#  1718629525785233234  Fahrradzaehlung .\nIst eine elektronische Zähl...
# -7297202107877194955  Anreizsystem für Übernahme von Grünpatenschaft...
# -4483786331694335797  Sehr schöne Idee! .\nDer Vorschlag würde einen...
#  5871064806466408833  Verlängerung der Straßenbahn 61 62 bis Godesbe...
#  2320403075463752097  Sollte, vorausgesetzt, Bonn .\nSollte, vorausg...
#  2566852176210875826  Nord? .\nIch dachte, Mehlem liegt im Süden. Al...
#  1067449746628595721  SWB Straßenbahnvorrang an Kreuzungen .\nBeispi...
# ...                                                                 ...
#  1973698535830369582  Ampel dann auch radfreundlich schalten .\nDies...
#  6223618517403548089  Kreuzung Roemerstrasse - Kaiser-Karl-Ring Nord...
# -7384580095283128086  Ihr Beitrag .\nLieber Gast,herzlichen Dank für...
# -2033902179901282955  Überweg für Radfahrer und Fußgänger trennen .\...
#  608546312043052308   Einfahrt in die Kölnstraße freigaben .\nDerzei...
#  5805553366814824688  Ampelschaltung Höhe Museum König .\nDiese Ampe...
#  1372842031231755247  Bettelampel an der B 56 / Reinold-Hagen-Straße...
#  6969913009477104879  Ihr Beitrag .\nLieber Gast,herzlichen Dank für...
# -8799723294478368571  Rathenauufer sollte Fahrradstraße werden .\nDa...
#  3026491433871526936  Ampelschaltung am Endenicher Ei .\nUm das "End...
#  168334671709879618   Süd-Ost-Verbindung .\nIch weiß eigentlich nie ...
# -2472311367726675903  Poller entfernen auf Popp.Allee .\nHier möchte...
#  8108152969676924882  Wurzelaufbrüche beseitigen .\nIn Höhe der Auto...
#  9079875249134115471  Linksabbiegen ermöglichen .\nEs würde Radfahre...
# -3612135372463688021  Radweg zwischen Fahrbahn und Parkplätzen .\nAu...
# -4692037805737303007  Ihr Beitrag .\nHallo kmb0713, herzlichen Dank ...
#  1826807881673744810  Parker auf Radstreifen Sternenburgallee .\nAuf...
# -7905666796425105576  Busfahrer missachtet entgegenkommenden Radverk...
#  6969377119120050145  Bei Baustellen Radfahrer berücksichtigen .\nOb...
#  8514051167344148298  Bodenwelle bei Auffahrt zur Reuterbrücke .\nAn...
#  1108464921862587069  Ollenhauerstr / Fnroedrich Ebert Allee .\nDer ...
# -5111453943405348232  Ihr Beitrag .\nLieber Gast, herzlichen Dank fü...
# -1872486901262230403  Gefahrenstelle Tankstelle .\nVon der Reuterbrü...
# -1638961252413740021  Ihr Beitrag .\nLieber Gast, herzlichen Dank fü...
# -8234950261182669133  Schlechter Straßenbelag, viele Schlaglöcher .\...
# -3527666862567484508  Einbahnstraße und nicht den Bürgersteig freige...
#  8078892133457975991  Fehlender Fahrradweg an der Franz-Josef-Strauß...
# -7408600361765941107  Ihr Beitrag .\nLieber Gast, herzlichen Dank fü...
#  3859407009916834403  Radweg in beide Richtungen am Busbahnhof .\nDa...
# -5770120604532882743  Normale Kreuzung oder Kreisverkehr .\nBei der ...
#
#                                                                     doc
# hash
#  492819066359988780   (Nebentätigkeiten, von, OB, und, Kommunalpoilt...
#  4402470584618071095  (Wache, (, Gabi, ), im, Bahnhof, ., \n, Diese,...
#  6280350261461137971  (Monetäre, Sparmaßnahme, ., \n, Ablösung, alle...
# -3466298431331063864  (Kosteneinsparung, bei, Friedhof-/Parkanlagen,...
# -7971046904978124907  (Leerstand, ., \n, Siehe, Leerstandsmelder, un...
# -5464475141879722540  (Minusstunden, bei, der, Feuerwehr, ;, Öffnung...
# -3377659701997023543  (Stadtverwaltung, und, Einsparmöglichkeiten, ....
# -9081569078624867654  (Aufsichtsrat, Stadtwerke, Bonn, ., \n, Ist, e...
# -6681834770025936415  (Sparkasse, Köln, Bonn, und, Ausschüttung, der...
#  5437548212583122831  (Beendigung, der, Unterstützung, der, Kunst, !...
# -7583605623074273787  (Mehr, Geld, für, Bonner, staatliche, Gymnasie...
# -5464319664140523355  (Bürgerbestimmung, Großprojekte, ., \n, Bei, g...
# -5788904644317865118  (Großprojekte, ., \n, Kein, Großprojekt, in, B...
# -3078748361664229079  (Patenschaften, für, Gräber, auf, Bonner, Frie...
#  7436848703089573130  (Friedhöfe, in, Ordnung, halten, ., \n, Es, gi...
# -2393745017980416918  (Verkehrs-, Umwelt-, und, Gesundheits-Konzept,...
#  323660551489142748   (Weihnachtsbaumabholung, durch, Bonn, Orange, ...
#  6121891870271679895  (Alternative, Nutzung, für, leer, stehende, Pü...
# -2731752165060716664  (Mehr, Geld, für, den, ÖPNV, ., \n, Seit, viel...
# -5222543903791805856  (Gelbe, Säcke, ., \n, Die, Bestellung, der, Ge...
#  5963311242915317913  (Was, hat, dieser, Vorschlag, mit, ., \n, Was,...
# -5306458750461174737  (Reitwege, im, Gebiet, Vinxel, /, Niederholtdo...
#  4514813816041113023  (Sparen, ., \n, Es, könnten, sehr, viele, Ampe...
#  1718629525785233234  (Fahrradzaehlung, ., \n, Ist, eine, elektronis...
# -7297202107877194955  (Anreizsystem, für, Übernahme, von, Grünpatens...
# -4483786331694335797  (Sehr, schöne, Idee, !, ., \n, Der, Vorschlag,...
#  5871064806466408833  (Verlängerung, der, Straßenbahn, 61, 62, bis, ...
#  2320403075463752097  (Sollte, ,, vorausgesetzt, ,, Bonn, ., \n, Sol...
#  2566852176210875826  (Nord, ?, ., \n, Ich, dachte, ,, Mehlem, liegt...
#  1067449746628595721  (SWB, Straßenbahnvorrang, an, Kreuzungen, ., \...
# ...                                                                 ...
#  1973698535830369582  (Ampel, dann, auch, radfreundlich, schalten, ....
#  6223618517403548089  (Kreuzung, Roemerstrasse, -, Kaiser-Karl-Ring,...
# -7384580095283128086  (Ihr, Beitrag, ., \n, Lieber, Gast, ,, herzlic...
# -2033902179901282955  (Überweg, für, Radfahrer, und, Fußgänger, tren...
#  608546312043052308   (Einfahrt, in, die, Kölnstraße, freigaben, ., ...
#  5805553366814824688  (Ampelschaltung, Höhe, Museum, König, ., \n, D...
#  1372842031231755247  (Bettelampel, an, der, B, 56, /, Reinold-Hagen...
#  6969913009477104879  (Ihr, Beitrag, ., \n, Lieber, Gast, ,, herzlic...
# -8799723294478368571  (Rathenauufer, sollte, Fahrradstraße, werden, ...
#  3026491433871526936  (Ampelschaltung, am, Endenicher, Ei, ., \n, Um...
#  168334671709879618   (Süd-Ost-Verbindung, ., \n, Ich, weiß, eigentl...
# -2472311367726675903  (Poller, entfernen, auf, Popp, ., Allee, ., \n...
#  8108152969676924882  (Wurzelaufbrüche, beseitigen, ., \n, In, Höhe,...
#  9079875249134115471  (Linksabbiegen, ermöglichen, ., \n, Es, würde,...
# -3612135372463688021  (Radweg, zwischen, Fahrbahn, und, Parkplätzen,...
# -4692037805737303007  (Ihr, Beitrag, ., \n, Hallo, kmb0713, ,, herzl...
#  1826807881673744810  (Parker, auf, Radstreifen, Sternenburgallee, ....
# -7905666796425105576  (Busfahrer, missachtet, entgegenkommenden, Rad...
#  6969377119120050145  (Bei, Baustellen, Radfahrer, berücksichtigen, ...
#  8514051167344148298  (Bodenwelle, bei, Auffahrt, zur, Reuterbrücke,...
#  1108464921862587069  (Ollenhauerstr, /, Fnroedrich, Ebert, Allee, ....
# -5111453943405348232  (Ihr, Beitrag, ., \n, Lieber, Gast, ,, herzlic...
# -1872486901262230403  (Gefahrenstelle, Tankstelle, ., \n, Von, der, ...
# -1638961252413740021  (Ihr, Beitrag, ., \n, Lieber, Gast, ,, herzlic...
# -8234950261182669133  (Schlechter, Straßenbelag, ,, viele, Schlaglöc...
# -3527666862567484508  (Einbahnstraße, und, nicht, den, Bürgersteig, ...
#  8078892133457975991  (Fehlender, Fahrradweg, an, der, Franz-Josef-S...
# -7408600361765941107  (Ihr, Beitrag, ., \n, Lieber, Gast, ,, herzlic...
#  3859407009916834403  (Radweg, in, beide, Richtungen, am, Busbahnhof...
# -5770120604532882743  (Normale, Kreuzung, oder, Kreisverkehr, ., \n,...
#
# [26138 rows x 9 columns]

# %%
lst = []
for tpl in df.itertuples():
    for i, sent in enumerate(tpl[9].sents):
        sent_list = []
        for token in sent:
            if token._.iwnlp_lemmas:
                lemma = token._.iwnlp_lemmas[0]
            else:
                lemma = token.lemma_
            sent_list.append(lemma)
        t = (tpl[0], i, sent_list)
        lst.append(t)
        
df_new = pd.DataFrame(lst, columns=[HASH, 'sent_idx', 'sentence'])
df_new
# Out:
#                        hash  sent_idx  \
# 0        492819066359988780         0
# 1        492819066359988780         1
# 2        492819066359988780         2
# 3        492819066359988780         3
# 4       4402470584618071095         0
# 5       4402470584618071095         1
# 6       4402470584618071095         2
# 7       4402470584618071095         3
# 8       4402470584618071095         4
# 9       4402470584618071095         5
# 10      4402470584618071095         6
# 11      6280350261461137971         0
# 12      6280350261461137971         1
# 13      6280350261461137971         2
# 14     -3466298431331063864         0
# 15     -3466298431331063864         1
# 16     -3466298431331063864         2
# 17     -3466298431331063864         3
# 18     -3466298431331063864         4
# 19     -3466298431331063864         5
# 20     -3466298431331063864         6
# 21     -7971046904978124907         0
# 22     -7971046904978124907         1
# 23     -7971046904978124907         2
# 24     -7971046904978124907         3
# 25     -7971046904978124907         4
# 26     -7971046904978124907         5
# 27     -7971046904978124907         6
# 28     -7971046904978124907         7
# 29     -7971046904978124907         8
# ...                     ...       ...
# 144477 -3527666862567484508         1
# 144478 -3527666862567484508         2
# 144479 -3527666862567484508         3
# 144480 -3527666862567484508         4
# 144481 -3527666862567484508         5
# 144482 -3527666862567484508         6
# 144483 -3527666862567484508         7
# 144484 -3527666862567484508         8
# 144485  8078892133457975991         0
# 144486  8078892133457975991         1
# 144487  8078892133457975991         2
# 144488 -7408600361765941107         0
# 144489 -7408600361765941107         1
# 144490 -7408600361765941107         2
# 144491 -7408600361765941107         3
# 144492 -7408600361765941107         4
# 144493 -7408600361765941107         5
# 144494 -7408600361765941107         6
# 144495 -7408600361765941107         7
# 144496 -7408600361765941107         8
# 144497  3859407009916834403         0
# 144498  3859407009916834403         1
# 144499  3859407009916834403         2
# 144500  3859407009916834403         3
# 144501  3859407009916834403         4
# 144502  3859407009916834403         5
# 144503 -5770120604532882743         0
# 144504 -5770120604532882743         1
# 144505 -5770120604532882743         2
# 144506 -5770120604532882743         3
#
#                                                  sentence
# 0       [Nebentätigkeit, von, OB, und, Kommunalpoilter...
# 1       [Durch, der, sogenannte"öffentliche, Ehrenamt,...
# 2       [Von, dies, Geld, müssen, kein, Cent, an, der,...
# 3                       [Das, gehören, abschaffen, .....]
# 4                 [Wache, (, Gabi, ), im, Bahnhof, ., \n]
# 5       [Diese, werden, vor, ca.5, Jahr, für, sehr, vi...
# 6       [Jetzt, sollen, einen, neu, Wache, bauen, werd...
# 7                  [Läßt, sich, der, nicht, vermeiden, ?]
# 8                                                     [?]
# 9                                                     [?]
# 10                                                    [?]
# 11                         [monetär, Sparmaßnahme, ., \n]
# 12      [Ablösung, all, Kredit, der, Stadt, für, der, ...
# 13      [Abschluss, neu, Kredit, mit, der, derzeit, ni...
# 14      [Kosteneinsparung, bei, Friedhof-/Parkanlagen,...
# 15      [Es, geben, z., B., in, viel, Stadt, der, USA,...
# 16      [Die, Bürger, übernehmen, dies, Arbeit, und, h...
# 17      [Das, ganz, unter, der, Anweisung, und, Kontro...
# 18      [Hier, werden, Personalkapazitäten, frei, stel...
# 19      [Je, nach, Ausweitung, können, sogar, über, ei...
# 20      [Diese, Einsatz, mit, Freiwilliger, können, au...
# 21                                            [Leerstand]
# 22                                                [., \n]
# 23      [sehen, Leerstandsmelder, und, eigen, Unterlag...
# 24      [In, Bonn, stehen, so, viel, Haus, leer, bzw, ...
# 25           [Ein, Teil, gehören, auch, der, Stadt, Bonn]
# 26                                [/Uni/, Privatmenschen]
# 27                                               [.., \n]
# 28      [Eigentum, verpflichten, und, ich, werden, Woh...
# 29      [Bsp, Richtung, Godesberg, nur, noch, Bürokomp...
# ...                                                   ...
# 144477  [Von, der, Rheingasse, kommend, müssen, ich, R...
# 144478                  [Am, Boeselagerhof, einbiegen, .]
# 144479  [Hier, fehlen, einen, Schild, ,, dass, der, Ei...
# 144480  [Erst, ab, der, Kapuzinerstraße, geben, ich, d...
# 144481  [Vorher, sollen, man, wohl, irgendwie, über, d...
# 144482                              [bitten, der, Straße]
# 144483                  [Am, Boeselagerhof, freigeben, .]
# 144484                                        [danken, .]
# 144485  [Fehlender, Fahrradweg, an, der, Franz-Josef-S...
# 144486  [Für, Fahrradfahrer, sein, der, Befahrung, der...
# 144487  [Insbesondere, von, der, Marie-Kahle-Allee, ko...
# 144488                              [Ihr, Beitrag, ., \n]
# 144489                                           [Lieber]
# 144490  [Gast, ,, herzlich, Dank, für, Ihren, Beitrag, .]
# 144491  [Sie, haben, mein, Vorschlag, der, Kategorie, ...
# 144492  [Das, von, Ihnen, angesprochen, Thema, sein, n...
# 144493  [Um, sicherstellen, ,, dass, Ihr, Vorschlag, i...
# 144494         [Wir, bitten, um, Ihr, Verständnis, ., \n]
# 144495                                         [herzlich]
# 144496                      [Dank, ,, Moderation, Wähner]
# 144497  [Radweg, in, beid, Richtung, am, Busbahnhof, ....
# 144498  [Das, mit, Abstand, am, wichtig, sein, einen, ...
# 144499  [aktuell, geben, ich, einfach, kein, Möglichke...
# 144500  [Das, werden, der, Verkehr, am, Busbahnhof, es...
# 144501  [Ansonsten, Kompliment, ,, sehr, nett, in, der...
# 144502      [Ich, hoffen, ,, der, helfen, Ihnen, weit, .]
# 144503      [normal, Kreuzung, oder, Kreisverkehr, ., \n]
# 144504  [Bei, der, Kreuzung, Euskirchener, Str, /, Eri...
# 144505  [Durch, der, kreisrund, Pflasterung, werden, a...
# 144506  [Vielleicht, werden, einen, genau, Beschilderu...
#
# [144507 rows x 3 columns]

# %%
phrases = gensim.models.phrases.Phrases(
    df_new['sentence'], 
    common_terms=stopwords, 
    min_count=3, 
    # threshold=0, scoring='npmi',
)
bigram = gensim.models.phrases.Phraser(phrases)
texts = [bigram[sentence] for sentence in df_new['sentence']]
texts
# Out:
# [['Nebentätigkeiten',
#   'von',
#   'OB',
#   'und',
#   'Kommunalpoilter',
#   '-',
#   'öffentliches',
#   'Ehrenamt',
#   '.',
#   '\n'],
#  ['Durch',
#   'das',
#   'sogenannte"öffentliche',
#   'Ehrenamt',
#   '"',
#   ' ',
#   'verdienen',
#   'manche',
#   'Komunalpolitiker',
#   'und',
#   'OB`s',
#   ' ',
#   'in',
#   'den',
#   'Verwaltungsräten',
#   'und',
#   'Aufsichtsräten',
#   'viel',
#   'Geld',
#   '(',
#   'bis',
#   'zu',
#   '5-stellig',
#   ')',
#   '\n'],
#  ['Von',
#   'diesem',
#   'Geld',
#   'muss',
#   'kein',
#   'Cent',
#   'an',
#   'die',
#   'Stadtkasse',
#   'abgeführt',
#   'werden',
#   'da',
#   'es',
#   'sich',
#   'um',
#   'ein',
#   'sogenanntes',
#   'öffentliches',
#   'Ehrenamt',
#   'handelt',
#   '.',
#   '\n'],
#  ['Das', 'gehört', 'abgeschafft', '.....'],
#  ['Wache', '(', 'Gabi', ')', 'im', 'Bahnhof', '.', '\n'],
#  ['Diese',
#   'wurde',
#   'vor',
#   'ca.5',
#   'Jahren',
#   'für',
#   'sehr',
#   'viel',
#   'Geld',
#   'umgebaut',
#   'und',
#   'galt',
#   'als',
#   'Vorzeigemodell',
#   'in',
#   'NRW',
#   '\n'],
#  ['Jetzt',
#   'soll',
#   'eine',
#   'neue',
#   'Wache',
#   'gebaut',
#   'werden',
#   ',',
#   'da',
#   'der',
#   'Bahnhofsumbau',
#   'beginnen',
#   'soll',
#   '.',
#   '\n'],
#  ['Läßt', 'sich', 'das', 'nicht', 'vermeiden', '?'],
#  ['?'],
#  ['?'],
#  ['?'],
#  ['Monetäre', 'Sparmaßnahme', '.', '\n'],
#  ['Ablösung',
#   'aller',
#   'Kredite',
#   'der',
#   'Stadt',
#   'für',
#   'die',
#   'mehr',
#   'als',
#   '1',
#   '-',
#   '2',
#   '%',
#   'Zinsen',
#   'vereinbart',
#   'wurden',
#   '.'],
#  ['Abschluss',
#   'neuer_Kredite',
#   'mit',
#   'den',
#   'derzeit',
#   'niedrigen',
#   'Zinsen',
#   'auf',
#   'lange',
#   'Sicht',
#   '.'],
#  ['Kosteneinsparung', 'bei', 'Friedhof-/Parkanlagen', 'in', 'Bonn', '.', '\n'],
#  ['Es',
#   'gibt',
#   'z._B.',
#   'in',
#   'vielen',
#   'Städten',
#   'der',
#   'USA',
#   '(',
#   'u._a.',
#   'NY',
#   ')',
#   'die',
#   'Möglichkeit',
#   'unter',
#   'Aufsicht',
#   'von',
#   'Gartenfachpersonal',
#   'Senioren',
#   'oder',
#   'sonstige',
#   'Bürger',
#   'mit',
#   'der',
#   'Zeit',
#   'und',
#   'Lust',
#   'dazu',
#   'die',
#   'jeweiligen',
#   'Friedhöfe',
#   'in',
#   'Ordnung',
#   'zu',
#   'halten',
#   '.'],
#  ['Die',
#   'Bürger',
#   'übernehmen',
#   'diese',
#   'Arbeit',
#   'und',
#   'halten',
#   'die',
#   'Anlagen',
#   'sauber',
#   ',',
#   'setzen',
#   'neue',
#   'Pflanzen',
#   'ein',
#   'usw.'],
#  ['Das',
#   'ganze',
#   'unter',
#   'der',
#   'Anweisung',
#   'und',
#   'Kontrolle',
#   'von',
#   'Fachpersonal',
#   '.',
#   '\n'],
#  ['Hier',
#   'werden',
#   'Personalkapazitäten',
#   'frei',
#   'gestellt',
#   'die',
#   'sich',
#   'dann',
#   'in',
#   'anderen',
#   'Bereichen',
#   'vermehrt',
#   'einbringen',
#   'können',
#   '.',
#   '\n'],
#  ['Je',
#   'nach',
#   'Ausweitung',
#   'kann',
#   'sogar',
#   'über',
#   'ein',
#   'Personalabbau',
#   'diskutiert',
#   'werden',
#   '.',
#   '\n'],
#  ['Diese',
#   'Einsätze',
#   'mit',
#   'Freiwilligen',
#   'können',
#   'auch',
#   'in',
#   'Parks',
#   'und',
#   'sonstigen',
#   'Grünflächen',
#   'im',
#   'geamten',
#   'Stadtbezirk',
#   'stattfinden',
#   '.'],
#  ['Leerstand'],
#  ['.', '\n'],
#  ['Siehe',
#   'Leerstandsmelder',
#   'und',
#   'eigene',
#   'Unterlagen',
#   'der',
#   'Stadt_Bonn',
#   '\n'],
#  ['In',
#   'Bonn',
#   'stehen',
#   'so',
#   'viele',
#   'Häuser',
#   'leer',
#   'bzw',
#   'verkommen',
#   '\n'],
#  ['Ein_Teil', 'gehört', 'auch', 'der', 'Stadt_Bonn'],
#  ['/Uni/', 'Privatmenschen'],
#  ['..', '\n'],
#  ['Eigentum',
#   'verpflichtet',
#   'und',
#   'es',
#   'wird',
#   'Wohraum',
#   'benötigt',
#   '-',
#   'auch',
#   'für',
#   'Menschen',
#   'mit',
#   'geringem_Einkommen',
#   '-',
#   'Es',
#   'gibt',
#   'doch',
#   'ein',
#   'Gesetz',
#   ',',
#   'wo',
#   'Eigentümer',
#   'bei',
#   'wissentlicher',
#   'Untätigkeit',
#   '(',
#   'Verfallen',
#   'lassen',
#   'des',
#   'Hauses',
#   ')',
#   ' ',
#   'eine',
#   'Geldstrafe',
#   'erhalten',
#   'und',
#   'wenn',
#   'es',
#   'längere_Zeit',
#   'unbewohnt',
#   'ist',
#   'besteht_die_Möglichkeit',
#   'ihm',
#   'dieses',
#   'zu',
#   'enteignenSie',
#   'müssen',
#   'die',
#   'Bestände',
#   'checken',
#   'und',
#   'nicht',
#   'nur',
#   'an',
#   'Investoren',
#   'verkaufen',
#   'sondern',
#   'auch',
#   'selber',
#   'wieder',
#   'Wohraum',
#   'schaffen',
#   '-',
#   'alternative',
#   'Projekte',
#   'soger',
#   'vorziehen',
#   '-',
#   'denn',
#   'den',
#   'Bürgern',
#   'mit',
#   'kreativen',
#   'Vorschlägen',
#   '/Ideen',
#   'gehört',
#   'die',
#   'Stadt',
#   'und',
#   'wir',
#   'wollen',
#   'doch',
#   'zufriedene',
#   'Bürger',
#   'Bürokomplexe',
#   'die',
#   'ungensutzt',
#   'sind',
#   'in',
#   'Wohnraum',
#   'umwandeln',
#   '-',
#   'es',
#   'ist',
#   'schon',
#   'auffällig',
#   'das',
#   'z',
#   '.'],
#  ['Bsp',
#   'Richtung',
#   'Godesberg',
#   'nur',
#   'noch',
#   'Bürokompexe',
#   'entstehen',
#   '.'],
#  ['Investoren',
#   'besser',
#   'hinterfragen/kritischer',
#   'sein',
#   ',',
#   'auch',
#   'wenn',
#   'diese',
#   'behaupten',
#   'sie',
#   'würden',
#   '30_%',
#   'sozialen_Wohnungsbau',
#   'machen',
#   ',',
#   'wenn',
#   'ihnen',
#   'das',
#   ' ',
#   'XY',
#   'Gelände',
#   'verkauft',
#   'wird',
#   '-',
#   'und',
#   'im',
#   'Anschluss',
#   'ziehen',
#   'sie',
#   'die',
#   'Förderung',
#   'zurück',
#   'und',
#   'vermieten',
#   'für',
#   '13',
#   '€',
#   'den',
#   'qm'],
#  ['Minusstunden', 'bei', 'der', 'Feuerwehr', ';'],
#  ['Öffnungszeiten', 'der', 'Schwimmbäder', 'stützen', '.', '\n'],
#  ['Ich_schlage',
#   'vor',
#   ',',
#   'auf',
#   'eine',
#   'regelmäßige',
#   'Öffnung',
#   'der',
#   'Schwimmbäder',
#   'hinzuarbeiten',
#   '.',
#   '\n'],
#  ['Dies',
#   'kann',
#   'kostengünstig',
#   'auch',
#   'dadurch',
#   'erfolgen',
#   ',',
#   'dass',
#   'die',
#   'Feuerwehrleute',
#   'mit',
#   'Minusstunden',
#   'ihre',
#   'Defizite',
#   'als',
#   'Bademeister',
#   'abarbeiten',
#   'dürfen',
#   '.'],
#  ['Regelmäßige',
#   'Öffniungszeiten',
#   'sind',
#   'wichtig',
#   'für',
#   'die',
#   'Kinder',
#   'und',
#   'Dauerschwimmer',
#   '.'],
#  ['Alle',
#   'Feuerwehrleute',
#   'haben',
#   'einen',
#   'DLRG',
#   '-',
#   'Schein',
#   'und',
#   'können',
#   'die',
#   'Bademeister',
#   'zumindest',
#   'unterstützen',
#   '.'],
#  ['Stadtverwaltung', 'und', 'Einsparmöglichkeiten', '.', '\n'],
#  ['Überlegung',
#   ',',
#   'ob',
#   'das',
#   'Stadtarchiv',
#   '(',
#   'das',
#   'ich',
#   'sehr',
#   'gut',
#   'und',
#   'wichtig',
#   'finde',
#   ')',
#   ',',
#   'das',
#   'jeden',
#   'Samstag',
#   'bis',
#   '12_Uhr',
#   'geöffnet',
#   'ist',
#   ',',
#   'nicht',
#   'nur',
#   'noch',
#   '1_x',
#   'im',
#   'Monat',
#   'diesen',
#   'Service',
#   'anbietet',
#   '.'],
#  ['(',
#   'Kosten-Nutzen-Rechnung-',
#   'wieviele',
#   'Menschen',
#   'nutzen',
#   'dieses',
#   'Angebot',
#   'am',
#   'Samstag)Müssen',
#   'Mitarbeiter_der_Stadtverwaltung'],
#  ['Urlaubstage', 'für', 'z', '.'],
#  ['Bsp',
#   'Altweiber',
#   '(',
#   'Donnerstag',
#   ')',
#   'und',
#   'Karnevalsfreitag',
#   'nehmen',
#   'oder',
#   'haben',
#   'sie',
#   'diese',
#   'frei',
#   'wg',
#   'Brauchtumspflege',
#   '-',
#   '  ',
#   '(',
#   'Ich',
#   'muss',
#   'Urlaub',
#   'nehmen)Gibt',
#   'es',
#   'eigentlich',
#   'bei',
#   'der',
#   'Stadt',
#   'eine',
#   'Art',
#   'Prämie',
#   'für',
#   'Mitarbeiter',
#   '?'],
#  ['Wenn', 'ja', ',', 'wird', 'diese', 'hinterfragt', '?', ' '],
#  ['Ansonsten', 'hat', 'sich', 'die', 'Frage', 'erledigt', '!', '!'],
#  ['Werden',
#   'Fortbildungen',
#   'für',
#   'Mitarbeiter',
#   'als',
#   'In-house-Seminare',
#   'angeboten',
#   ',',
#   'so',
#   'dass',
#   'mehrer',
#   'MA',
#   'daran',
#   'teilnehmen',
#   'können',
#   'oder',
#   'wird',
#   'es',
#   'individuell',
#   'gestaltet',
#   '(',
#   'In-House-Fortbildungen',
#   'sind',
#   'z.g',
#   '.'],
#  ['T', 'günstiger', 'da'],
#  ['Übernachtungskosten',
#   '/',
#   'Wegegeld',
#   'etc',
#   'wegfällt)Warum',
#   'wird',
#   'der',
#   'Bonn-Ausweis',
#   'für',
#   'SGB',
#   'II-Bezieher',
#   'nicht',
#   'direkt',
#   'über',
#   'das',
#   'Jobcenter',
#   '/',
#   'Grundsicherung',
#   'ausgestellt',
#   'sowie',
#   'bei',
#   'Bedarf',
#   'ein',
#   'WBS',
#   '?'],
#  ['(',
#   'Bürokratieabbau-',
#   ' ',
#   'das',
#   'JC',
#   'hat',
#   'die',
#   'finanzielle_Situation',
#   'der',
#   'Antragsteller',
#   'im',
#   'Vorfeld',
#   'schon',
#   'geprüft)Werden',
#   'die',
#   'Mitarbeiter',
#   'nach',
#   'poteniellen',
#   'Einsparmöglichkeiten',
#   '/',
#   'Effizienz',
#   '/',
#   'Effektivität',
#   '/'],
#  ['Vorgängen',
#   'befragt-',
#   'diese',
#   'wissen',
#   'doch',
#   'am',
#   'besten',
#   'wo',
#   'gespart/effektiver',
#   'gearbeitet',
#   'werden',
#   'und',
#   'was',
#   'überflüssig',
#   'ist'],
#  ['Aufsichtsrat', 'Stadtwerke'],
#  ['Bonn'],
#  ['.', '\n'],
#  ['Ist',
#   'es',
#   'wirklich',
#   'notwendig',
#   'das',
#   'dieser',
#   'aus',
#   '16',
#   'Mitglieder',
#   'besteht',
#   '?',
#   '\n'],
#  ['Davon',
#   'sind',
#   'noch',
#   '8',
#   'Mitglieder',
#   'aus',
#   'der',
#   'Politik',
#   'und',
#   'alle',
#   'dieser',
#   'Menschen',
#   'verdienen',
#   'ihr',
#   'Geld',
#   'mit',
#   'ihren_eigentlichen',
#   'Berufen',
#   '.',
#   '\n'],
#  ['Sie',
#   'beziehen',
#   'dann',
#   'zusätzlich',
#   'noch',
#   'Gelder',
#   'aus',
#   'Ihre',
#   'Tätigkeit',
#   'aus',
#   'dem',
#   'Aufsichtsrat',
#   '.',
#   '\n'],
#  ['Ein',
#   'Obulus',
#   'wäre',
#   'ok',
#   'aber',
#   'ich',
#   'denke',
#   'die',
#   'Bezüge',
#   'sind',
#   'eher',
#   'hoch',
#   'anzusetzen',
#   '.',
#   '\n'],
#  ['Darauf',
#   'könnte',
#   'man',
#   'doch',
#   'bei',
#   'der',
#   'prekären',
#   'Haushalts-Lage',
#   'in',
#   'Bonn',
#   'verzichten'],
#  ['Sparkasse', 'Köln'],
#  ['Bonn', 'und', 'Ausschüttung', 'der', 'Gewinne', '.', '\n'],
#  ['Warum', 'schüttet', 'die', 'Sparkasse'],
#  ['KÖLNBONN', ' '],
#  ['nur',
#   'winzige',
#   'Bruchteile',
#   'ihrer',
#   'Gewinne',
#   'an',
#   'die',
#   'Stadt',
#   'aus',
#   '.'],
#  ['Diese',
#   'Sparkasse',
#   'ist',
#   'doch',
#   'z.',
#   'T',
#   'auch',
#   'in',
#   'kommunaler',
#   'Trägerschaft',
#   'Durch',
#   'eine',
#   'angemessene',
#   ' ',
#   'Ausschüttung',
#   'könnte',
#   'der',
#   'komunale',
#   'Haushalt',
#   'entlastet',
#   'werden'],
#  ['Es',
#   'ist',
#   'nicht',
#   'korrekt',
#   'von',
#   'diesem',
#   'Geld',
#   'eigene',
#   'Sicherheitsrücklagen',
#   'zu',
#   'bilden',
#   '\n'],
#  ['Die', 'Entschuldigung', 'das', 'man'],
#  ['Eigenkapital',
#   'braucht',
#   'auf',
#   'Grund',
#   'der',
#   'niedrigen',
#   'Zinsen',
#   'und',
#   'steigenden',
#   'Regulkierungskosten',
#   'etc_...'],
#  ['ist',
#   'nicht',
#   'zu',
#   'akzeptieren',
#   '-',
#   'das',
#   'betrifft',
#   'uns',
#   'alleIn',
#   'den',
#   'Aufsichträten',
#   'sitzten-',
#   'glaube',
#   'ich-',
#   'auch',
#   'wiederum',
#   'städtischen',
#   'Politiker',
#   ',',
#   ' ',
#   'die',
#   'hier',
#   'wiederum',
#   'Gelder',
#   'beziehen',
#   '-',
#   'trotz',
#   'Gehalt',
#   'aus',
#   'dem',
#   'eigentlcihem',
#   'Beruf',
#   '\n',
#   'Hier',
#   'müßte',
#   'man',
#   'auch',
#   'eingreifen',
#   ';'],
#  ['diese', 'Bezüge', 'müssen', 'gedeckelt', ' '],
#  ['werden-', 'Ich_verweise', 'auf', 'die', 'prekäre', 'Haushaltslage'],
#  ['Beendigung', 'der', 'Unterstützung', 'der', 'Kunst', '!'],
#  ['Rasen-Veranstaltungen', 'in', 'der', 'Rheinaue', '.', '\n'],
#  ['Die',
#   'Stadt_Bonn',
#   'unterstützt',
#   'seit',
#   '2012',
#   'den',
#   'Veranstalter',
#   'der',
#   'o._g.',
#   'Open-Air-Veranstaltungen',
#   'in',
#   'jeder',
#   'erdenklichen',
#   'Form',
#   '.'],
#  ['Die', 'Fa.', 'KultMeile'],
#  ['UG',
#   '(',
#   'Inhaber',
#   ':',
#   'Martin',
#   'Nötzel',
#   ')',
#   'muss',
#   'weder',
#   'Pachtgebühren',
#   'für',
#   'eine',
#   'jeweils',
#   'mehrmonatige',
#   'Nutzung',
#   'eines',
#   '"',
#   'Filetstücks',
#   '"',
#   'des',
#   'Landschaftsschutzgebietes',
#   '"',
#   'Rheinaue',
#   '"',
#   'und',
#   'die',
#   'damit',
#   'einhergehende',
#   'Verunstaltung',
#   'der',
#   'Rasenflächen',
#   'zahlen',
#   'noch',
#   'die',
#   'Kosten',
#   'der',
#   'gesetzlich',
#   'erforderlichen',
#   'Lärmmessungen',
#   'selbst',
#   'tragen',
#   '(_siehe',
#   'bsp',
#   '.'],
#  ['die', 'Drucksachen-Nr', '.', '1312504', 'vom', '16.08.2013', ')', '.'],
#  ['Die',
#   'Stadt_Bonn',
#   'stellt',
#   'Haushaltsmittel',
#   'in',
#   'Höhe',
#   'von',
#   '25.000,00',
#   'Euro',
#   '(',
#   '2013',
#   ')',
#   'mit',
#   'dem',
#   'ungewissen',
#   'Ziel',
#   'einer',
#   'Rückzahlung',
#   '(',
#   'd._h.',
#   'nur',
#   'wenn',
#   'es',
#   'die',
#   'wirtschaftliche',
#   'Situation',
#   'des',
#   'Veranstalters',
#   'erlaubt',
#   ')',
#   'bereit',
#   '.'],
#  ['Ein',
#   'derartiges',
#   'Handeln',
#   'ist',
#   'moralisch',
#   'verwerflich',
#   'und',
#   'kann',
#   'in',
#   'Zeiten',
#   'eines',
#   'Milliardendefizits',
#   'im',
#   'städtischen_Haushalt',
#   'künftig',
#   'nicht',
#   'weiter',
#   'hingenommen',
#   'werden',
#   '.'],
#  ['Die',
#   'Verwaltung_empfiehlt',
#   ',',
#   'dem',
#   'Bürgervorschlag_nicht_zu_folgen',
#   '.'],
#  ['Auf',
#   'Beschluss',
#   'des',
#   'Rates',
#   'vom',
#   '19.09.2013',
#   '(_DS-Nr',
#   '.',
#   ':',
#   '1312504',
#   ')',
#   'wurden',
#   'die',
#   'Kosten',
#   'für',
#   'Lärmmessungen',
#   'in',
#   'Höhe',
#   'von',
#   '25.000',
#   'EUR',
#   'übernommen',
#   ',',
#   'um',
#   'die',
#   'im',
#   'Sommer',
#   '2013',
#   'noch',
#   'laufenden',
#   'Open-Air-Konzerte',
#   'nicht',
#   'zu',
#   'gefährden',
#   '.'],
#  ['Der',
#   'Veranstalter',
#   'der',
#   'Open-Air-Konzerte',
#   'ist',
#   'verpflichtet',
#   ',',
#   'die',
#   'Kosten',
#   'der',
#   'Lärmmessungen',
#   'der',
#   'Stadt',
#   'zu',
#   'erstatten',
#   ',',
#   'sobald',
#   'ihm',
#   'dies',
#   'wirtschaftlich',
#   'möglich',
#   'ist',
#   '.'],
#  ['Darüber_hinaus',
#   'haben',
#   'die',
#   'Veranstalter',
#   'des',
#   'KunstRasens',
#   'von',
#   'der',
#   'Kulturverwaltung',
#   'keine',
#   'Förderung',
#   'erhalten',
#   '.'],
#  ['Für',
#   'die',
#   'Nutzung',
#   'des',
#   'Geländes',
#   'zahlen',
#   'die',
#   'Veranstalter',
#   'eine',
#   'Pacht',
#   'und',
#   'für',
#   'die',
#   'Beseitigung',
#   'evtl.'],
#  ['Schäden',
#   'in',
#   'der',
#   'Rheinaue',
#   'ist',
#   'bei',
#   'der',
#   'Stadt',
#   'eine',
#   'Kaution',
#   'hinterlegt',
#   '.'],
#  ['Der', 'Vorschlag', 'wird', 'mit', 'Mehrheit_gegen_BBB', 'abgelehnt', '.'],
#  ['Mehr', 'Geld', 'für', 'Bonner', 'staatliche', 'Gymnasien', '.', '\n'],
#  ['Viele',
#   'Gymnasien',
#   'der',
#   'Stadt_Bonn',
#   'sind',
#   'baulich',
#   'in',
#   'schlechtem_Zustand',
#   ',',
#   'da',
#   'zu',
#   'wenig',
#   'Finanzmittel',
#   'für',
#   'den',
#   'Unterhalt',
#   'und',
#   'die',
#   'Sanierung',
#   'der',
#   'Gebäude',
#   'zur',
#   'Verfügung_stehen',
#   '.'],
#  ['Es',
#   'gibt',
#   'uralte',
#   'Fenster',
#   'und',
#   'Türen',
#   ',',
#   'undichte',
#   'Dächer',
#   ',',
#   'verschmutzte',
#   'Flure',
#   ',',
#   'baufällige',
#   'Turnhallen',
#   ',',
#   'mieserable',
#   'Beleuchtung',
#   ',',
#   'häßliche',
#   'Schulhöfe',
#   '.'],
#  ['Für',
#   'eine',
#   'Stadt',
#   ',',
#   'die',
#   'gute',
#   'Bildung',
#   'auf',
#   'ihre',
#   'Fahnen',
#   'schreiben',
#   'will',
#   ',',
#   'bedarf',
#   'es',
#   'daher',
#   'dringend',
#   'der',
#   'Bereitstellung',
#   'ausreichender',
#   'Mittel',
#   ',',
#   'um',
#   'den',
#   'Sanierungsstau',
#   'zügig',
#   'zu',
#   'beheben',
#   '.'],
#  ['Bürgerbestimmung', 'Großprojekte', '.', '\n'],
#  ['Bei',
#   'großen',
#   'Bauvorhaben',
#   'welche',
#   'die',
#   'Stadt_Bonn',
#   'mit',
#   'mind.',
#   '50',
#   'Mio.€',
#   'mitbezahlt',
#   'sollen',
#   'vorher',
#   'die',
#   'Bürger',
#   'abstimmen',
#   '.'],
#  ['Lieber',
#   'eine',
#   'im',
#   'Vergleich',
#   'günstige',
#   'Abstimmung',
#   'durchführen',
#   'als',
#   'später',
#   'Steuergelder',
#   'verschwenden',
#   'für',
#   'Objekte',
#   'die',
#   'wenige',
#   'haben',
#   'möchten',
#   '.'],
#  ['Großprojekte', '.', '\n'],
#  ['Kein',
#   'Großprojekt',
#   'in',
#   'Bonn',
#   'bis',
#   'die',
#   'Sanierung_der_Beethovenhalle',
#   'abgeschlossen',
#   'ist',
#   '\n'],
#  ['Kein',
#   'Zentralbad',
#   'trotz',
#   'angeblichem',
#   'Synergieeffekt',
#   '-',
#   ' ',
#   'der',
#   'wohl',
#   'nur',
#   'für',
#   'die',
#   'SWB',
#   'gut',
#   'ist'],
#  ['Patenschaften', 'für', 'Gräber', 'auf', 'Bonner', 'Friedhöfen', '.', '\n'],
#  ['Auf',
#   'den',
#   'Bonner',
#   'Friedhöfen',
#   'sieht',
#   'man',
#   'leider',
#   'immer',
#   'wieder',
#   'verwilderte',
#   'Gräber',
#   '.',
#   '\n'],
#  ['Nach',
#   'Ablauf',
#   'der',
#   '"',
#   'Ruhezeit',
#   '"',
#   'müssen',
#   'diese',
#   'Gräber',
#   'mitsamt',
#   'Grabsteinen',
#   'eingeebnet',
#   'werden',
#   ',',
#   'was',
#   'sicherlich',
#   'auch',
#   'Kosten_verursacht',
#   '.'],
#  ['Auf',
#   'dem',
#   'Kölner',
#   'Melatenfriedhof',
#   'gibt',
#   'es',
#   'eine',
#   '"',
#   'Aktion',
#   '"',
#   'zur',
#   'Patenschaft',
#   'von',
#   'Gräbern',
#   '.'],
#  ['Dieses',
#   'bedeutet',
#   ',',
#   'dass',
#   'sich',
#   'der',
#   'Mensch',
#   'vor',
#   'dem',
#   'Ableben',
#   'eine',
#   'Grabstätte',
#   'aussucht',
#   ',',
#   'die',
#   'er',
#   'dann',
#   'pflegt',
#   '.'],
#  ['Dadurch',
#   'werden',
#   'Verwilderung',
#   'und',
#   'dergleichen',
#   'vermieden',
#   '.',
#   '\n'],
#  ['Der',
#   'Interessent',
#   'verpflichtet',
#   'sich',
#   'dann',
#   'dazu',
#   ',',
#   'das',
#   'Grab',
#   'regelmäßig',
#   'zu',
#   'pflegen',
#   ',',
#   'Rückschnitt',
#   'zu',
#   'beitreiben',
#   ',',
#   'damit',
#   'es',
#   'immer',
#   'gepflegt',
#   'aussieht',
#   '.'],
#  ['Zwar',
#   'darf',
#   'der',
#   'Grabstein',
#   'dort',
#   'nicht',
#   'geändert',
#   'werden',
#   ',',
#   'aber',
#   'es',
#   'ist',
#   'erlaubt',
#   ',',
#   'sich',
#   'eine',
#   'Platte',
#   'oder',
#   'dergleichen',
#   'mit',
#   'Namen',
#   'in',
#   'die',
#   'Grabstätte',
#   'zu',
#   'legen',
#   '.'],
#  ['Wäre',
#   'dieses',
#   'nicht',
#   'auch',
#   'eine',
#   'Alternative',
#   'für',
#   'die',
#   'Stadt_Bonn',
#   ',',
#   'in',
#   'dem',
#   'Menschen',
#   'sich',
#   'dann',
#   'um',
#   'diese',
#   'Grabstätten',
#   'kümmern',
#   '.'],
#  ['Zeitgleich',
#   'kann',
#   'man',
#   'dann',
#   ',',
#   'ggf.',
#   'vergünstigt',
#   ',',
#   'eine',
#   'Beerdigung',
#   'in',
#   'der',
#   'Grabstätte',
#   'vereinbaren',
#   '.'],
#  ['Friedhöfe', 'in', 'Ordnung_halten', '.', '\n'],
#  ['Es',
#   'gibt',
#   'z._B.',
#   'in',
#   'vielen',
#   'Städten',
#   'der',
#   'USA',
#   '(',
#   'u._a.',
#   'NY',
#   ')',
#   'die',
#   'Möglichkeit',
#   'unter',
#   'Aufsicht',
#   'von',
#   'Gartenfachpersonal',
#   'Senioren',
#   'oder',
#   'sonstige',
#   'Bürger',
#   'mit',
#   'der',
#   'Zeit',
#   'und',
#   'Lust',
#   'dazu',
#   'die',
#   'jeweiligen',
#   'Friedhöfe',
#   'in',
#   'Ordnung',
#   'zu',
#   'halten',
#   '.'],
#  ['Die',
#   'Bürger',
#   'übernehmen',
#   'diese',
#   'Arbeit',
#   'und',
#   'halten',
#   'die',
#   'Anlagen',
#   'sauber',
#   ',',
#   'setzen',
#   'neue',
#   'Pflanzen',
#   'ein',
#   'usw.'],
#  ['Das',
#   'ganze',
#   'unter',
#   'der',
#   'Anweisung',
#   'und',
#   'Kontrolle',
#   'von',
#   'Fachpersonal',
#   '.',
#   '\n'],
#  ['Hier',
#   'werden',
#   'Personalkapazitäten',
#   'frei',
#   'gestellt',
#   'die',
#   'sich',
#   'dann',
#   'in',
#   'anderen',
#   'Bereichen',
#   'vermehrt',
#   'einbringen',
#   'können',
#   '.',
#   '\n'],
#  ['Je',
#   'nach',
#   'Ausweitung',
#   'kann',
#   'sogar',
#   'über',
#   'ein',
#   'Personalabbau',
#   'diskutiert',
#   'werden',
#   '.',
#   '\n'],
#  ['Diese',
#   'Einsätze',
#   'mit',
#   'Freiwilligen',
#   'können',
#   'auch',
#   'in',
#   'Parks',
#   'und',
#   'sonstigen',
#   'Grünflächen',
#   'im',
#   'geamten',
#   'Stadtbezirk',
#   'stattfinden',
#   '.'],
#  ['Verkehrs-', 'Umwelt-', 'und', 'Gesundheits-Konzept', '.', '\n'],
#  ['Vorschlag',
#   'für',
#   'das',
#   'Bonner',
#   'Verkehrs-',
#   'und',
#   'GesundheitskonzeptSehr',
#   'geehrte_Damen',
#   'und',
#   'Herren',
#   ',',
#   '\n',
#   'die',
#   'Feinstaub-Belastung',
#   'innerhalb',
#   'der',
#   'Stadt_Bonn',
#   'liegt',
#   'inzwischen',
#   'deutlich',
#   'über',
#   'den',
#   'gesundheitlich',
#   'unbedenklichen',
#   'Grenzwerten',
#   '.'],
#  ['Die',
#   'Entscheidungsträger',
#   'der',
#   'Stadt_Bonn',
#   'sind',
#   'zu',
#   'unverzüglichem',
#   'und',
#   'nachhaltigem',
#   'Handeln',
#   'gesetzlich',
#   ',',
#   'und',
#   'vor',
#   'allem',
#   'zum',
#   'Wohle',
#   'ihrer',
#   'Bürger',
#   ',',
#   'verpflichtet',
#   '!',
#   '\n'],
#  ['Der',
#   'motorisierte_Verkehr',
#   'ist',
#   'der',
#   'Hauptverursacher',
#   'für',
#   'die',
#   'Feinstaub-Belastung',
#   '.'],
#  ['Deshalb',
#   'ist',
#   'der',
#   'innerstädtische',
#   'motorisierte_Verkehr',
#   'nachhaltig',
#   'zu',
#   'reduzieren',
#   ',',
#   'zum',
#   'Gesundheitsschutz',
#   'der',
#   'Menschen',
#   'und',
#   'auch',
#   'um',
#   'zukünftige',
#   'PKW-Fahrverbote',
#   'zu',
#   'vermeiden',
#   '.',
#   '\n'],
#  ['Das_Konzept',
#   'für',
#   'die',
#   'Mobile-Stadt-Bonn',
#   'ist',
#   'aufkommensneutral',
#   'und',
#   'mit',
#   'folgenden',
#   'Maßnahmen',
#   'gesundheitsorientiert',
#   ',',
#   'zukunftsweisend',
#   ',',
#   'nachhaltig',
#   ',',
#   'einfach',
#   ',',
#   'transparent',
#   'für',
#   'alle',
#   'Bürger',
#   'und',
#   'Gäste',
#   'der',
#   'Stadt_Bonn',
#   'zu',
#   'gestalten',
#   ':'],
#  ['Verkehr', 'Innenstadt', '\n'],
#  ['Die',
#   'Geschwindigkeit',
#   'in',
#   'der',
#   'Innenstadt',
#   'beträgt',
#   '30_km/h',
#   '.',
#   '\n'],
#  ['Verkehrsschilder',
#   'in',
#   'der',
#   'Bonner_Innenstadt',
#   'entfallen',
#   ',',
#   'es',
#   'gilt',
#   '„',
#   'rechts_vor_links',
#   '“',
#   '!',
#   '(',
#   'Kostenreduzierung',
#   'und',
#   'Einsparpotential',
#   'auch',
#   'in',
#   'den',
#   'Außenbezirken)Die'],
#  ['Parkgebühren',
#   'werden',
#   'für',
#   'PKW',
#   'in',
#   'der',
#   'Zeit',
#   'von',
#   '8.00',
#   'bis',
#   '19.00',
#   'Uhr',
#   'deutlich',
#   'angehoben',
#   'und',
#   'stehen',
#   'der',
#   'Stadt',
#   'zur',
#   'Kompensation',
#   'des',
#   'ÖPNV',
#   'in',
#   'BONN',
#   'zur',
#   'Verfügung',
#   ':',
#   '\n'],
#  ['1'],
#  ['.', '\t'],
#  ['Stunde', '5'],
#  ['€', '\n'],
#  ['2'],
#  ['.', '\t'],
#  ['Stunde', '4'],
#  ['€', '\n'],
#  ['3'],
#  ['.', '\t'],
#  ['Stunde', '3'],
#  ['€', '\n'],
#  ['4'],
#  ['.', '\t'],
#  ['Stunde', '2'],
#  ['€', '\n'],
#  ['5'],
#  ['.', '\t'],
#  ['Stunde_1', '€'],
#  ['(', '5_Stunden', '='],
#  ['15_€', 'Parkgebühr', ')', '\n'],
#  ['6'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['7'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['8'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['9'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['10'],
#  ['.', '\t'],
#  ['Stunde_1',
#   '€',
#   '(',
#   '10-',
#   '24_Stunden',
#   'maximale',
#   'Parkgebühr',
#   '20_€',
#   ')'],
#  ['Die', 'Parkgebühr', 'in', 'den', 'Außenbezirken', 'beträgt', '\n'],
#  ['1'],
#  ['.', '\t', 'Stunde', '3'],
#  ['€', '\n'],
#  ['2'],
#  ['.', '\t'],
#  ['Stunde', '2'],
#  ['€', '\n'],
#  ['3'],
#  ['.', '\t'],
#  ['Stunde', '2'],
#  ['€', '\n'],
#  ['4'],
#  ['.', '\t'],
#  ['Stunde', '2'],
#  ['€', '\n'],
#  ['5'],
#  ['.', '\t'],
#  ['Stunde_1', '€'],
#  ['(', '5_Stunden', '='],
#  ['10_€', 'Parkgebühr', ')', '\n'],
#  ['6'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['7'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['8'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['9'],
#  ['.', '\t'],
#  ['Stunde_1'],
#  ['€', '\n'],
#  ['10'],
#  ['.', '\t'],
#  ['Stunde_1', '€', '(', '10-', '24_Stunden', 'maximale', 'Parkgebühr'],
#  ['15_€', ')'],
#  ['Ab',
#   '19.00',
#   'bis',
#   '24.00',
#   'Uhr',
#   'beträgt',
#   'die',
#   'Parkgebühr',
#   '1_€',
#   'pro_Stunde',
#   '.'],
#  ['ÖPNV', '\n'],
#  ['Die',
#   'Fahrt',
#   'mit',
#   'Bussen_und_Bahnen',
#   'innerhalb',
#   'der',
#   'Stadt_Bonn',
#   'kostet',
#   'pro',
#   'Fahrgast',
#   '1_€',
#   '.',
#   '\n'],
#  ['Jeder',
#   'Fahrgast',
#   ',',
#   'egal',
#   'ob',
#   'Kind',
#   ',',
#   'Erwachsener',
#   'oder',
#   'älterer',
#   'Mensch',
#   'zahlt',
#   'pro_Fahrt',
#   'einen',
#   'Euro',
#   '.',
#   '\n'],
#  ['(',
#   'Ausgaben-Steigerung',
#   ',',
#   'die',
#   'durch',
#   'Kostenreduzierung',
#   'und',
#   'Erhöhung_der_Parkgebühren',
#   'kompensiert'],
#  ['wird)Die',
#   'Stadt_Bonn',
#   'veranstaltet',
#   'an',
#   '4',
#   '(',
#   'vier',
#   ')',
#   'Tagen',
#   'pro_Jahr',
#   'einen',
#   'Auto-freien-Sonntag',
#   '.',
#   '\n'],
#  ['Beispiel'],
#  [':',
#   'Motto_"',
#   'Autofreie',
#   'Reuterstraße',
#   '"',
#   'oder',
#   '"',
#   'Autofreie',
#   'City',
#   '"',
#   '.',
#   '\n'],
#  ['Autofahrer',
#   'und',
#   'andere',
#   'Verkehrsteilnehmer',
#   'haben',
#   'dadurch',
#   'die',
#   'Gelegenheit',
#   'mit',
#   'den',
#   'Anwohnern',
#   'zu',
#   'reden',
#   '...',
#   'und',
#   'zu',
#   'feiern',
#   '.'],
#  ['Die',
#   'Vorschläge',
#   'haben',
#   'zum',
#   'Ziel',
#   ',',
#   'den',
#   'motorisierten_Verkehr',
#   'in',
#   'der',
#   'City',
#   'und',
#   'in',
#   'den',
#   'Außenbezirken',
#   'zu',
#   'reduzieren',
#   'und',
#   'Fußgänger',
#   'und',
#   'FahrradfahrerInnen',
#   'zu',
#   'gleichberechtigten',
#   'Verkehrsteilnehmern',
#   'zu',
#   'machen',
#   '.',
#   '\n'],
#  ['Die', 'Feinstaub-Belastung', 'in', 'Bonn', 'wird', 'reduziert', '.', '\n'],
#  ['Das',
#   'drohende',
#   'Fahrverbot',
#   'für',
#   'den',
#   'motorisierten_Verkehr',
#   'wird',
#   'durch',
#   'die',
#   'vorgeschlagenen',
#   'Maßnahmen',
#   'vermieden',
#   '.'],
#  ['Anmerkung_:', '\n'],
#  ['Die',
#   'Parkgebühren',
#   'in',
#   'Städten',
#   'wie',
#   'Utrecht',
#   'und',
#   'Rotterdam',
#   'sind',
#   'deutlich_höher',
#   'als',
#   'die',
#   'hier',
#   'für',
#   'Bonn',
#   'vorgeschlagenen',
#   '.',
#   '\n'],
#  ['Zum', 'ÖPNV'],
#  [':'],
#  ['In',
#   'Graz',
#   'ist',
#   'die',
#   'Benutzung',
#   'des',
#   'innerstädtischen',
#   'ÖPNV',
#   'für',
#   'alle',
#   'Bürger',
#   'und',
#   'Gäste',
#   'der',
#   'Stadt',
#   'Graz',
#   'gratis',
#   '!'],
#  ['Weihnachtsbaumabholung', 'durch', 'Bonn_Orange', 'einstellen', '.', '\n'],
#  ['Die', 'zweitägige', 'Weihnachtsbaumabholung', 'durch', 'Bonn'],
#  ['Orange', 'sollte', 'zur', 'Kosteneinsparung', 'eingestellt', 'werden', '.'],
#  ['Bürgerin',
#   'und',
#   'Bürger',
#   'haben',
#   'durch',
#   'Biotonne',
#   'und',
#   'in',
#   'den',
#   'Stadtteilen',
#   'vorhandene',
#   'Abgabemöglichkeiten',
#   'an',
#   'Friedhöfen',
#   'die',
#   'Möglichkeit',
#   'den',
#   'selbst',
#   'gekauften',
#   'Baum',
#   'auch',
#   'kostenfrei',
#   'selbst',
#   'zu',
#   'entsorgen',
#   '.'],
#  ['Wer',
#   'aus',
#   'unterschiedlichen',
#   'Gründen',
#   'dazu',
#   'nicht',
#   'in',
#   'der',
#   'Lage',
#   'sein',
#   'sollte',
#   ',',
#   'der',
#   'sollte',
#   'Freunde',
#   'und',
#   'Bekannte',
#   ',',
#   'Hausmitbewohner',
#   'etc.',
#   'für',
#   'Hilfe',
#   'ansprechen',
#   ',',
#   'was',
#   'vielleicht',
#   'auch',
#   'das',
#   'soziale_Miteinander',
#   'fördern',
#   'könnte',
#   '.'],
#  ['Wer',
#   'die',
#   'kostenfreie',
#   'Hundekotbeutelabgabe',
#   'abschafft',
#   ',',
#   'sollte',
#   'auch',
#   'über',
#   'eine',
#   'solche',
#   'Maßnahme',
#   'nachdenken',
#   '.'],
#  ['Alternative',
#   'Nutzung',
#   'für',
#   'leer_stehende',
#   'Pützchens_Markt',
#   'Wiese',
#   '.',
#   '\n'],
#  ['Die',
#   'Veranstaltungsfläche',
#   '"',
#   'Pütchens',
#   'Markt',
#   '"',
#   'ist',
#   'ca.',
#   '80.000',
#   'qm2',
#   'groß',
#   '.'],
#  ['Sie',
#   'wird',
#   'aktuell',
#   '1x',
#   'im',
#   'Jahr',
#   'für',
#   'die',
#   '5-tägige',
#   'Kirmes',
#   'Pützchens_Markt',
#   'genutzt',
#   '.'],
#  ['Mit',
#   'Auf-',
#   'und',
#   'Abbauzeiten',
#   'der',
#   'Buden',
#   'und',
#   'Fahrgeschäfte',
#   ',',
#   'wird',
#   'der',
#   'Platz',
#   'ca._3',
#   'Wochen',
#   'im',
#   'Jahr',
#   'genutzt',
#   'und',
#   'ist',
#   'damit',
#   'fast',
#   'das',
#   'ganze',
#   'Jahr',
#   'ungenutzt',
#   '.',
#   '\n'],
#  ['In',
#   'dieser',
#   'Zeit',
#   'könnten',
#   'hier',
#   'mit',
#   'anderen',
#   'Veranstaltungen',
#   'oder',
#   'alternativen',
#   'Angeboten',
#   'für',
#   'Bürger',
#   'Einnahmen',
#   'durch',
#   'Miete',
#   'o.ä.',
#   'erzielt',
#   'werden',
#   '.'],
#  ['Da',
#   'die',
#   'Marktwiese',
#   'in',
#   'einem',
#   'Wohngebiet',
#   'liegt',
#   ',',
#   'sind',
#   'Veranstaltungen',
#   'mit',
#   'einem',
#   'höherem',
#   'Lärmpegel',
#   'nach',
#   '22:00_Uhr',
#   'nicht',
#   'möglich',
#   ',',
#   'aber',
#   'ein',
#   'Wochenmarkt',
#   ',',
#   'Ausstellungen',
#   ',',
#   'Kinderpuppentheater',
#   '…'],
#  ['..', 'könnten', 'dort', 'gastieren', '.', '\n'],
#  ['Eine',
#   'ähnliche',
#   'Anfrage',
#   'wurde',
#   'schon',
#   '2011',
#   'an',
#   'die',
#   'Verwaltung',
#   'gerichtet',
#   '.'],
#  ['Damals',
#   'lautete',
#   'die',
#   'Antwort',
#   ':',
#   ' ',
#   '"',
#   'über',
#   'die',
#   'Flächennutzung',
#   'Pützchens_Markt',
#   'kann',
#   'die',
#   'Verwaltung',
#   'nicht',
#   'selbst',
#   'entscheiden',
#   '.'],
#  ['Für',
#   'Veranstaltungen',
#   'auf',
#   'dem',
#   'Marktgelände',
#   'müsste',
#   'die',
#   'Bezirksvertretung_Beuel',
#   'im',
#   'Rahmen',
#   'des',
#   'Marktverzeichnisses',
#   'gemäß_§',
#   '7',
#   'Abs._2',
#   'Buchst',
#   '.'],
#  ['r',
#   'der',
#   'Bezirkssatzung',
#   'einen',
#   'grundsätzlichen',
#   'Beschluss',
#   'fassen',
#   '.'],
#  ['Die',
#   'hatte',
#   'aber',
#   'bereits',
#   'vor',
#   'vielen',
#   'Jahren',
#   'die',
#   'Verwaltung',
#   'ausdrücklich',
#   'aufgefordert',
#   ',',
#   'auf',
#   'dem',
#   'Marktgelände',
#   'außer',
#   'dem',
#   'Jahrmarkt',
#   'Pützchen',
#   'und',
#   'einer',
#   'weiteren',
#   'Stadtteilbezogenen',
#   'Brauchtumsveranstaltung',
#   'keine',
#   'weiteren',
#   'Aktivitäten',
#   'zuzulassen',
#   '.'],
#  ['Hintergrund',
#   'ist',
#   ',',
#   'dass',
#   'so',
#   'die',
#   'Beeinträchtigungen',
#   'für',
#   'die',
#   'Anwohner',
#   '(',
#   'Lärmbelästigungen',
#   ',',
#   'erhöhtes',
#   'Fahrzeugaufkommen',
#   ')',
#   'auf',
#   'ein',
#   'Mindestmaß',
#   'reduziert',
#   'werden',
#   'sollen',
#   '.'],
#  ['Aus_diesem_Grund',
#   'und',
#   'zur',
#   'Vermeidung',
#   'von',
#   'Präzedenzfällen',
#   'sind',
#   'auch',
#   'schon',
#   '„',
#   'ruhigere',
#   '“',
#   'Veranstaltungen',
#   'wie',
#   'z._B.',
#   'die',
#   'Immobilientage',
#   'nicht',
#   'befürwortet',
#   'worden."Hierzu',
#   'ein',
#   'paar',
#   'Anmerkungen_:',
#   '\n'],
#  ['Wenn',
#   'bereits',
#   '2011',
#   'die',
#   'Rede',
#   'davon',
#   'war',
#   ',',
#   'dass',
#   '"',
#   'vor',
#   'vielen',
#   'Jahren',
#   '"',
#   'geäußert',
#   'wurde',
#   ',',
#   'dass',
#   'man',
#   'keine',
#   'weiteren',
#   'Veranstaltungen',
#   'auf',
#   'der',
#   'Wiese',
#   'möchte',
#   ',',
#   'macht',
#   'es',
#   'm.E.',
#   'Sinn',
#   ',',
#   'zu',
#   'prüfen',
#   ',',
#   'ob',
#   'das',
#   'heute',
#   'immer',
#   'noch',
#   'so',
#   'gesehen',
#   'wird',
#   '.'],
#  ['Immerhin',
#   'hat',
#   'sich',
#   'die',
#   'Situation',
#   'seit',
#   'dem',
#   'deutlich',
#   'verändert',
#   '.'],
#  ['In_Anbetracht',
#   'der',
#   'aktuellen',
#   'Haushaltssituation',
#   'der',
#   'Stadt_Bonn',
#   ',',
#   'und',
#   'den',
#   'starken',
#   'Einschnitten',
#   '(',
#   'Bibliothek',
#   ',',
#   'Schwimmbad',
#   ')',
#   ',',
#   'den',
#   'Pützchens',
#   'Anwohner',
#   'dadurch',
#   'schon',
#   'tragen',
#   'mussten',
#   ',',
#   'steht',
#   'die',
#   'Bezirksvertretung_Beuel',
#   'm',
#   '.'],
#  ['E',
#   'in',
#   'der',
#   'Pflicht',
#   ',',
#   'hier',
#   'im',
#   'Sinne',
#   'der',
#   'Anwohner',
#   'auch',
#   'neue',
#   'Angebote',
#   'wieder',
#   'zuzulassen',
#   '.',
#   '\n'],
#  ['In',
#   'Pützchen',
#   'entsteht',
#   'zudem',
#   'eine',
#   'Neubau-Siedlung',
#   'nach',
#   'der',
#   'anderen',
#   '.'],
#  ['Es', 'gibt', 'viel', 'Zuzug'],
#  ['v.a.', 'von', 'Familien_mit_Kindern', '.'],
#  ['Öffentliche', 'Spielplätze', 'sind', 'aber', 'rar', '.'],
#  ['Eine',
#   'Eisdiele',
#   'gibt',
#   'es',
#   'erst',
#   'seit',
#   'diesem',
#   'Sommer',
#   'im',
#   'Stadtteil',
#   'Pützchen',
#   ',',
#   'diese',
#   'aber',
#   'an',
#   'einer',
#   'sehr',
#   'stark_befahrenen',
#   'Kreuzung',
#   'an',
#   'der',
#   'Pützchens_Chaussee',
#   ',',
#   'mit',
#   'Kleinkindern',
#   'also',
#   'suboptimal',
#   '.',
#   '\n'],
#  ['Für',
#   'die',
#   'Wiese',
#   'steht',
#   'zudem',
#   'nicht',
#   'nur',
#   'die',
#   'eine',
#   'Option',
#   '(',
#   'laute',
#   'oder',
#   'weniger',
#   'laute',
#   'Veranstaltungen',
#   ')',
#   'im',
#   'Raum',
#   '.'],
#  ['Das',
#   'frei',
#   'stehende',
#   'Gelände',
#   'kann',
#   'auch',
#   'für',
#   'Angebote',
#   ',',
#   'die',
#   'den',
#   'Stadtteil',
#   'für',
#   'die',
#   'Anwohner',
#   'attraktiver',
#   'machen',
#   'genutzt',
#   'werden',
#   '.'],
#  ['Dies',
#   'hat',
#   'den',
#   'Vorteil',
#   ',',
#   'dass',
#   'die',
#   'befürchtenden',
#   'LKW-Trosse',
#   'und',
#   'tausende',
#   'von',
#   'Besuchern',
#   'ausbleiben',
#   ',',
#   'die',
#   'Anwohner',
#   'also',
#   'nicht',
#   'weiter',
#   'belästig',
#   'werden',
#   ',',
#   'sondern',
#   'die',
#   'Anwohner',
#   'selbst',
#   'die',
#   'Nutzer',
#   'der',
#   'Marktwiese',
#   'sind',
#   '.'],
#  ['Im_Sommer',
#   'würde',
#   'beispielweise',
#   'eine',
#   'Eiscafe/Eisdiele',
#   'hier',
#   'großen',
#   'Zulauf',
#   'finden',
#   '.'],
#  ['Ein',
#   'Café',
#   ',',
#   'mit',
#   'der',
#   'Möglichkeit',
#   ',',
#   'im',
#   'Sommer',
#   'auch',
#   'draußen',
#   'zu',
#   'sitzen',
#   'gibt',
#   'es',
#   'in',
#   'Pütchen',
#   'aktuell',
#   'nicht',
#   'nicht',
#   '.'],
#  ['Hierfür',
#   'gibt',
#   'es',
#   'auch',
#   'mobile',
#   'Konzepte',
#   ',',
#   'so',
#   'dass',
#   'die',
#   'Wiese',
#   'auch',
#   'wieder',
#   'für',
#   'Pützchens_Markt',
#   'im',
#   'Herbst',
#   'frei',
#   'zur',
#   'Verfügung_steht',
#   '.'],
#  ['Auch',
#   'andere',
#   'Möglichkeiten',
#   ',',
#   'wie',
#   'ein',
#   'Wochenmarkt',
#   ',',
#   'Spiel-',
#   'und',
#   'Turngeräte',
#   'für',
#   'Kinder',
#   ',',
#   'Ruhebänke',
#   'für',
#   'Senioren',
#   '(',
#   'unweit',
#   'ist',
#   'ein',
#   'Altersheim',
#   ')',
#   ',',
#   '…',
#   '.könnten',
#   'so',
#   'angebracht',
#   'werden',
#   ',',
#   'dass',
#   'man',
#   'die',
#   'Wiese',
#   'für',
#   'Pützchens_Markt',
#   'wieder',
#   'räumen',
#   'kann',
#   '.',
#   '\n'],
#  ['Eine',
#   'ergebnisoffene',
#   'Diskussion',
#   'wird',
#   'hier',
#   'bestimmt',
#   'noch',
#   'viele',
#   'weitere',
#   'Nutzungs-',
#   'und',
#   'damit',
#   'Einnahmepotentiale',
#   'zu',
#   'Tage',
#   'fördern',
#   ',',
#   'als',
#   'ich',
#   'hier',
#   'auf',
#   'die',
#   'Schnelle',
#   'angebracht',
#   'habe',
#   '.'],
#  ['Mehr_Lebensqualität',
#   'bei',
#   'gleichzeitigem',
#   'EinnahmeplusPützchen',
#   'musste',
#   'in',
#   'der',
#   'letzten',
#   'Einsparrunde',
#   'der',
#   'Stadt_Bonn',
#   'starke',
#   'Einschnitte',
#   'hinnehmen',
#   ',',
#   'die',
#   'die',
#   'Lebensqualität',
#   'des',
#   'Stadtteils',
#   'negativ',
#   'beeinträchtigen',
#   '.'],
#  ['So',
#   'wurde',
#   'z.B.',
#   'Die',
#   'Stadtteilbibliothek',
#   'komplett',
#   'geschlossen',
#   '.'],
#  ['Das',
#   'Schwimmbad',
#   'sollte',
#   'erst',
#   'auch',
#   'geschlossen',
#   'werden',
#   ',',
#   'wurde',
#   'dann',
#   'aber',
#   'mit',
#   'verkürzten',
#   'Öffnungszeiten',
#   'doch',
#   'wieder',
#   'eröffnet',
#   '.',
#   '\n'],
#  ['Mit',
#   'alternativen',
#   'Nutzungen',
#   'der',
#   'Marktwiese',
#   'kann',
#   'für',
#   'die',
#   'Anwohner',
#   'wieder',
#   'ein',
#   'besseres',
#   'Angebot',
#   'im',
#   'Stadtteil',
#   'geschaffen',
#   'werden',
#   'bei',
#   'gleichzeitiger',
#   'Erhöhung_der_Einnahmen',
#   'aus',
#   'der',
#   'brach',
#   'liegenden',
#   'Wiese',
#   '.'],
#  ['Es',
#   'wäre',
#   'zu',
#   'schade',
#   ',',
#   'wenn',
#   'die',
#   'Stadt_Bonn',
#   'aufgrund',
#   'eines',
#   'vor',
#   'vielen',
#   'Jahren',
#   'von',
#   'der',
#   'Bezirksvertretung',
#   'Beul',
#   'gefassten',
#   'Entschlusses',
#   ',',
#   'hier',
#   'Potentiale',
#   'ungenutzt',
#   'lassen',
#   'würde',
#   '.'],
#  ['Mehr', 'Geld', 'für', 'den', 'ÖPNV', '.', '\n'],
#  ['Seit',
#   'vielen',
#   'Jahren',
#   'sind',
#   'die',
#   'Aufwendungen',
#   'für',
#   'den',
#   'ÖPNV',
#   'nicht',
#   'mehr',
#   'gestiegen',
#   '-',
#   'im',
#   'Gegensatz',
#   'zu',
#   'anderen',
#   'Bereichen',
#   '.',
#   '\n'],
#  ['Dies_führt',
#   'dazu',
#   ',',
#   'dass',
#   'mittlerweile',
#   'dringend_benötigte',
#   'Verbesserungen',
#   'nicht',
#   'umgesetzt',
#   'werden',
#   'können',
#   ',',
#   'z.B.',
#   'Taktverdichtungen',
#   'auf',
#   'überfüllten',
#   'Linien',
#   ',',
#   'Verbesserung',
#   'der',
#   'Pünktlichkeit',
#   'durch',
#   'realistische',
#   'Fahr-',
#   'und',
#   'Wendezeiten',
#   '(',
#   'erfordert',
#   'mehr',
#   'Fahrzeuge',
#   '...',
#   ')',
#   'usw',
#   '.'],
#  ['Die',
#   'Erhöhung',
#   'muss',
#   'mindestens',
#   'die',
#   'Benachteiligung',
#   'in',
#   'den',
#   'letzten_Jahren',
#   'gegenüber',
#   'dem',
#   'Theater',
#   'ausgleichen',
#   '.'],
#  ['Gelbe_Säcke', '.', '\n'],
#  ['Die',
#   'Bestellung',
#   'der',
#   'Gelbe_Säcke',
#   'funktioniert',
#   'schlecht',
#   'und',
#   'es',
#   'ist',
#   'nie',
#   'nach',
#   'zu',
#   'vollziehen',
#   ',',
#   'wieviele',
#   'Wochen',
#   'nach',
#   'einer',
#   'Bestellung',
#   'vergehen',
#   'bis',
#   'dann',
#   'die',
#   'bestellten',
#   'Säcke',
#   'schliesslich',
#   'geliefert',
#   'werden',
#   '.'],
#  ['Zudem',
#   'werden',
#   'zu',
#   'jeder',
#   'Bestellung',
#   'max.',
#   '2',
#   'Rollen',
#   'mit',
#   'Gelben',
#   'Säcken',
#   'geliefert',
#   '-',
#   'völlig',
#   'unabhängig',
#   'davon',
#   ',',
#   'ob',
#   'ich',
#   'mehr',
#   'bestellt',
#   'habe',
#   '.',
#   '\n'],
#  ['Die',
#   'letzte',
#   'Lieferung',
#   'wurde',
#   'uns',
#   'an',
#   'einem',
#   'Samstag',
#   'einfach',
#   'vor',
#   'die',
#   'Haustür',
#   'gestellt',
#   ',',
#   'mit',
#   'dem',
#   'Effekt',
#   ',',
#   'dass',
#   'wir',
#   'nur',
#   'noch',
#   'eine',
#   'Rolle',
#   'vorgefunden',
#   'haben',
#   '....'],
#  ['Dieses_System',
#   'sollte',
#   'überarbeitet',
#   'und',
#   'effizienter',
#   'gestaltet',
#   'werden',
#   '.'],
#  ['Zudem',
#   'sollte',
#   'es',
#   'für',
#   'mich',
#   'als',
#   'Kundin',
#   'ersichtlich',
#   'sein',
#   ',',
#   'wann',
#   'diese',
#   'Gelben',
#   'Säcke',
#   'geliefert',
#   'werden',
#   '.'],
#  ['Was', 'hat', 'dieser', 'Vorschlag', 'mit', '.', '\n'],
#  ['Was',
#   'hat',
#   'dieser',
#   'Vorschlag',
#   'mit',
#   'dem',
#   'Bonner_Haushalt',
#   'zu',
#   'tun',
#   '?'],
#  ['Reitwege', 'im', 'Gebiet', 'Vinxel'],
#  ['/'],
#  ['Niederholtdorf/'],
#  ['Paffelsberg', '.', '\n'],
#  ['Die', 'Reitwege', 'im', 'Gebiet', 'Vinxel', '/', 'Niederholtdorf/'],
#  ['Paffelsberg',
#   'sind',
#   'in',
#   'sehr',
#   'schlechtem_Zustand',
#   'oder',
#   'auch',
#   'komplett',
#   'verschwunden',
#   'und',
#   'zugewuchert',
#   '.'],
#  ['Hier_besteht', 'dringend_Handlungsbedarf', '.'],
#  ['Auf',
#   'Nachfrage',
#   'bei',
#   'der',
#   'Stadt_Bonn',
#   'wurde',
#   'mitgeteilt',
#   ',',
#   'dass',
#   'die',
#   'Reitwege',
#   'ausschließlich',
#   'über',
#   'die',
#   'von',
#   'Reitern',
#   'zu',
#   'erwerbende',
#   'Plakette',
#   'finanziert',
#   'werden',
#   '.'],
#  ['Dieses_Geld',
#   'reiche',
#   'aber',
#   'nicht',
#   'aus',
#   'um',
#   'alle',
#   'Reitwege',
#   'der',
#   'Stadt_Bonn',
#   'in',
#   'einem',
#   'bereitbaren',
#   'Zustand',
#   'zu',
#   'erhalten',
#   '.',
#   '\n'],
#  ['Mein_Vorschlag',
#   'ist',
#   ':',
#   'hier',
#   'aus',
#   'Steuergeldern',
#   'zu',
#   'bezuschussen',
#   '.'],
#  ['Radfahrer',
#   'müssen',
#   'ja',
#   'auch',
#   'keine',
#   'Plakette',
#   'kaufen',
#   'und',
#   'die',
#   'Stadt',
#   'baut',
#   'und',
#   'unterhält',
#   'trotzdem',
#   'die',
#   'Fahrradwege',
#   '!'],
#  ['Sparen', '.', '\n'],
#  ['Es',
#   'könnten',
#   'sehr',
#   'viele',
#   'Ampeln',
#   'von',
#   '22',
#   'bis',
#   '6',
#   'ausgeschaltet',
#   'werden',
#   ',',
#   'aufgrund',
#   'des',
#   'nicht',
#   'vorhanden',
#   'Verkehrs',
#   '.'],
#  ['Die',
#   'Oper',
#   'braucht',
#   'kein',
#   'Mensch',
#   ',',
#   'die',
#   'kostet',
#   'nur',
#   'Geld',
#   'und',
#   'ist',
#   'nie',
#   'ausverkauft',
#   '.'],
#  ['Und',
#   'das',
#   'gesparte_Geld',
#   'könnte',
#   'man',
#   'gut',
#   'in',
#   'die',
#   'Straßen',
#   'investieren',
#   'und',
#   'die',
#   'Asphaltdecke',
#   'erneuern',
#   '.'],
#  ['Fahrradzaehlung', '.', '\n'],
#  ['Ist', 'eine', 'elektronische', 'Zählung', 'tatsächlich', 'nötig', '?'],
#  ['Welchen', 'Nutzen', 'hat', 'der', 'Bonner_Bürger', 'davon', '?'],
#  ['Bei', 'schoenem', 'Wetter', 'fahren', 'mehr', 'Bürger', 'Fahrrad', '?'],
#  ['Was', 'bitte', 'soll', 'das'],
#  ['?'],
#  ['?'],
#  ['?'],
#  ['Anreizsystem', 'für', 'Übernahme_von_Grünpatenschaften', '.', '\n'],
#  ['Die',
#   'Stadt_Bonn',
#   'bietet',
#   'schon',
#   'jetzt',
#   'die',
#   'Möglichkeit',
#   ',',
#   'Grünpatenschaften',
#   'zu',
#   'übernehmen',
#   '.'],
#  ['Laut',
#   'Auskunft',
#   'auf',
#   'auf',
#   'www.bonn.de',
#   'gibt',
#   'es',
#   'ca.',
#   '630',
#   'Patenschaften',
#   'von',
#   'Bürgern',
#   'für',
#   'Beete',
#   'im',
#   'öffentlichen_Raum',
#   '.'],
#  ['Dort', 'heißt', 'es', ':', '"'],
#  ['Dabei_handelt',
#   'es',
#   'sich',
#   'um',
#   'Baumbeete',
#   ',',
#   'Pflanzkübel',
#   'und',
#   'Grünflächen',
#   ',',
#   'die',
#   'teilweise',
#   'von',
#   'Vereinen',
#   ',',
#   'Straßengemeinschaften',
#   'oder',
#   'Schulen',
#   'angelegt',
#   ',',
#   'bepflanzt',
#   ',',
#   'gepflegt',
#   'und',
#   'unterhalten',
#   'werden',
#   '.'],
#  ['Damit',
#   'wird',
#   ',',
#   'sowohl',
#   'mit',
#   'Blick',
#   'auf',
#   'die',
#   'Pflanzen',
#   'aber',
#   'auch',
#   'auf',
#   'das',
#   'Erscheinungsbild',
#   'der',
#   'Stadt',
#   ',',
#   'ein',
#   'wichtiger',
#   'Beitrag',
#   'zum',
#   'Erhalt',
#   'der',
#   'biologischen_Vielfalt',
#   'geleistet',
#   '.',
#   '"'],
#  ['Da',
#   'es',
#   'nach',
#   'Auskunft',
#   'der',
#   'Seite',
#   'allein',
#   '34.000',
#   'Straßenbäume',
#   'gibt',
#   ',',
#   'erscheint',
#   'die',
#   'Zahl',
#   'von',
#   '630',
#   'Patenschaften',
#   'sehr',
#   'wenig',
#   '.'],
#  ['Zumal',
#   'es',
#   'eine',
#   'große',
#   'Menge',
#   'traurig',
#   'vor',
#   'sich',
#   'hinkümmernder',
#   'kleiner',
#   'und',
#   'größerer',
#   'Flächen',
#   'gibt',
#   ',',
#   'die',
#   'aus',
#   'Kostengründen',
#   'allenfalls',
#   'mit',
#   'Bodendeckern',
#   'bepflanzt',
#   'sind',
#   ',',
#   'in',
#   'denen',
#   'sich',
#   'der',
#   'Müll',
#   'verfängt',
#   '.'],
#  ['Dies_dürfte',
#   'sicher',
#   'auch',
#   'daran',
#   'liegen',
#   ',',
#   'dass',
#   'gar',
#   'nicht',
#   'jedem',
#   'bekannt',
#   'ist',
#   ',',
#   'dass',
#   'er',
#   'die',
#   'Patenschaft',
#   'für',
#   'ein',
#   'Beet',
#   'vor',
#   'seiner',
#   'Haustür',
#   'übernehmen',
#   'kann',
#   '.'],
#  ['Das',
#   'könnte',
#   'und',
#   'sollte',
#   'dadurch',
#   'geändert',
#   'werden',
#   ',',
#   'dass',
#   'ein',
#   'Anreizsystem',
#   'eingeführt',
#   'wird',
#   '(_z.',
#   'B.',
#   'jährliche',
#   'Preise',
#   'für',
#   'das',
#   'schönste',
#   'Straßenbeet',
#   ',',
#   'Möglichkeit',
#   ',',
#   'nach',
#   'dem',
#   'Muster',
#   'gespendeter',
#   'Parkbänke',
#   'kleine',
#   'Namensschilder',
#   'an',
#   'den',
#   'Beeten',
#   'anzubringen',
#   ')',
#   'und',
#   'offensiv',
#   'Informationen',
#   'an',
#   'potentiell',
#   'Interessierte',
#   'wie',
#   'z._B.',
#   'Schulen',
#   ',',
#   'Unternehmen',
#   ',',
#   'Einzelhandel',
#   ',',
#   'aber',
#   'auch',
#   'Privathaushalte',
#   '(_z.',
#   'B.',
#   'über',
#   'das',
#   '"',
#   'Schaufenster',
#   '"',
#   ')',
#   'gerichtet',
#   'werden',
#   '.'],
#  ['Ich_bin_überzeugt',
#   ',',
#   'dass',
#   'die',
#   'Möglichkeit',
#   ',',
#   'eine',
#   'Patenschaft',
#   'zu',
#   'übernehmen',
#   'und',
#   'diese',
#   'eventuell',
#   'sogar',
#   'durch',
#   'ein',
#   'Schild',
#   'sichtbar',
#   'zu',
#   'machen',
#   ',',
#   'auf',
#   'vielfältiges',
#   'Interesse',
#   'stoßen',
#   'würde',
#   '.'],
#  ['Der',
#   'öffentliche_Raum',
#   'würde',
#   'verschönert',
#   'und',
#   'der',
#   'Gemeinsinn',
#   'und',
#   'die',
#   'Wertschätzung',
#   'für',
#   'die',
#   'Flächen',
#   'außerhalb',
#   'des',
#   'eigenen',
#   'Balkons',
#   'oder',
#   'Vorgartens',
#   'gefördert',
#   '.'],
#  ['Ein',
#   'wichtiger',
#   'Nebeneffekt',
#   'wäre',
#   'auch',
#   'die',
#   'Einsparung',
#   'nicht',
#   'unerheblicher',
#   'Summen',
#   'an',
#   'öffentlichen_Geldern',
#   'für',
#   'den',
#   'erforderlichen',
#   'Pflegaufwand',
#   '.'],
#  ['Das_Amt',
#   'für',
#   'Stadtgrün',
#   'bewirbt',
#   'seit',
#   'vielen',
#   'Jahren',
#   'die',
#   'Möglichkeit',
#   'der',
#   'Übernahme_von_Grünpatenschaften',
#   '.'],
#  ['Insbesondere',
#   'mit',
#   'Verweis',
#   'auf',
#   'die',
#   'vielen',
#   'tausend',
#   'Bäume',
#   'ist',
#   'auch',
#   'unter',
#   'dem',
#   'Stichwort',
#   '„',
#   'Baumstarke',
#   'Stadt',
#   '“',
#   'eine',
#   'Kampagne',
#   'zur',
#   'Übernahme',
#   'von',
#   'Baumpatenschaften',
#   'gestartet',
#   'worden',
#   '.'],
#  ['Die', 'tatsächliche', 'Resonanz', 'war', 'leider', 'überschaubar', '.'],
#  ['Gleichwohl',
#   'fördert',
#   'das',
#   'Amt_für_Stadtgrün',
#   'interessierte',
#   'Bürgerinnen_und_Bürger',
#   ',',
#   'die',
#   'eine',
#   'Grünpatenschaft',
#   'übernehmen',
#   'wollen',
#   '.'],
#  ['Zusätzliche',
#   'Anreize',
#   'könnten',
#   'allerdings',
#   'lediglich',
#   'in',
#   'Form',
#   'einer',
#   'Würdigung',
#   'des',
#   'Engagements',
#   'bzw.',
#   'ggfls',
#   '.'],
#  ['durch',
#   'eine',
#   'Fotoausstellung',
#   'besonders',
#   'gepflegter',
#   'Beete',
#   'passieren',
#   '.'],
#  ['Weitere',
#   'Maßnahmen',
#   'würden',
#   'abhängig',
#   'von',
#   'der',
#   'Ausgestaltung',
#   'weitere',
#   'zur',
#   'Zeit',
#   'nicht',
#   'abschätzbare',
#   'Finanzmittel',
#   'erfordern',
#   '.'],
#  ['Die',
#   'Verwaltung',
#   'hält',
#   'die',
#   'o._g.',
#   'Maßnahmen',
#   'für',
#   'ausreichend',
#   ',',
#   'um',
#   'für',
#   'die',
#   'Übernahme_von_Grünpatenschaften',
#   'zu',
#   'werben',
#   '.'],
#  ['Durch',
#   'die',
#   'Vergabe',
#   'einzelner',
#   'Grünpatenschaften',
#   'ergibt',
#   'sich',
#   'keine',
#   'signifikante',
#   ',',
#   'finanzielle',
#   'Einsparung',
#   '.'],
#  ['Die',
#   'Übernahme_von_Grünpatenschaften',
#   'bedeutet',
#   'in',
#   'erster',
#   'Linie',
#   'eine',
#   'Aufwertung',
#   'der',
#   'Baumbeete',
#   'und',
#   'führt',
#   'auch',
#   'zu',
#   'einer',
#   'geringen',
#   'Entlastung',
#   'der',
#   'Bezirksgärtner',
#   '.'],
#  ['Der',
#   'Vorschlag',
#   'wird',
#   'einstimmig',
#   'bei',
#   'Enthaltung',
#   'BBB',
#   'wie',
#   'Änderungsantrag',
#   'angenommen',
#   '.'],
#  ['Der', 'Wortlaut', 'des', 'Antrages', 'lautet_:'],
#  ['Die',
#   'Verwaltung',
#   'organisiert',
#   'eine',
#   'Fotoausstellung',
#   'im',
#   'Foyer',
#   'des',
#   'Stadthauses',
#   'zu',
#   'Baumbeeten',
#   'im',
#   'Stadtgebiet',
#   'und',
#   'veröffentlicht',
#   'diese',
#   'entsprechend',
#   'im',
#   'Internet',
#   '.'],
#  ['Die',
#   'Bürgerinnen_und_Bürger',
#   'werden',
#   'aufgefordert',
#   ',',
#   'Fotos',
#   'einzuschicken',
#   ',',
#   'welche',
#   'später',
#   'anhand',
#   'verschiedener',
#   'Kategorien',
#   'bewertet',
#   'werden',
#   'können',
#   ',',
#   'wie',
#   'zum',
#   'Beispiel',
#   ':',
#   'das',
#   'schönste',
#   ',',
#   'das',
#   'ökologischste',
#   ',',
#   'das',
#   'gepflegteste',
#   'Baumbeet',
#   '.'],
#  ['Die',
#   'Verwaltung',
#   'verstärkt',
#   'ihre',
#   'Öffentlichkeitsarbeit',
#   'im',
#   'Hinblick',
#   'auf',
#   'die',
#   'Übernahme_von_Grünpatenschaften',
#   '.'],
#  ['Dies',
#   'soll',
#   'insbesondere',
#   'durch',
#   'mehr',
#   'Pressearbeit',
#   'sowie',
#   'Werbung',
#   'in',
#   'den',
#   'sozialen',
#   'Medien',
#   'und',
#   'direkt',
#   'an',
#   'den',
#   'Baumscheiben',
#   'geschehen',
#   '.'],
#  ['Aktuell',
#   'wird',
#   'vermehrt',
#   'Werbung',
#   'auf',
#   'www.bonn.de',
#   'geschaltet',
#   '(',
#   'letzte',
#   'Aktualisierung',
#   'August',
#   '2017',
#   ')',
#   '.'],
#  ['Sehr', 'schöne_Idee', '!', '.', '\n'],
#  ['Der',
#   'Vorschlag',
#   'würde',
#   'einen',
#   'allgemeinen',
#   'Mehrwert',
#   'stiften',
#   'und',
#   'der',
#   'Stadt',
#   'zugleich',
#   'Kosten_sparen',
#   '-',
#   'volle_Zustimmung',
#   '!'],
#  ['Wenn',
#   'Schulen',
#   'oder',
#   'Klassen',
#   'entsprechende',
#   'Patenschaften',
#   'übernehmen',
#   ',',
#   'könnte',
#   'man',
#   'auch',
#   'eine',
#   'Art',
#   '"',
#   'Schulwettbewerb',
#   '"',
#   '(',
#   'schulintern',
#   'oder',
#   'schulübergreifend',
#   ')',
#   'veranstalten',
#   ',',
#   'was',
#   'die',
#   'Kinder',
#   'zusätzlich',
#   'entsprechend',
#   'motivieren',
#   'würde',
#   '.'],
#  ['Verlängerung', 'der', 'Straßenbahn', '61', '62', 'bis', 'Godesberg'],
#  ['Nord', '.', '\n'],
#  ['In', 'Dottendorf', 'angekommen', ';'],
#  ['am', 'Ende', 'der', 'Stadt', '?'],
#  ['Nein', 'Bonn', 'geht', 'bis', 'Mehlem', '.'],
#  ['Eine_Verlängerung',
#   'ist',
#   'ein',
#   'wichtiges',
#   'Singnal',
#   'für',
#   'mehr',
#   'ÖPNV',
#   '.'],
#  ['Es',
#   'würde',
#   'Kosten_sparen',
#   'und',
#   'mehr',
#   'Menschen',
#   'in',
#   'deine',
#   'Srassenbahn',
#   'locken',
#   '.'],
#  ['Sollte', ',', 'vorausgesetzt', ',', 'Bonn', '.', '\n'],
#  ['Sollte',
#   ',',
#   'vorausgesetzt',
#   ',',
#   'Bonn',
#   'hätte',
#   'jemals',
#   'wieder',
#   'genug',
#   'Mittel',
#   ',',
#   'eine',
#   'Verlängerung',
#   'einer',
#   'S-Bahn',
#   'im',
#   'Bonner_Süden',
#   'jemals',
#   'angedacht',
#   'werden',
#   ',',
#   'wäre',
#   'es',
#   'die',
#   '16/63',
#   'in',
#   'Godesberg',
#   ',',
#   'die',
#   'schon',
#   'so',
#   'angelegt',
#   'ist',
#   ',',
#   'dass',
#   'sie',
#   'theoretisch',
#   'verlängert',
#   'werden',
#   'könnte',
#   '.'],
#  ['Aber',
#   'vermutlich',
#   'werden',
#   'wir',
#   'das',
#   'zu',
#   'unseren',
#   'Lebzeiten',
#   'nicht',
#   'mehr',
#   'erleben',
#   '...'],
#  ['Nord'],
#  ['?'],
#  ['.', '\n'],
#  ['Ich_dachte', ',', 'Mehlem', 'liegt', 'im', 'Süden', '.'],
#  ['Alles',
#   'dürfte',
#   'nicht',
#   'zu',
#   'haben',
#   'sein',
#   ',',
#   'da',
#   'es',
#   'zumindest',
#   'bis',
#   'zur',
#   'Stadthalle',
#   'geht',
#   '.'],
#  ['Und',
#   'es',
#   'muss',
#   'dann',
#   'nicht',
#   'über',
#   'Dottendorf',
#   'sein',
#   ',',
#   'so',
#   'schön',
#   'es',
#   'auch',
#   'wäre',
#   '.',
#   '\n'],
#  ['Eine_Verlängerung',
#   'von',
#   'der',
#   'Stadthalle',
#   'weiter',
#   'in',
#   'den',
#   'Süden',
#   'sichedrlich',
#   'sinnvoll',
#   'und',
#   'ein',
#   'Projekt',
#   'zur',
#   'Prüfung',
#   'ohe',
#   'Totschlagediskussion',
#   '.'],
#  ['SWB', 'Straßenbahnvorrang', 'an', 'Kreuzungen', '.', '\n'],
#  ['Beispiel',
#   'Linie',
#   '61',
#   ',',
#   '120',
#   'Fahrten',
#   'pro_Tag',
#   'und',
#   'Richtung',
#   ',',
#   'macht',
#   'bei',
#   'nur',
#   'einer',
#   'eingesparten',
#   'Minute/'],
#  ['Bahn'],
#  ['mindestens',
#   '29.200',
#   'EUR_/',
#   'Jahr',
#   'Einsparung',
#   'durch',
#   'Vorrangschaltung',
#   'an',
#   'allen',
#   'Kreuzungen',
#   '.'],
#  ['Klimastadt',
#   'Bonn',
#   'muß',
#   'hier',
#   'ÖPNV',
#   'fördern',
#   'und',
#   'Attraktivität',
#   'steigern',
#   ',',
#   'Lärm_und_Abgase',
#   'verringern',
#   ',',
#   'Leute',
#   'zum',
#   'Umsteigen',
#   'bewegen',
#   '.'],
#  ['Eingesparte', 'Kosten', 'in', 'den', 'Ausbau', 'und', 'höhere', 'Taktung'],
#  ['stecken!365', 'Tage', 'x'],
#  ['240', 'Fahrten', 'x'],
#  ['1', 'Minuten'],
#  ['='],
#  ['87.600', 'Minuten'],
#  ['='],
#  ['1.460', 'Stunden', 'x', '20', 'EUR'],
#  ['='],
#  ['29.200', 'EURBeispiel', 'Linie', '62', ':'],
#  ['ca', '30.000', 'EURBeispiel', 'Linie_66', ':', ' '],
#  ['60.000', 'EUR', '/Jahr', ','],
#  ['da',
#   'min',
#   '2',
#   '-',
#   '3_Minuten',
#   'Ersparnis/',
#   'FahrtGesamteinsparung',
#   'nur',
#   'durch',
#   'Vorrangschaltung',
#   ':'],
#  ['ca', '120.000', 'EUR_/', 'Jahr'],
#  ['Interessante_Idee', '.', '\n'],
#  ['Das', 'ist', 'mal', 'eine', 'innovative', 'Idee', '.'],
#  ['Ich',
#   'bin',
#   'nicht',
#   'ganz',
#   'überzeugt',
#   ',',
#   'ob',
#   'sie',
#   'wirklich',
#   'das',
#   'angenommene',
#   'Einsparpotential',
#   'hat',
#   ',',
#   'zumal',
#   'ja',
#   'zumindest',
#   'kurzfristig',
#   'mit',
#   'der',
#   'entsprechenden',
#   'Umstellung',
#   'der',
#   'gesamten',
#   'Ampelanlagen',
#   'einige',
#   'Kosten_entstehen',
#   'dürften',
#   '.'],
#  ['Aber',
#   'ich',
#   'würde',
#   'sehr',
#   'gerne',
#   'eine',
#   'Stellungnahme_der_Verwaltung',
#   'zu',
#   'dieser',
#   'Idee',
#   'sehen',
#   '.'],
#  ['Also', 'volle_Zustimmung', '!'],
#  ['ÖPNV'],
#  ['Vorrang', 'geben', '.', '\n'],
#  ['Dem', 'ÖPNV'],
#  ['Vorrang',
#   'einzuräumen',
#   'ist',
#   'sicherlich',
#   'eine',
#   'attraktive',
#   'Idee',
#   '.'],
#  ['Leider',
#   'fehlt',
#   'Bonn',
#   ',',
#   'im',
#   'Vergleich_zu_anderen_Großstädten',
#   ',',
#   'die',
# ...
#   "'",
#   'ist',
#   'vorgeschoben',
#   ',',
#   'da',
#   'die',
#   'derzeitigen',
#   'Gesamtschulen',
#   'eher',
#   'etwas',
#   'mehr',
#   'Schüler',
#   'aus',
#   'diesem',
#   'Drittel',
#   'aufnehmen',
#   '.'],
#  ['Zudem',
#   'wollen',
#   'immer',
#   'mehr',
#   'Eltern',
#   ',',
#   'dass',
#   'ihre',
#   'Kinder',
#   '9',
#   'Jahre',
#   'Zeit',
#   'haben',
#   ',',
#   'um',
#   'ggf.',
#   'das',
#   'Abitur',
#   'zu',
#   'erlangen',
#   '.'],
#  ['Mit',
#   'zumindest',
#   'einer',
#   'Klasse',
#   'im',
#   'Jahrgang',
#   '2018/19',
#   'könnte',
#   'also',
#   'in',
#   'jedem',
#   'Fall',
#   'begonnen',
#   'werden',
#   '.'],
#  ['Die',
#   'Verwaltung_empfiehlt',
#   ',',
#   'dem',
#   'Bürgervorschlag_nicht_zu_folgen',
#   '.'],
#  ['Die',
#   'Umwandlung',
#   'einer',
#   'Haupt-',
#   'und/oder',
#   'Realschule',
#   'im',
#   'Stadtbezirk_Hardtberg',
#   'in',
#   'eine',
#   '6',
#   '.',
#   'Bonner_Gesamtschule',
#   'hat',
#   'keine',
#   'unmittelbare',
#   'haushaltsrelevante',
#   'Auswirkung',
#   '.'],
#  ['Darüber_hinaus',
#   'besteht',
#   'aus',
#   'Sicht_der_Verwaltung',
#   'aktuell',
#   'keine',
#   'Notwendigkeit',
#   'zur',
#   'Einrichtung',
#   'einer',
#   '6',
#   '.',
#   'Bonner_Gesamtschule',
#   '.'],
#  ['In',
#   'der',
#   'Vergangenheit',
#   'wurde',
#   'bereits',
#   'wiederholt',
#   'geprüft',
#   ',',
#   'inwieweit',
#   'das',
#   'dafür',
#   'erforderliche',
#   'Schülerpotential',
#   'vorliegt',
#   ':'],
#  ['Tragendes',
#   'Element',
#   'eines',
#   'nachhaltig',
#   'funktionierenden',
#   'Gesamtschulsystems',
#   'ist',
#   'die',
#   'hinreichend',
#   'pädagogische',
#   'Leistungsmischung',
#   '.'],
#  ['Diese',
#   'notwendige',
#   'pädagogische',
#   'Leistungsmischung',
#   'für',
#   'die',
#   'Errichtung',
#   'einer',
#   'sechsten',
#   'Gesamtschule',
#   'ist',
#   'gegenwärtig',
#   'in',
#   'Bonn',
#   'nicht',
#   'darstellbar',
#   '.'],
#  ['Diese',
#   'Einschätzung',
#   'wird',
#   'übereinstimmend',
#   'auch',
#   'von',
#   'den',
#   'Schulleiterinnen',
#   'und',
#   'Schulleitern',
#   'der',
#   '5',
#   'Bonner',
#   'Gesamtschulen',
#   'geteilt',
#   ',',
#   'zumal',
#   'im',
#   'Endaus¬bau',
#   'am',
#   'Standort',
#   'von',
#   'Bonns',
#   'Fünfter',
#   ',',
#   'nach',
#   'Fertigstellung',
#   'des',
#   'Neubaus',
#   ',',
#   'zwei',
#   'weitere',
#   'Züge',
#   'vorgesehen',
#   'sind',
#   '.'],
#  ['Die',
#   'Errichtung',
#   'einer',
#   'weiteren',
#   'Gesamtschule',
#   'setzt',
#   '–',
#   'die',
#   'entsprechende',
#   'Zahl',
#   'von',
#   'mindestens',
#   '100',
#   'Anmeldungen',
#   'gem.',
#   '§',
#   '82',
#   'Abs._1',
#   'SchulG',
#   'NRW',
#   'unterstellt',
#   '–',
#   'bis',
#   'Klasse',
#   '10',
#   'mindestens',
#   '4',
#   'Parallelklassen',
#   'pro',
#   'Jahrgang',
#   'voraus',
#   '(',
#   '§',
#   '82',
#   'Abs.',
#   '7',
#   'SchulG',
#   'NRW',
#   ')',
#   '.'],
#  ['Eine',
#   'anderweitige',
#   '„',
#   'Verteilung',
#   '“',
#   'der',
#   'Schülerinnen_und_Schüler',
#   'im',
#   'Anmeldeverfahren',
#   'ist',
#   'dem',
#   'Einfluss',
#   'des',
#   'Schulträgers',
#   'entzogen',
#   '.'],
#  ['Über',
#   'die',
#   'Aufnahme',
#   'entscheidet',
#   'im',
#   'Rahmen',
#   'der',
#   'vom',
#   'Schulträger',
#   'festgelegten',
#   'Zügigkeiten',
#   'nach',
#   'den',
#   'Vorgaben',
#   'des',
#   'Schulgesetzes',
#   'NRW',
#   'grundsätzlich',
#   'allein',
#   'die',
#   'Schulleitung',
#   '.'],
#  ['Die',
#   'Verwaltung',
#   'sieht',
#   'derzeit',
#   'keine',
#   'Möglichkeit',
#   'der',
#   'Gründung',
#   'einer',
#   '6',
#   '.',
#   'Gesamtschule',
#   'in',
#   'Bonn',
#   '.'],
#  ['In_diesem_Zusammenhang',
#   'wird',
#   'auch',
#   'auf',
#   'die',
#   'Drucksachen-Nummer',
#   '1411996ST2',
#   'verwiesen',
#   '.'],
#  ['Der',
#   'Vorschlag_wurde_mit_Mehrheit',
#   'gegen',
#   'Linke',
#   'und',
#   'Sozial',
#   'Liberalen',
#   'bei',
#   'Enth',
#   '.'],
#  ['SPD', 'abgelehnt', '.'],
#  ['Kostenobergrenze', 'für', 'Sanierung_der_Beethovenhalle', '.', '\n'],
#  ['Sofortige',
#   'Festlegung',
#   'einer',
#   'verbindlichen',
#   'Kostenobergrenze',
#   'der',
#   'Sanierungskosten',
#   'für',
#   'die',
#   'Beethovenhalle',
#   'gemäß',
#   'der',
#   'Kosten',
#   ',',
#   'auf',
#   'deren',
#   'Basis',
#   'ie',
#   'Sanierung',
#   'ursprünglich',
#   'beschlossen',
#   'wurde',
#   '.'],
#  ['Sollten',
#   'die',
#   'Kosten',
#   'darüber',
#   'steigen',
#   ',',
#   'sind',
#   'optionale',
#   'Sanierungsmodule',
#   'wieder',
#   'zu',
#   'streichen',
#   'oder',
#   'erneut',
#   'über',
#   'die',
#   'Sanierung',
#   'zu',
#   'entscheiden',
#   '.'],
#  ['Aus',
#   'Sicht_der_Verwaltung',
#   'wird',
#   'dem',
#   'Vorschlag',
#   'bereits',
#   'ohne',
#   'weitergehenden',
#   'Beschluss',
#   'faktisch',
#   'Rechnung_getragen',
#   '.'],
#  ['Der_Rat',
#   'hat',
#   'in',
#   'seiner',
#   'Sitzung',
#   'am',
#   '07.04.2016',
#   'auf',
#   'der',
#   'Grundlage',
#   'des',
#   'seinerzeitigen',
#   'Standes',
#   'der',
#   'Kostenberechnung',
#   '(',
#   'Leistungsphase',
#   '3',
#   'der',
#   'HOAI',
#   ')',
#   'beschlossen',
#   ',',
#   'die',
#   'Verwaltung',
#   'mit',
#   'der',
#   'Umsetzung',
#   'der',
#   'Sanierung',
#   'in',
#   'der',
#   'vorgelegten',
#   'Form',
#   'zu',
#   'beauftragen',
#   '(_vgl.',
#   'DS',
#   '1611089',
#   ')',
#   '.'],
#  ['Auf',
#   'dieser',
#   'Basis',
#   'wurden',
#   'die',
#   'Planungsleistungen',
#   'seitdem',
#   'fortgeführt',
#   'und',
#   'die',
#   'Umsetzung',
#   'vorbereitet',
#   'bzw.',
#   'aktuell',
#   'begonnen',
#   '.'],
#  ['Die',
#   'damals',
#   'beschlossenen',
#   'ca._60',
#   'Millionen_Euro',
#   'wurden',
#   'zur',
#   'Grundlage',
#   'für',
#   'die',
#   'Haushaltsanmeldungen',
#   'des',
#   'anstehenden',
#   'Doppelhaushaltes',
#   '2017/2018',
#   'gemacht',
#   ',',
#   'sodass',
#   'dem',
#   'Projekt',
#   'nur',
#   'die',
#   'dann',
#   'in',
#   'den',
#   'Haushalt',
#   'einzustellenden',
#   'Mittel_zur_Verfügung',
#   'stehen',
#   '.'],
#  ['Sofern',
#   'es',
#   'zu',
#   'Kostensteigerungen',
#   'kommen',
#   'sollte',
#   ',',
#   'die',
#   'das',
#   'im',
#   'Haushalt',
#   'zur',
#   'Verfügung_stehende',
#   'Budget',
#   'überschreiten',
#   ',',
#   'müssten',
#   'diese',
#   'vorab',
#   'vom',
#   'Stadtrat',
#   'genehmigt',
#   'werden',
#   ',',
#   'was',
#   'auch',
#   'bei',
#   'einem',
#   'beschlossenen',
#   'Kostendeckel',
#   'nicht',
#   'anders',
#   'wäre',
#   '.'],
#  ['Der',
#   'Vorschlag',
#   'ist',
#   'einstimmig',
#   'erledigt',
#   'im',
#   'Sinne',
#   'der',
#   'Stellungnahme_der_Verwaltung',
#   '.'],
#  ['Beethovenhalle', '.', '\n'],
#  ['Vorschlag', ':'],
#  ['Den',
#   'Denkmalschutz',
#   'der',
#   'Beethovenhalle',
#   '(',
#   'zumindest_teilweise',
#   ')',
#   'aufheben',
#   'und',
#   'dadurch',
#   'die',
#   'Kosten',
#   'der',
#   'Sanierung',
#   'reduzieren',
#   '.'],
#  ['Reduzierung',
#   'von',
#   'Verwaltungs-',
#   'und',
#   'Rechtsverteidigungskosten',
#   'durch',
#   'eine',
#   'gerechtere',
#   'Staffelung',
#   'der',
#   'Elternbeiträge',
#   '.',
#   '\n'],
#  ['In',
#   'Bonn',
#   'werden',
#   'Eltern',
#   'von',
#   'Kindern',
#   ',',
#   'die',
#   'in',
#   'öffentlich_geförderten',
#   'Kindergärten',
#   'oder',
#   'Tagespflegestellen',
#   'betreut',
#   'werden',
#   ',',
#   'zu',
#   'einem',
#   'monatlichen',
#   'Kostenbeitrag',
#   'herangezogen',
#   ',',
#   'dem',
#   'sog._„',
#   'Elternbeitrag',
#   '“',
#   '.'],
#  ['Mit',
#   'diesen',
#   'Elternbeiträgen',
#   'deckt',
#   'die',
#   'Stadt_Bonn',
#   'einen',
#   '(',
#   'insgesamt',
#   'eher',
#   'kleinen',
#   ')',
#   'Teil',
#   'der',
#   'Gesamtkosten',
#   ',',
#   'die',
#   'für',
#   'die',
#   'betreffenden',
#   'Betreuungsangebote',
#   'entstehen',
#   '.'],
#  ['Die',
#   'Höhe',
#   'des',
#   'zu',
#   'zahlenden',
#   'Elternbeitrags',
#   'hängt',
#   'vom',
#   'Einkommen',
#   'der',
#   'Eltern',
#   'des',
#   'Kindes',
#   'ab',
#   '.'],
#  ['Dabei',
#   'sieht',
#   'die',
#   'einschlägige',
#   'Satzung',
#   'eine',
#   'Staffelung',
#   'in',
#   'derzeit',
#   'zehn',
#   'unterschiedliche',
#   'Einkommensstufen',
#   'vor',
#   ',',
#   'aus',
#   'denen',
#   'sich',
#   'die',
#   'Höhe',
#   'des',
#   'jeweiligen',
#   'Elternbeitrags',
#   'ergibt',
#   '.'],
#  ['So',
#   'ist',
#   'z._B.',
#   'bei',
#   'einem',
#   'Jahreseinkommen',
#   'zwischen',
#   '36.813,00',
#   'und',
#   '49.084,00',
#   'Euro',
#   '(',
#   'Stufe',
#   '4',
#   ')',
#   'für',
#   'die',
#   'Betreuung',
#   'eines',
#   'mindestens_3',
#   'Jahre_alten',
#   'Kindes',
#   'in',
#   'einer',
#   'Kindertageseinrichtung',
#   'im',
#   'Umfang',
#   'von',
#   'bis',
#   'zu',
#   '45',
#   'Stunden',
#   'wöchentlich',
#   'ein',
#   'monatlicher',
#   'Elternbeitrag',
#   'von',
#   '128,00',
#   'Euro',
#   'zu',
#   'leisten',
#   '.'],
#  ['Bei',
#   'einem',
#   'Einkommen',
#   'von',
#   '49.084,00',
#   'Euro',
#   'bis',
#   '61.355,00',
#   'Euro',
#   '(',
#   'Stufe',
#   '5',
#   ')',
#   'werden',
#   '196,00',
#   'Euro_fällig',
#   '.'],
#  ['Es',
#   'ist',
#   'daher',
#   'von',
#   'erheblicher',
#   'Bedeutung',
#   ',',
#   'welcher',
#   'Einkommensstufe',
#   'man',
#   'zugerechnet',
#   'wird',
#   '.'],
#  ['In',
#   'dem',
#   'Beispiel',
#   'macht',
#   'die',
#   'Frage',
#   ',',
#   'ob',
#   'man',
#   'der',
#   'Stufe',
#   '4',
#   'oder',
#   'der',
#   'Stufe',
#   '5',
#   'unterfällt',
#   ',',
#   'einen',
#   'monatlichen',
#   'Unterschied',
#   'von',
#   '(',
#   '196,00',
#   '-',
#   '128,00',
#   '=)'],
#  ['68,00',
#   'Euro',
#   'aus',
#   ',',
#   'was',
#   'einem',
#   'Jahresbetrag',
#   'von',
#   '(',
#   '68,00',
#   '*_12',
#   '=)'],
#  ['816,00', 'Euro', 'entspricht', '.'],
#  ['Hieraus',
#   'folgen',
#   'm._E.',
#   'zwei',
#   'Defizite',
#   ',',
#   'die',
#   'sich',
#   'auch',
#   'haushaltsrelevant',
#   'auswirken',
#   '.'],
#  ['Zum',
#   'einen',
#   'ergibt',
#   'sich',
#   'aus',
#   'der',
#   'erheblichen',
#   'finanziellen',
#   'Bedeutung',
#   'einer',
#   'korrekten',
#   'Einstufung',
#   'ein',
#   'erheblicher',
#   'Anreiz',
#   'für',
#   'Eltern',
#   'und',
#   'Verwaltung',
#   ',',
#   'eine',
#   'niederigere',
#   'bzw.',
#   'höhere',
#   'Einstufung',
#   'zu',
#   'begründen',
#   '.'],
#  ['Hierfür',
#   'besteht',
#   'auch',
#   'Potential',
#   ',',
#   'da',
#   'die',
#   'Berechnung',
#   'des',
#   'elternbeitragsrelevanten',
#   'Einkommens',
#   'sehr',
#   'kompliziert',
#   'ist',
#   'und',
#   'über',
#   'viele',
#   'Fragen',
#   'Streit',
#   'zwischen',
#   'den',
#   'beitragspflichtigen',
#   'Eltern',
#   'und',
#   'der',
#   'Verwaltung',
#   'entsteht',
#   '.'],
#  ['Dieser',
#   'Streit',
#   'lässt',
#   'sich',
#   'zwar',
#   'ggf.',
#   'gerichtlich',
#   'klären',
#   '.'],
#  ['Bis',
#   'dahin',
#   'entsteht',
#   'aber',
#   'allen',
#   'Beteiligten',
#   'ein',
#   'hoher',
#   'Aufwand',
#   ',',
#   'der',
#   'insbesondere',
#   'für',
#   'die',
#   'Stadt_Bonn',
#   'selbst',
#   'bei',
#   'einem',
#   'Erfolg',
#   'vor',
#   'Gericht',
#   'nicht',
#   'kompensiert',
#   'werden',
#   'kann',
#   '.'],
#  ['Denn',
#   'die',
#   'Rechtsverteidigung',
#   'durch',
#   'Behördenbedienstete',
#   'wird',
#   'dem',
#   'allgemeinen',
#   'Aufwand',
#   'der',
#   'Behörde',
#   'zugerechnet',
#   '.'],
#  ['Vorgerichtlicher',
#   'Aufwand',
#   'der',
#   'Verwaltung',
#   'ist',
#   'erst',
#   'recht',
#   'nicht',
#   'erstattungsfähig',
#   '.'],
#  ['Und',
#   'zum',
#   'anderen',
#   'ist',
#   'die',
#   'derzeitige',
#   'Staffelung',
#   'auch',
#   'nicht',
#   'gerecht',
#   ':'],
#  ['In',
#   'dem',
#   'oben',
#   'ausgeführten',
#   'Beispiel',
#   'zahlen',
#   'Eltern_mit_einem_Jahreseinkommen',
#   'von',
#   '49.000,00',
#   'Euro',
#   'jährliche',
#   'Elternbeiträge',
#   'in',
#   'Höhe',
#   'von',
#   '(',
#   '128,00',
#   '*_12'],
#  ['=)'],
#  ['1.536,00', 'Euro', '.'],
#  ['Eltern_mit_einem_Jahreseinkommen',
#   'von',
#   '49.100,00',
#   'Euro',
#   'zahlen',
#   'demgegenüber',
#   'Elternbeiträge',
#   'in',
#   'Höhe',
#   'von',
#   '(',
#   '196,00',
#   '*_12'],
#  ['=)'],
#  ['2.352,00', 'Euro', '.'],
#  ['Obwohl',
#   'sie',
#   'also',
#   'ein',
#   'um',
#   'nur',
#   '100,00',
#   'Euro',
#   'höheres',
#   'Einkommen',
#   'haben',
#   ',',
#   'zahlen',
#   'sie',
#   '816,00',
#   'Euro',
#   'mehr',
#   ',',
#   'so',
#   'dass',
#   'ihnen',
#   'am',
#   'Ende',
#   'sogar',
#   'über',
#   '700,00',
#   'Euro',
#   '*',
#   'weniger',
#   '*',
#   'zur',
#   'Verfügung_stehen',
#   'als',
#   'den',
#   'eigentlich',
#   'einkommensschwächeren',
#   'Eltern',
#   '.'],
#  ['Diese',
#   'Ungleichbehandlung',
#   'resultiert',
#   'aus',
#   'den',
#   'relativ_hohen',
#   'Beitragssprüngen',
#   'zwischen',
#   'den',
#   'einzelnen',
#   'Einkommensstufen',
#   ',',
#   'die',
#   'wiederum',
#   'den',
#   'oben',
#   'geschilderten',
#   'Anreiz',
#   'zur',
#   'Fogle',
#   'haben',
#   ',',
#   'eine',
#   'günstigere',
#   'Einstufung',
#   'zu',
#   'erreichen',
#   '.'],
#  ['Diese',
#   'beiden',
#   'Defizite',
#   'der',
#   'derzeitigen',
#   'Staffelung',
#   'ließen',
#   'sich',
#   'beheben',
#   ',',
#   'indem',
#   'eine',
#   'genauere',
#   'Korrelation',
#   'zwischen',
#   'Einkommens-',
#   'und',
#   'Beitragshöhe',
#   'hergestellt',
#   'wird',
#   '.'],
#  ['Ideal',
#   'wäre',
#   'hierbei',
#   'eine',
#   'unmittelbar',
#   'lineare',
#   'Ableitung',
#   '.'],
#  ['Diese',
#   'dürfte',
#   'allerdings',
#   'rechtlich',
#   'problematisch',
#   'sein',
#   ',',
#   'da',
#   '§',
#   '23',
#   'Abs.',
#   '5',
#   'S.',
#   '1',
#   'KiBiz',
#   'ausdrücklich',
#   'eine',
#   '„',
#   'soziale_Staffelung',
#   '“',
#   'vorschreibt',
#   '.'],
#  ['Als',
#   'zweitbeste',
#   '-',
#   'und',
#   'rechtssichere(re',
#   ')',
#   '-',
#   'Lösung',
#   'bliebe',
#   'aber',
#   'eine',
#   'rechnerisch',
#   'hergeleitete',
#   'Staffelung',
#   'mit',
#   'sehr',
#   'kleinen',
#   'Einkommensstufen',
#   '.'],
#  ['Rechstechnisch',
#   'ließe',
#   'sich',
#   'eine',
#   'solche',
#   'Regelung',
#   'an',
#   '§',
#   '13',
#   'RVG',
#   'anlehnen',
#   '.'],
#  ['Denkbar',
#   'wäre',
#   'etwa',
#   'folgende',
#   'Bestimmung:„Höhe',
#   'der',
#   'ElternbeiträgeBei',
#   'einem',
#   'maßgeblichen',
#   'Elterneinkommen',
#   'von',
#   'mehr',
#   'als',
#   '15.000,00',
#   'Euro',
#   'werden',
#   'Elternbeiträge',
#   'erhoben',
#   '.'],
#  ['Deren',
#   'Höhe',
#   'richtet',
#   'sich',
#   'aus',
#   'dem',
#   'in',
#   'der',
#   'Anlage',
#   'vorgesehenen',
#   'Ausgangswert',
#   'und',
#   'erhöht',
#   'sich',
#   'für',
#   'jeden',
#   'angefangenen',
#   'Betrag',
#   'von',
#   'weiteren',
#   '100_Euro',
#   'um',
#   'den',
#   'in',
#   'der',
#   'Anlage',
#   'ausgewiesenen',
#   'Erhöhungswert',
#   '.'],
#  ['Anlage',
#   '(',
#   'hier',
#   'nur',
#   'als',
#   'Beispiel',
#   'für',
#   'die',
#   'Betreuung',
#   'von',
#   'Kindern',
#   'ab',
#   'drei',
#   'Jahren',
#   'in',
#   'einer',
#   'Kindertageseinrichtung)Betreuung',
#   'in',
#   'KindertageseinrichtungKinder',
#   'über',
#   '3',
#   'J.',
#   'bis',
#   'zur',
#   'Einschulung',
#   '\n',
#   '25',
#   'Stunden',
#   ':'],
#  ['Ausgangswert'],
#  ['26,00', 'Euro', '/', 'Erhöhungswert'],
#  ['0,25', 'Euro', '\n', '35', 'Stunden', ':'],
#  ['Ausgangswert', '30,00', 'Euro', '/', 'Erhöhungswert'],
#  ['0,27', 'Euro', '\n', '45', 'Stunden', ':'],
#  ['Ausgangswert',
#   '46,00_Euro',
#   '/',
#   'Erhöhungswert',
#   '0,42',
#   'Euro“(Die',
#   'Zahlen',
#   'orientieren',
#   'sich',
#   'an',
#   'den',
#   'derzeitigen',
#   'Sätzen',
#   'und',
#   'sollen',
#   'hier',
#   'nur',
#   'beispielhaft',
#   'verwendet',
#   'werden',
#   '.'],
#  ['Es',
#   'müsste',
#   'außerdem',
#   'eine',
#   'Beitragsobergrenze',
#   'verankert',
#   'werden',
#   ',',
#   'um',
#   'eine',
#   'Kostenüberdeckung',
#   'im',
#   'Einzelfall',
#   'zu',
#   'vermeiden.)Im',
#   'obigen',
#   'Beispiel',
#   'würde',
#   'damit',
#   'Folgendes',
#   'gelten',
#   ':'],
#  ['Ausgangswert',
#   'wären',
#   '46,00_Euro',
#   '(',
#   'Betreuung',
#   'von',
#   'bis',
#   'zu',
#   '45',
#   'Stunden',
#   'wöchentlich',
#   ')',
#   '.'],
#  ['Die',
#   'erstgenannten',
#   'Eltern_mit_einem_Jahreseinkommen',
#   'von',
#   '49.000,00',
#   'Euro',
#   'müssten',
#   'also',
#   'einen',
#   'Elternbeitrag',
#   'von',
#   '46,00_Euro',
#   '(',
#   'Ausgangswert',
#   ')',
#   '+',
#   '(',
#   '(',
#   '49.000,00',
#   '-',
#   '15.000,00',
#   '=)'],
#  ['34.000,00'],
#  ['Euro', '/'],
#  ['100', '=)', '340', '*'],
#  ['0,42', 'Euro', '(', 'Erhöhungswert', ')'],
#  ['='],
#  ['188,80', 'Euro', 'zahlen', '.'],
#  ['Die',
#   'Eltern_mit_einem_Jahreseinkommen',
#   'von',
#   '49.100,00',
#   'Euro',
#   'müssten',
#   'entsprechend',
#   'einen',
#   'Elternbetrag',
#   'von',
#   '46,00_Euro',
#   '+',
#   '(',
#   '(',
#   '49.100,00',
#   '-',
#   '15.000,00',
#   '=)'],
#  ['34.100,00', 'Euro'],
#  ['/'],
#  ['100', '=)', '341', '*'],
#  ['0,42', 'Euro'],
#  ['='],
#  ['189,22', 'Euro', 'zahlen', '.'],
#  ['Einem',
#   'jährlichen',
#   'Unterschied',
#   'von',
#   '816,00',
#   'Euro',
#   'nach',
#   'geltender',
#   'Rechtslage',
#   'stünde',
#   'damit',
#   'ein',
#   'Unterschied',
#   'von',
#   'lediglich',
#   '(',
#   '12',
#   '*',
#   '0,42',
#   'Euro'],
#  ['=', ')'],
#  ['5,04', 'Euro', 'gegenüber', '.'],
#  ['Die',
#   'Belastung',
#   'der',
#   'Eltern',
#   'würde',
#   'also',
#   'weitgehend',
#   'linear',
#   'zum',
#   'Einkommen',
#   'ansteigen',
#   '.'],
#  ['Zwar',
#   'käme',
#   'es',
#   'an',
#   'den',
#   '„',
#   'Grenzen',
#   '“',
#   'jeder',
#   'vollen',
#   '100_Euro',
#   'weiterhin',
#   'zu',
#   'einem',
#   'Beitrag“sprung',
#   '“',
#   '.'],
#  ['Dieser',
#   'entspräche',
#   'aber',
#   'dem',
#   'jeweiligen',
#   'Erhöhungswert',
#   ',',
#   'wäre',
#   'also',
#   'sehr',
#   'gering',
#   'und',
#   'eher',
#   'ein',
#   'Beitrags“hüpfer',
#   '"',
#   '.'],
#  ...]
