# %%
# coding: utf-8

import argparse
import pickle
import re
from os.path import join

import pandas as pd
from numpy import dot, float32 as REAL, sqrt, newaxis
from gensim import matutils
from gensim.models import Word2Vec, Doc2Vec

from train_utils import init_logging
from constants import ETL_PATH, DATASETS
from tqdm import tqdm

pd.options.display.max_rows = 200
tqdm.pandas()

# %%
LOG = None


def get_indices(d2v, w2v, max_title_length=4, min_doc_length=41):
    phrases = get_phrases(max_title_length=max_title_length, min_doc_length=min_doc_length)
    d2v_indices = []
    w2v_indices = []
    dout = wout = 0
    for label in phrases:
        try:
            idx = d2v.docvecs.doctags[label].offset
            d2v_indices.append(idx)
        except:
            dout += 1
        try:
            idx = w2v.wv.vocab[label].index
            w2v_indices.append(idx)
        except:
            wout += 1
    return d2v_indices, w2v_indices


def index_embeddings(d2v, w2v, d2v_indices, w2v_indices):
    """
    Modifies the argument models. Normalizes the d2v und w2v vectors.
    Also reduces the number of d2v docvecs.
    """
    # Models normalised in unit vectord from the indices given above in pickle files.
    d2v.wv.syn0norm = (d2v.wv.syn0 / sqrt((d2v.wv.syn0 ** 2).sum(-1))[..., newaxis]).astype(REAL)
    d2v.docvecs.vectors_docs_norm = \
        (d2v.docvecs.doctag_syn0 / sqrt((d2v.docvecs.doctag_syn0 ** 2).sum(-1))[..., newaxis]) \
        .astype(REAL)[d2v_indices]
    LOG.info("doc2vec normalized")

    w2v.wv.syn0norm = (w2v.wv.syn0 / sqrt((w2v.wv.syn0 ** 2).sum(-1))[..., newaxis]).astype(
        REAL)
    w2v_indexed = w2v.wv.syn0norm[w2v_indices]
    LOG.info("word2vec normalized")
    return w2v_indexed


def load_topics(topics_path, metrics, params, nbtopics, print_sample=False):
    LOG.info(f'Loading topics {topics_path}')
    # TODO !!!!!!!!!!!!
    topics = pd.read_csv(topics_path, index_col=None)
    if metrics and 'metric' in topics.columns:
        topics = topics[topics.metric.isin(metrics)]
    if params and 'param_id' in topics.columns:
        topics = topics[topics.param_id.isin(params)]
    if nbtopics and 'nb_topics' in topics.columns:
        topics = topics[topics.nb_topics.isin(nbtopics)]
    topics = (
        topics.drop(
            ['dataset', 'metric', 'param_id', 'nb_topics', 'topic_idx', 'topic_id', 'domain'],
            axis=1, errors='ignore'
        )
        .reset_index(drop=True)
    )
    if print_sample:
        LOG.info('\n' + topics.head(10))
    LOG.info(f'number of topics {len(topics)}')
    return topics


def parse_args():
    parser = argparse.ArgumentParser()

    parser.add_argument("--topics_file", type=str, required=False)
    parser.add_argument("--labels_file", type=str, required=False)
    parser.add_argument("--d2v_indices", type=str, required=False)
    parser.add_argument("--w2v_indices", type=str, required=False)

    emb_path = EMB_PATH
    parser.add_argument("--d2v_path", type=str, required=False, default=join(emb_path, 'd2v', 'd2v'))
    parser.add_argument("--w2v_path", type=str, required=False, default=join(emb_path, 'w2v', 'w2v'))

    parser.add_argument("--dataset", type=str, required=False)
    parser.add_argument("--nbfiles", type=int, required=False, default=None)
    parser.add_argument("--version", type=str, required=False, default='noun')
    parser.add_argument("--metrics", nargs='*', type=str, required=False, default=['ref'])
    parser.add_argument("--params", nargs='*', type=str, required=False, default=['e42'])
    parser.add_argument("--nbtopics", nargs='*', type=int, required=False, default=[100])

    parser.add_argument("--nblabels", type=int, required=False, default=20)
    parser.add_argument("--max_title_length", type=int, required=False, default=4)
    parser.add_argument("--min_doc_length", type=int, required=False, default=41)

    args = parser.parse_args()

    dataset = DATASETS.get(args.dataset, args.dataset)
    nbfiles_str = f'_nbfiles{args.nbfiles:02d}' if args.nbfiles else ''
    if args.topics_file:
        topics_file_is_given = True
        args.nbfiles = args.version = args.metrics = args.params = args.nbtopics = None
    else:
        topics_file_is_given = False
        args.topics_file = join(
            LDA_PATH, args.version, 'topics',
            f'{dataset}{nbfiles_str}_topic-candidates.csv'
        )
    if args.labels_file is None:
        if topics_file_is_given:
            args.labels_file = args.topics_file.strip('.csv') + '_label-candidates.csv'
        else:
            args.labels_file = join(
                LDA_PATH, args.version, 'topics',
                f'{dataset}{nbfiles_str}_label-candidates.csv'
            )

    if args.d2v_indices and args.w2v_indices:
        args.max_title_length = None
        args.min_doc_length = None

    return (
        args.topics_file, args.labels_file, args.d2v_indices, args.w2v_indices,
        args.d2v_path, args.w2v_path,
        args.metrics, args.params, args.nbtopics,
        args.max_title_length, args.min_doc_length, args.nblabels, args
    )


def fake_args():
    d2v_path = "NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v"
    w2v_path = "NETL/model_run/pre_trained_models/word2vec_en/word2vec"
    topics_file = "NETL/model_run/data/topics.csv"
    labels_file = "NETL/model_run/output_candidates_topics_gen35_newimp"
    d2v_indices = "NETL/model_run/support_files/en/doc2vec_indices_en"
    w2v_indices = "NETL/model_run/support_files/en/word2vec_indices_en"
    metrics = None
    params = None
    nbtopics = None
    max_title_length = 4
    min_doc_length = 41
    nblabels = 19
    return (
        topics_file, labels_file, d2v_indices, w2v_indices,
        d2v_path, w2v_path,
        metrics, params, nbtopics,
        max_title_length, min_doc_length, nblabels, dict()
    )


def get_word(word):
    if type(word) != str:
        return word
    inst = re.search(r"_\(([A-Za-z0-9_]+)\)", word)
    if inst is None:
        return word
    else:
        word = re.sub(r'_\(.+\)', '', word)
        return word


def load_embeddings(d2v_path, w2v_path):
    LOG.info(f'Doc2Vec loading {d2v_path}')
    d2v = Doc2Vec.load(d2v_path)
    LOG.info(f'vocab size: len(d2v.wv.vocab)')
    LOG.info(f'docvecs size: {len(d2v.docvecs.vectors_docs)}')

    LOG.info(f'Word2Vec loading {w2v_path}')
    w2v = Word2Vec.load(w2v_path)
    LOG.info(f'vocab size: {len(w2v.wv.vocab)}')
    return d2v, w2v


def get_phrases(max_title_length, min_doc_length, lemmatized_only=True):
    dewiki_phrases_lemmatized = 'dewiki_phrases_lemmatized.pickle'
    phrases = pd.read_pickle(join(ETL_PATH, dewiki_phrases_lemmatized))
    # creating a list containing original and lemmatized phrases
    phrases = phrases.query(f"doc_len >= {min_doc_length} and title_len <= {max_title_length}")
    if lemmatized_only:
        phrases = phrases.token.unique()
    else:
        phrases = phrases.token.append(phrases.text).unique()
    pat = re.compile(r'^[a-zA-ZÄÖÜäöü]+.*')
    phrases = filter(lambda x: pat.match(x), phrases)
    return phrases

# %%
(
    topics_file, labels_file, d2v_indices_file, w2v_indices_file,
    d2v_path, w2v_path,
    metrics, params, nb_topics,
    max_title_length, min_doc_length, nb_labels, args
) = fake_args()

LOG = logger = init_logging(name='label_candidates')
#log_args(logger, args)

topics = load_topics(
    topics_path=topics_file, metrics=metrics, params=params, nbtopics=nb_topics, print_sample=False
)
# Out:
# 2018-11-17 01:21:42,665 : INFO : pandas: 0.23.4
# 2018-11-17 01:21:42,666 : INFO : gensim: 3.5.0
# 2018-11-17 01:21:42,667 : INFO : python: 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56)  [GCC 7.2.0]
# 2018-11-17 01:21:42,668 : INFO : Loading topics NETL/model_run/data/topics.csv
# 2018-11-17 01:21:42,674 : INFO : number of topics 228

# %%
d2v, w2v = load_embeddings(
    d2v_path=d2v_path, w2v_path=w2v_path
)

if d2v_indices_file and w2v_indices_file:
    logger.info(f'loading {d2v_indices_file}')
    with open(d2v_indices_file, 'rb') as fp:
        d2v_indices = pickle.load(fp)
    logger.info(f'loading {w2v_indices_file}')
    with open(w2v_indices_file, 'rb') as fp:
        w2v_indices = pickle.load(fp)
else:
    d2v_indices, w2v_indices = get_indices(
        d2v=d2v, w2v=w2v, max_title_length=max_title_length, min_doc_length=min_doc_length
    )
d2v_indices = sorted(set(d2v_indices))
w2v_indices = sorted(set(w2v_indices))

w2v_indexed = index_embeddings(
    d2v=d2v, w2v=w2v, d2v_indices=d2v_indices, w2v_indices=w2v_indices
)
# Out:
# 2018-11-17 00:45:06,325 : INFO : pandas: 0.23.4
# 2018-11-17 00:45:06,326 : INFO : gensim: 3.5.0
# 2018-11-17 00:45:06,327 : INFO : python: 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56)  [GCC 7.2.0]
# 2018-11-17 00:45:06,327 : INFO : Loading topics NETL/model_run/data/topics.csv
# 2018-11-17 00:45:06,341 : INFO : number of topics 4
# 2018-11-17 00:45:06,342 : INFO : Doc2Vec loading NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v
# 2018-11-17 00:45:06,342 : INFO : loading Doc2Vec object from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v
# 2018-11-17 00:45:06,473 : INFO : Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.
# 2018-11-17 00:45:06,475 : INFO : loading Doc2Vec object from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v
# 2018-11-17 00:45:16,819 : INFO : loading docvecs recursively from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v.docvecs.* with mmap=None
# 2018-11-17 00:45:16,820 : INFO : loading doctag_syn0 from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v.docvecs.doctag_syn0.npy with mmap=None
# 2018-11-17 00:45:31,247 : INFO : loading syn1neg from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v.syn1neg.npy with mmap=None
# 2018-11-17 00:45:31,483 : INFO : loading syn0 from NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v.syn0.npy with mmap=None
# 2018-11-17 00:45:31,706 : INFO : setting ignored attribute syn0norm to None
# 2018-11-17 00:45:31,707 : INFO : setting ignored attribute cum_table to None
# 2018-11-17 00:45:31,707 : INFO : loaded NETL/model_run/pre_trained_models/doc2vec_en/docvecmodel.d2v
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:531: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:535: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2018-11-17 00:45:33,184 : INFO : vocab size: len(d2v.wv.vocab)
# 2018-11-17 00:45:33,185 : INFO : docvecs size: 4988569
# 2018-11-17 00:45:33,185 : INFO : Word2Vec loading NETL/model_run/pre_trained_models/word2vec_en/word2vec
# 2018-11-17 00:45:33,186 : INFO : loading Word2Vec object from NETL/model_run/pre_trained_models/word2vec_en/word2vec
# 2018-11-17 00:45:35,538 : INFO : loading syn1neg from NETL/model_run/pre_trained_models/word2vec_en/word2vec.syn1neg.npy with mmap=None
# 2018-11-17 00:45:38,776 : INFO : Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.
# 2018-11-17 00:45:38,777 : INFO : loading Word2Vec object from NETL/model_run/pre_trained_models/word2vec_en/word2vec
# 2018-11-17 00:45:41,385 : INFO : loading syn1neg from NETL/model_run/pre_trained_models/word2vec_en/word2vec.syn1neg.npy with mmap=None
# 2018-11-17 00:45:41,731 : INFO : loading syn0 from NETL/model_run/pre_trained_models/word2vec_en/word2vec.syn0.npy with mmap=None
# 2018-11-17 00:45:42,082 : INFO : setting ignored attribute syn0norm to None
# 2018-11-17 00:45:42,082 : INFO : setting ignored attribute cum_table to None
# 2018-11-17 00:45:42,083 : INFO : loaded NETL/model_run/pre_trained_models/word2vec_en/word2vec
# 2018-11-17 00:45:44,811 : INFO : vocab size: 1105979
# 2018-11-17 00:45:44,812 : INFO : loading NETL/model_run/support_files/en/doc2vec_indices_en
# 2018-11-17 00:45:44,897 : INFO : loading NETL/model_run/support_files/en/word2vec_indices_en
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: Call to deprecated `doctag_syn0` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs instead).
# 2018-11-17 00:45:53,150 : INFO : doc2vec normalized
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
# 2018-11-17 00:45:54,467 : INFO : word2vec normalized

# %%
def get_labels(topic, nb_labels, d2v, w2v, w2v_indexed, d_indices, w_indices):
    valdoc2vec = 0.0
    valword2vec = 0.0
    store_indices = []
    topic = topic.iloc[0, :]
    topic_len = len(topic)
    for item in topic:
        try:
            # The word2vec value of topic word from doc2vec trained model
            tempdoc2vec = d2v.wv.syn0norm[d2v.wv.vocab[item].index]
        except:
            pass
        else:
            meandoc2vec = matutils.unitvec(tempdoc2vec).astype(REAL)  # Getting the unit vector
            # The dot product of all labels in doc2vec with the unit vector of topic word
            distsdoc2vec = dot(d2v.docvecs.doctag_syn0norm, meandoc2vec)
            valdoc2vec = valdoc2vec + distsdoc2vec

        try:
            # The word2vec value of topic word from word2vec trained model
            tempword2vec = w2v.wv.syn0norm[w2v.wv.vocab[item].index]
        except:
            pass
        else:
            # Unit vector
            meanword2vec = matutils.unitvec(tempword2vec).astype(REAL)
            # dot product of all possible labels in word2vec vocab with the unit vector of topic word
            distsword2vec = dot(w2v_indexed, meanword2vec)
            """
            This next section of code checks if the topic word is also a potential label in trained 
            word2vec model. If that is the case, it is important the dot product of label with that 
            topic word is not taken into account.Hence we make that zero and further down the code 
            also exclude it in taking average of that label over all topic words. 
            """
            if w2v.wv.vocab[item].index in w_indices:
                i_val = w_indices.index(w2v.wv.vocab[item].index)
                store_indices.append(i_val)
                distsword2vec[i_val] = 0.0
            valword2vec = valword2vec + distsword2vec

    avgdoc2vec = valdoc2vec / float(topic_len)  # Give the average vector over all topic words
    avgword2vec = valword2vec / float(topic_len)  # Average of word2vec vector over all topic words

    # argsort and get top 100 doc2vec label indices
    bestdoc2vec = matutils.argsort(avgdoc2vec, topn=100, reverse=True)
    resultdoc2vec = []
    # Get the doc2vec labels from indices
    for elem in bestdoc2vec:
        ind = d_indices[elem]
        temp = d2v.docvecs.index_to_doctag(ind)
        resultdoc2vec.append((temp, float(avgdoc2vec[elem])))

    # This modifies the average word2vec vector for cases
    # in which the word2vec label was same as topic word.
    for element in store_indices:
        avgword2vec[element] = (avgword2vec[element] * topic_len) / (float(topic_len - 1))

    # argsort and get top 100 word2vec label indices
    bestword2vec = matutils.argsort(avgword2vec, topn=100, reverse=True)
    # Get the word2vec labels from indices
    resultword2vec = []
    for element in bestword2vec:
        ind = w_indices[element]
        temp = w2v.wv.index2word[ind]
        resultword2vec.append((temp, float(avgword2vec[element])))

    # Get the combined set of both doc2vec labels and word2vec labels
    comb_labels = sorted(set([i[0] for i in resultdoc2vec] + [i[0] for i in resultword2vec]))
    newlist_doc2vec = []
    newlist_word2vec = []

    # Get indices from combined labels
    for elem in comb_labels:
        try:
            newlist_doc2vec.append(d_indices.index(d2v.docvecs.doctags[elem].offset))
            temp = get_word(elem)
            newlist_word2vec.append(w_indices.index(w2v.wv.vocab[temp].index))
        except:
            pass
    newlist_doc2vec = set(newlist_doc2vec)
    newlist_word2vec = set(newlist_word2vec)

    # Finally again get the labels from indices. We searched for the score from both d2v and w2v models
    scores_d2v = pd.Series({
        d2v.docvecs.index_to_doctag(d_indices[elem]): float(avgdoc2vec[elem]) for elem in newlist_doc2vec
    }, name='doc2vec')

    scores_w2v = pd.Series({
        w2v.wv.index2word[w_indices[elem]]: float(avgword2vec[elem]) for elem in newlist_word2vec
    }, name='word2vec')
    
    # Finally get the combined score with the label. The label used will be of doc2vec not of word2vec.
    scores = pd.concat([scores_d2v, scores_w2v], axis=1)
    scores['combined'] = scores[['doc2vec', 'word2vec']].sum(axis=1, skipna=False)
    scores_d2v = scores.doc2vec.sort_values(ascending=False).index.values[:nb_labels]
    scores_w2v = scores.word2vec.sort_values(ascending=False).index.values[:nb_labels]
    scores_com = scores.combined.dropna().sort_values(ascending=False).index.values[:nb_labels]
    scores = pd.DataFrame(
        [scores_d2v, scores_w2v, scores_com], 
        index=['doc2vec', 'word2vec', 'combined'],
        columns=[f'label{i}' for i in range(nb_labels)]
    )
    return scores

# %%
# %%time
labels = topics[:].groupby(level=0).progress_apply(
    lambda row: get_labels(
        topic=row, nb_labels=nb_labels,
        d2v=d2v, w2v=w2v, w2v_indexed=w2v_indexed,
        d_indices=d2v_indices, w_indices=w2v_indices
    )
)
# Out:
#   0%|          | 0/228 [00:00<?, ?it/s]/home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
#   # Remove the CWD from sys.path while we load stuff.
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `doctag_syn0norm` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs_norm instead).
#   app.launch_new_instance()
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:93: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# 100%|██████████| 228/228 [1:10:31<00:00, 20.58s/it]
# CPU times: user 1h 37min 44s, sys: 18 s, total: 1h 38min 2s
# Wall time: 1h 11min 3s

# %%
labels
# Out:
#                                                   label0  \
# 0   doc2vec                      microsoft_visual_studio
#     word2vec                                    software
#     combined                             cloud_computing
# 1   doc2vec   massachusetts_gubernatorial_election,_1994
#     word2vec                                barack_obama
#     combined                                 john_mccain
# 2   doc2vec                               windows_mobile
#     word2vec                            operating_system
#     combined                            operating_system
# 3   doc2vec                                 flash_memory
#     word2vec                                flash_memory
#     combined                                flash_memory
# 4   doc2vec                       history_of_video_games
#     word2vec                                    xbox_360
#     combined                                    xbox_360
# 5   doc2vec                       independent_politician
#     word2vec                                the_election
#     combined                            primary_election
# 6   doc2vec                         pediatric_psychology
#     word2vec                                     patient
#     combined                             palliative_care
# 7   doc2vec                                     empanada
#     word2vec                                       sauce
#     combined                                       pasta
# 8   doc2vec                      roman_catholic_theology
#     word2vec                                    in_jesus
#     combined                                christianity
# 9   doc2vec                      winning_streak_(sports)
#     word2vec                               olympic_games
#     combined                               olympic_games
# 10  doc2vec      washington_gubernatorial_election,_2000
#     word2vec                        presidential_nominee
#     combined                                 sarah_palin
# 11  doc2vec                   streak-throated_woodpecker
#     word2vec                                      yellow
#     combined                                      yellow
# 12  doc2vec                financial_crisis_of_2007â08
#     word2vec                                  investment
#     combined                    subprime_mortgage_crisis
# 13  doc2vec                                    nutrition
#     word2vec                                      eating
#     combined                                   nutrition
# 14  doc2vec                             four-wheel_drive
#     word2vec                                     the_car
#     combined                            four-wheel_drive
# 15  doc2vec                                        gmail
#     word2vec                                         web
#     combined                                     website
# 16  doc2vec                                  natural_gas
#     word2vec                                 natural_gas
#     combined                                 natural_gas
# 17  doc2vec                          biochemical_cascade
#     word2vec                             gene_expression
#     combined                             gene_expression
# 18  doc2vec                    microsoft_mobile_services
#     word2vec                               mobile_device
#     combined                                  smartphone
# 19  doc2vec                                   rock_music
#     word2vec                                    the_band
#     combined                                  rock_music
# 20  doc2vec                                extra_innings
#     word2vec                              the_final_game
#     combined                               extra_innings
# 21  doc2vec                    incest_in_popular_culture
#     word2vec                                    daughter
#     combined                                      father
# 22  doc2vec                          private_prosecution
#     word2vec                                    the_case
#     combined                                  prosecutor
# 23  doc2vec                                         shoe
#     word2vec                                       strap
#     combined                                       strap
# 24  doc2vec                                  high_school
#     word2vec                                    graduate
#     combined                                 high_school
# 25  doc2vec                               perfect_season
#     word2vec                              the_final_game
#     combined                                    playoffs
# 26  doc2vec                                  los_angeles
#     word2vec                                        jose
#     combined                                 los_angeles
# 27  doc2vec                                   mail_order
#     word2vec                                        sell
#     combined                                  mail_order
# 28  doc2vec                             sys_technologies
#     word2vec                                   marketing
#     combined                                   marketing
# 29  doc2vec                           air_national_guard
#     word2vec                                        army
#     combined                                        army
# 30  doc2vec                    campus_of_elon_university
#     word2vec                                 dining_room
#     combined                                 dining_room
# 31  doc2vec                             economy_of_india
#     word2vec                                  percentage
#     combined                                    tax_rate
# 32  doc2vec    list_of_ecoregions_in_north_america_(cec)
#     word2vec                                        deer
#     combined                                        deer
# 33  doc2vec             oxford_period_poetry_anthologies
# ...                                                  ...
# 194 combined                          membrane_potential
# 195 doc2vec                                     survivin
#     word2vec                                  cell_death
#     combined                                  cell_death
# 196 doc2vec                           child_sexual_abuse
#     word2vec                                         sex
#     combined                                  pedophilia
# 197 doc2vec                           child_sexual_abuse
#     word2vec                                 adolescence
#     combined                                 adolescence
# 198 doc2vec                          physician_assistant
#     word2vec                                    medicine
#     combined                                    medicine
# 199 doc2vec                         italian_crested_newt
#     word2vec                                  the_uptake
#     combined                                  metabolism
# 200 doc2vec                                     bio-mems
#     word2vec                               the_procedure
#     combined                                percutaneous
# 201 doc2vec             management_of_multiple_sclerosis
#     word2vec                           clinical_research
#     combined                             pain_management
# 202 doc2vec                                   neurotoxin
#     word2vec                              animal_studies
#     combined                              glucocorticoid
# 203 doc2vec                       educational_assessment
#     word2vec                                  evaluation
#     combined                                  evaluation
# 204 doc2vec                             urine_test_strip
#     word2vec                                       urine
#     combined                                     albumin
# 205 doc2vec                                       stroke
#     word2vec                                     disease
#     combined                       myocardial_infarction
# 206 doc2vec                      epidemiology_of_obesity
#     word2vec                              mortality_rate
#     combined                             life_expectancy
# 207 doc2vec                              bioavailability
#     word2vec                             bioavailability
#     combined                             bioavailability
# 208 doc2vec                               ovarian_cancer
#     word2vec                                      biopsy
#     combined                                      biopsy
# 209 doc2vec                                    data_grid
#     word2vec                                        data
#     combined                                   usability
# 210 doc2vec                                prothionamide
#     word2vec                              clinical_trial
#     combined                              clinical_trial
# 211 doc2vec                                      sol-gel
#     word2vec                                  solubility
#     combined                                  solubility
# 212 doc2vec                                      sol-gel
#     word2vec                               the_molecules
#     combined                                nanoparticle
# 213 doc2vec                         sensitivity_analysis
#     word2vec                                quantitative
#     combined                         regression_analysis
# 214 doc2vec                   streptococcus_dysgalactiae
#     word2vec                                      tested
#     combined                             diagnostic_test
# 215 doc2vec                            psychology_of_art
#     word2vec                                  perception
#     combined                                  perception
# 216 doc2vec                             multiple_myeloma
#     word2vec                                   diagnosis
#     combined                      differential_diagnosis
# 217 doc2vec                                chronic_wound
#     word2vec                               wound_healing
#     combined                               wound_healing
# 218 doc2vec                               working_memory
#     word2vec                              working_memory
#     combined                              working_memory
# 219 doc2vec           complications_of_diabetes_mellitus
#     word2vec                                      normal
#     combined                          c-reactive_protein
# 220 doc2vec                             complex_training
#     word2vec                               effectiveness
#     combined                           strength_training
# 221 doc2vec                             spatial_analysis
#     word2vec                                   heuristic
#     combined                                 methodology
# 222 doc2vec                         italian_crested_newt
#     word2vec                               water_content
#     combined                              carbon_dioxide
# 223 doc2vec                                       insect
#     word2vec                                  parasitoid
#     combined                                       aphid
# 224 doc2vec                      sociology_of_the_family
#     word2vec                                   the_study
#     combined                              social_support
# 225 doc2vec                                    data_grid
#     word2vec                                     example
#     combined                                      system
# 226 doc2vec                             spatial_analysis
#     word2vec                                 calculation
#     combined                          mathematical_model
# 227 doc2vec                              water_pollution
#     word2vec                               contamination
#     combined                              carbon_dioxide
#
#                                                label1  \
# 0   doc2vec                    desktop_virtualization
#     word2vec                         operating_system
#     combined                         operating_system
# 1   doc2vec   washington_gubernatorial_election,_2000
#     word2vec                     presidential_nominee
#     combined                            joe_lieberman
# 2   doc2vec                       windows_home_server
#     word2vec                           user_interface
#     combined                        microsoft_windows
# 3   doc2vec                                  mac_mini
#     word2vec                              motherboard
#     combined                              motherboard
# 4   doc2vec                                  xbox_360
#     word2vec                              playstation
#     combined                              playstation
# 5   doc2vec           illinois_senate_elections,_2008
#     word2vec                                 the_vote
#     combined                         general_election
# 6   doc2vec                   tuberculosis_management
#     word2vec                          palliative_care
#     combined                                 medicine
# 7   doc2vec                        stuffed_intestines
#     word2vec                               mayonnaise
#     combined                               mayonnaise
# 8   doc2vec                              christianity
#     word2vec                                   christ
#     combined                                    jesus
# 9   doc2vec                             rimil_buriuly
#     word2vec                            olympic_medal
#     combined                     2008_summer_olympics
# 10  doc2vec   washington_gubernatorial_election,_1988
#     word2vec                            state_senator
#     combined                     presidential_nominee
# 11  doc2vec                   brown-capped_woodpecker
#     word2vec                                     blue
#     combined                                      red
# 12  doc2vec    subprime_crisis_background_information
#     word2vec                            the_financial
#     combined                            goldman_sachs
# 13  doc2vec                        protein_(nutrient)
#     word2vec                             healthy_diet
#     combined                             healthy_diet
# 14  doc2vec                     zf_4hp18_transmission
#     word2vec                               the_engine
#     combined                           power_steering
# 15  doc2vec                 social_networking_service
#     word2vec                                  website
#     combined                                    gmail
# 16  doc2vec                        sustainable_energy
#     word2vec                              fossil_fuel
#     combined                                petroleum
# 17  doc2vec                            silencer_(dna)
#     word2vec                                  in_vivo
#     combined                     transcription_factor
# 18  doc2vec                                    iphone
#     word2vec                               smartphone
#     combined                                    gmail
# 19  doc2vec                              heart_(band)
#     word2vec                               some_songs
#     combined                            cover_version
# 20  doc2vec                       martinsville_astros
#     word2vec                            the_last_game
#     combined                           perfect_season
# 21  doc2vec              children_of_general_hospital
#     word2vec                                   father
#     combined                                    uncle
# 22  doc2vec                                prosecutor
#     word2vec                               prosecutor
#     combined                            supreme_court
# 23  doc2vec                            shoulder_strap
#     word2vec                                    waist
#     combined                                 backpack
# 24  doc2vec                                   college
#     word2vec                                   school
#     combined                                  college
# 25  doc2vec                   winning_streak_(sports)
#     word2vec                                     team
#     combined                           perfect_season
# 26  doc2vec                             san_francisco
#     word2vec                                     luis
#     combined                            san_francisco
# 27  doc2vec                                  pet_shop
#     word2vec                                    buyer
#     combined                                    buyer
# 28  doc2vec                                     kt_ds
#     word2vec                                 industry
#     combined                       project_management
# 29  doc2vec              1st_cavalry_brigade_(france)
#     word2vec                                commander
#     combined                       united_states_army
# 30  doc2vec                            harvey_mansion
#     word2vec                                 bathroom
#     combined                              living_room
# 31  doc2vec                          economy_of_china
#     word2vec                                  billion
#     combined                            profit_margin
# 32  doc2vec                      lakeland_downs_mouse
#     word2vec                                     fowl
#     combined                                   rabbit
# 33  doc2vec                penguin_poetry_anthologies
# ...                                               ...
# 194 combined                            cell_membrane
# 195 doc2vec                        induced_stem_cells
#     word2vec                              cell_growth
#     combined                                apoptosis
# 196 doc2vec                         domestic_violence
#     word2vec                              promiscuity
#     combined                                    abuse
# 197 doc2vec                   sociology_of_the_family
#     word2vec                                    child
#     combined                                    child
# 198 doc2vec                mental_health_professional
#     word2vec                                  nursing
#     combined                                  nursing
# 199 doc2vec                                neurotoxin
#     word2vec                               activation
#     combined                            cell_membrane
# 200 doc2vec                            electrosurgery
#     word2vec                            the_technique
#     combined                               ultrasound
# 201 doc2vec                aids_clinical_trials_group
#     word2vec                         drug_development
#     combined                             gene_therapy
# 202 doc2vec                     chlorophenylbiguanide
#     word2vec                                 toxicity
#     combined                      self-administration
# 203 doc2vec                        program_evaluation
#     word2vec                             quantitative
#     combined                             quantitative
# 204 doc2vec                          copper_in_health
#     word2vec                             blood_plasma
#     combined                               hemoglobin
# 205 doc2vec         contraindications_to_thrombolysis
#     word2vec                                diagnosis
#     combined                                   sepsis
# 206 doc2vec                 demographics_of_the_world
#     word2vec                               prevalence
#     combined                         infant_mortality
# 207 doc2vec                      paracetamol_toxicity
#     word2vec                      oral_administration
#     combined                         pharmacokinetics
# 208 doc2vec                        cholangiocarcinoma
#     word2vec                   differential_diagnosis
#     combined                   differential_diagnosis
# 209 doc2vec                                smart_grid
#     word2vec                          data_collection
#     combined                            data_analysis
# 210 doc2vec          management_of_multiple_sclerosis
#     word2vec                              the_patient
#     combined                             chemotherapy
# 211 doc2vec                       properties_of_water
#     word2vec                            surface_layer
#     combined                                   liquid
# 212 doc2vec                   vectors_in_gene_therapy
#     word2vec                                  bilayer
#     combined                                  sol-gel
# 213 doc2vec                           factor_analysis
#     word2vec                               observable
#     combined                             quantitative
# 214 doc2vec                                     klf17
#     word2vec                               blood_test
#     combined                     immunohistochemistry
# 215 doc2vec                          negative_priming
#     word2vec                              stimulation
#     combined                       recognition_memory
# 216 doc2vec                aids_clinical_trials_group
#     word2vec                                prognosis
#     combined                         adjuvant_therapy
# 217 doc2vec                               ethenzamide
#     word2vec                        anti-inflammatory
#     combined                             inflammation
# 218 doc2vec                  educational_neuroscience
#     word2vec                              human_brain
#     combined                              human_brain
# 219 doc2vec                      biomarker_(medicine)
#     word2vec                              blood_sugar
#     combined                       insulin_resistance
# 220 doc2vec                reserve_training_wing_raaf
#     word2vec                         aerobic_exercise
#     combined                         physical_fitness
# 221 doc2vec              principal_component_analysis
#     word2vec                                  example
#     combined                       mathematical_model
# 222 doc2vec                            ethylene_oxide
#     word2vec                               solubility
#     combined                               solubility
# 223 doc2vec                   lymantria_dispar_dispar
#     word2vec                                 nematode
#     combined                                   insect
# 224 doc2vec                            social_support
#     word2vec                                education
#     combined                                education
# 225 doc2vec                                  bio-mems
#     word2vec                               particular
#     combined                              information
# 226 doc2vec                      sensitivity_analysis
#     word2vec                               estimation
#     combined                      logistic_regression
# 227 doc2vec                          activated_carbon
#     word2vec                              groundwater
#     combined                          water_pollution
#
#                                                          label2  \
# 0   doc2vec                           microsoft_exchange_server
#     word2vec                                     virtualization
#     combined                                            hyper-v
# 1   doc2vec                               conservative_democrat
#     word2vec                                        john_mccain
#     combined                                          joe_biden
# 2   doc2vec                                           virtuawin
#     word2vec                                              linux
#     combined                                              linux
# 3   doc2vec                                   solid-state_drive
#     word2vec                                    hard_disk_drive
#     combined                                       compactflash
# 4   doc2vec                                         playstation
#     word2vec                                        nintendo_ds
#     combined                                           gamecube
# 5   doc2vec                     minnesota_senate_election,_2010
#     word2vec                                              votes
#     combined                                      state_senator
# 6   doc2vec                                 history_of_medicine
#     word2vec                                             health
#     combined                                             health
# 7   doc2vec                                               offal
#     word2vec                                            dessert
#     combined                                            sausage
# 8   doc2vec                              mary_(mother_of_jesus)
#     word2vec                                              faith
#     combined                                 christian_theology
# 9   doc2vec                                          pan_shiyun
#     word2vec                                         gold_medal
#     combined                               summer_olympic_games
# 10  doc2vec                 alaska_gubernatorial_election,_1970
#     word2vec                                   campaign_manager
#     combined                                       running_mate
# 11  doc2vec                           yellow-crowned_woodpecker
#     word2vec                                                red
#     combined                                               blue
# 12  doc2vec                            subprime_mortgage_crisis
#     word2vec                                   financial_crisis
#     combined                                       central_bank
# 13  doc2vec                                        healthy_diet
#     word2vec                                          nutrition
#     combined                                        weight_loss
# 14  doc2vec                                            nanceene
#     word2vec                                        the_vehicle
#     combined                                  front-wheel_drive
# 15  doc2vec                                             website
#     word2vec                                        web_content
#     combined                                           internet
# 16  doc2vec                                 grid_energy_storage
#     word2vec                             electricity_generation
#     combined                                        fossil_fuel
# 17  doc2vec                                    chemical_biology
#     word2vec                               transcription_factor
#     combined                                          apoptosis
# 18  doc2vec                                      windows_mobile
#     word2vec                                       mobile_phone
#     combined                                             iphone
# 19  doc2vec             the_acoustic_ep_(the_early_november_ep)
#     word2vec                                             a_song
#     combined                                           the_band
# 20  doc2vec                    2015_washington_nationals_season
#     word2vec                                             season
#     combined                                           playoffs
# 21  doc2vec       the_young_and_the_restless_characters_(2000s)
#     word2vec                                             mother
#     combined                                               aunt
# 22  doc2vec                                       supreme_court
#     word2vec                                      supreme_court
#     combined                                         jury_trial
# 23  doc2vec                                      top_(clothing)
#     word2vec                                           trousers
#     combined                                            webbing
# 24  doc2vec                           uiuc_college_of_education
#     word2vec                                        high_school
#     combined                                             school
# 25  doc2vec                                            playoffs
#     word2vec                                             played
#     combined                                    exhibition_game
# 26  doc2vec                                             rex_ray
#     word2vec                                               juan
#     combined                                          san_diego
# 27  doc2vec                                 list_of_superstores
#     word2vec                                         purchasing
#     combined                                             retail
# 28  doc2vec                                  machine_to_machine
#     word2vec                                         technology
#     combined                                         automation
# 29  doc2vec                          united_states_marine_corps
#     word2vec                                           military
#     combined                                           infantry
# 30  doc2vec                                   patterson_mansion
#     word2vec                                               room
#     combined                                               room
# 31  doc2vec                                 exerodonta_catracha
#     word2vec                                                per
#     combined                                     rate_of_return
# 32  doc2vec                               fauna_of_saskatchewan
#     word2vec                                             rabbit
#     combined                                          wild_boar
# 33  doc2vec                           oxford_poetry_anthologies
# ...                                                         ...
# 194 combined                                     depolarization
# 195 doc2vec                                      carcinogenesis
#     word2vec                                        cancer_cell
#     combined                                     carcinogenesis
# 196 doc2vec                                          pedophilia
#     word2vec                                          addiction
#     combined                                  domestic_violence
# 197 doc2vec                                             sibling
#     word2vec                                    early_childhood
#     combined                                        foster_care
# 198 doc2vec                                           neurology
#     word2vec                                             clinic
#     combined                                     medical_school
# 199 doc2vec                                magnesium_in_biology
#     word2vec                                      intracellular
#     combined                                            cytosol
# 200 doc2vec                             central_venous_catheter
#     word2vec                                       percutaneous
#     combined                                     electrosurgery
# 201 doc2vec                                       prothionamide
#     word2vec                                            therapy
#     combined                                       chemotherapy
# 202 doc2vec                                      phytoandrogens
#     word2vec                                           efficacy
#     combined                                    bioavailability
# 203 doc2vec                           evidence_based_assessment
#     word2vec                                        measurement
#     combined                                    factor_analysis
# 204 doc2vec                                        hyperkalemia
#     word2vec                                            albumin
#     combined                                              urine
# 205 doc2vec                                multiple_morbidities
#     word2vec                                          prognosis
#     combined                                      heart_failure
# 206 doc2vec                                 diseases_of_poverty
#     word2vec                                    life_expectancy
#     combined                                     mortality_rate
# 207 doc2vec                                         etanidazole
#     word2vec                                   pharmacokinetics
#     combined                                           diazepam
# 208 doc2vec                                renal_cell_carcinoma
#     word2vec                                       asymptomatic
#     combined                               renal_cell_carcinoma
# 209 doc2vec                             cellular_neural_network
#     word2vec                                      data_analysis
#     combined                                         simulation
# 210 doc2vec              selective_serotonin_reuptake_inhibitor
#     word2vec                                            therapy
#     combined                                            placebo
# 211 doc2vec                                    activated_carbon
#     word2vec                                             liquid
#     combined                                        water_vapor
# 212 doc2vec                                     carbon_nanotube
#     word2vec                                         adsorption
#     combined                                           graphene
# 213 doc2vec                                predictive_analytics
#     word2vec                                        measurement
#     combined                                        time_series
# 214 doc2vec                               mycoplasma_capricolum
#     word2vec                                    diagnostic_test
#     combined                                         blood_test
# 215 doc2vec                                    sleep_and_memory
#     word2vec                                            example
#     combined                                     working_memory
# 216 doc2vec                                          fusariosis
#     word2vec                                            therapy
#     combined                                          prognosis
# 217 doc2vec                                           mucositis
#     word2vec                                       inflammation
#     combined                                       chemotherapy
# 218 doc2vec                                    sleep_and_memory
#     word2vec                                          cognition
#     combined                                  prefrontal_cortex
# 219 doc2vec   critical_illness-related_corticosteroid_insuff...
#     word2vec                                     susceptibility
#     combined                                          biomarker
# 220 doc2vec                                          stretching
#     word2vec                                   physical_fitness
#     combined                                  physical_exercise
# 221 doc2vec                                  image_segmentation
#     word2vec                                               data
#     combined                       principal_component_analysis
# 222 doc2vec                                      carbon_dioxide
#     word2vec                                        evaporation
#     combined                                               urea
# 223 doc2vec                  external_morphology_of_lepidoptera
#     word2vec                                           the_eggs
#     combined                                           nematode
# 224 doc2vec                                     minority_stress
#     word2vec                                    social_behavior
#     combined                                        adolescence
# 225 doc2vec                                   lateral_computing
#     word2vec                                             system
#     combined                                          structure
# 226 doc2vec                  linear_least_squares_(mathematics)
#     word2vec                                               data
#     combined                                 standard_deviation
# 227 doc2vec                                italian_crested_newt
#     word2vec                                           leaching
#     combined                                        groundwater
#
#                                                label3  \
# 0   doc2vec                           cloud_computing
#     word2vec                               middleware
#     combined                      windows_server_2003
# 1   doc2vec   washington_gubernatorial_election,_1984
#     word2vec                               john_kerry
#     combined                             barack_obama
# 2   doc2vec                     microsoft_office_live
#     word2vec                              web_browser
#     combined                             windows_2000
# 3   doc2vec                               asus_eee_pc
#     word2vec                              floppy_disk
#     combined                                      usb
# 4   doc2vec                             playstation_4
#     word2vec                            playstation_3
#     combined                              nintendo_ds
# 5   doc2vec                   vermont_elections,_2008
#     word2vec                                 election
#     combined                                 election
# 6   doc2vec                                 neurology
#     word2vec                             the_hospital
#     combined                          pain_management
# 7   doc2vec                           fried_aubergine
#     word2vec                                     soup
#     combined                                  dessert
# 8   doc2vec                       god_in_christianity
#     word2vec                                believers
#     combined                           sanctification
# 9   doc2vec                   hungary_at_the_olympics
#     word2vec                     2008_summer_olympics
#     combined                              asian_games
# 10  doc2vec   washington_gubernatorial_election,_1980
#     word2vec                      lieutenant_governor
#     combined                    conservative_democrat
# 11  doc2vec                      painted_tiger_parrot
#     word2vec                                    white
#     combined                                   purple
# 12  doc2vec                      european_debt_crisis
#     word2vec                              refinancing
#     combined                                citigroup
# 13  doc2vec                               weight_loss
#     word2vec                              weight_loss
#     combined                                   eating
# 14  doc2vec                            detroit-oxford
#     word2vec                                     axle
#     combined                                transaxle
# 15  doc2vec                                social_web
#     word2vec                                 internet
#     combined                                  web_2.0
# 16  doc2vec                          hydrogen_economy
#     word2vec                                petroleum
#     combined                    liquefied_natural_gas
# 17  doc2vec                            carcinogenesis
#     word2vec                             gene_product
#     combined                          dna_methylation
# 18  doc2vec                                     gmail
#     word2vec                               mobile_app
#     combined                              google_play
# 19  doc2vec                         heavy_metal_music
#     word2vec                                the_music
#     combined                              guitar_solo
# 20  doc2vec                              lew_graulich
#     word2vec                                  shutout
#     combined                                no-hitter
# 21  doc2vec                                    incest
#     word2vec                                    uncle
#     combined                                   mother
# 22  doc2vec                        judiciary_of_texas
#     word2vec                            federal_court
#     combined                         attorney_general
# 23  doc2vec                                underpants
#     word2vec                            black_leather
#     combined                           shoulder_strap
# 24  doc2vec                    education_in_singapore
#     word2vec                                  college
#     combined                                education
# 25  doc2vec                          one-game_playoff
#     word2vec                                   season
#     combined                             championship
# 26  doc2vec                                 san_diego
#     word2vec                                      del
#     combined                              san_antonio
# 27  doc2vec                              antique_shop
#     word2vec                                   bought
#     combined                               purchasing
# 28  doc2vec                     teamquest_corporation
#     word2vec                            manufacturing
#     combined                        technical_support
# 29  doc2vec                            aerial_warfare
#     word2vec                                artillery
#     combined                                  cavalry
# 30  doc2vec                    russell_hall_(georgia)
#     word2vec                         the_second_floor
#     combined                                 bathroom
# 31  doc2vec                    kalophrynus_bunguranus
#     word2vec                               per_capita
#     combined                   gross_domestic_product
# 32  doc2vec                             atikonak_lake
#     word2vec                                   animal
#     combined                                      pig
# 33  doc2vec                palgrave's_golden_treasury
# ...                                               ...
# 194 combined                                  cytosol
# 195 doc2vec                       biochemical_cascade
#     word2vec                          gene_expression
#     combined                                 survivin
# 196 doc2vec                                     abuse
#     word2vec                       sexual_intercourse
#     combined                       child_sexual_abuse
# 197 doc2vec                  developmental_psychology
#     word2vec                                childhood
#     combined                                  sibling
# 198 doc2vec                      pediatric_psychology
#     word2vec                        medical_education
#     combined                                neurology
# 199 doc2vec                   vectors_in_gene_therapy
#     word2vec                               metabolism
#     combined                                    lipid
# 200 doc2vec                               metroplasty
#     word2vec                                  cannula
#     combined                                  cannula
# 201 doc2vec                                lorglumide
#     word2vec                                 efficacy
#     combined                            antipsychotic
# 202 doc2vec                          laboratory_mouse
#     word2vec                                  in_vivo
#     combined                               neurotoxin
# 203 doc2vec                           factor_analysis
#     word2vec                                 analysis
#     combined                            psychometrics
# 204 doc2vec                          diabetes_in_dogs
#     word2vec                                excretion
#     combined                                potassium
# 205 doc2vec                            cardiac_asthma
#     word2vec                           mortality_rate
#     combined                                 dementia
# 206 doc2vec                            maternal_death
#     word2vec                           incidence_rate
#     combined                               birth_rate
# 207 doc2vec                                 methadone
#     word2vec                                 toxicity
#     combined                                bupropion
# 208 doc2vec                               sarcoidosis
#     word2vec                            abnormalities
#     combined                              sarcoidosis
# 209 doc2vec     computer-aided_production_engineering
#     word2vec                                 software
#     combined            geographic_information_system
# 210 doc2vec                          autism_therapies
#     word2vec                             chemotherapy
#     combined                          pain_management
# 211 doc2vec                               abiogenesis
#     word2vec                             condensation
#     combined                          silicon_dioxide
# 212 doc2vec                              nanoparticle
#     word2vec                                 molecule
#     combined                               adsorption
# 213 doc2vec                          spatial_analysis
#     word2vec                                 data_set
#     combined                     sensitivity_analysis
# 214 doc2vec                                    cyb561
#     word2vec              sensitivity_and_specificity
#     combined                                 serology
# 215 doc2vec                                     lc4mp
#     word2vec                                  context
#     combined                              habituation
# 216 doc2vec                            ovarian_cancer
#     word2vec                   differential_diagnosis
#     combined                          diagnostic_test
# 217 doc2vec                     dermatitis_gangrenosa
#     word2vec                            anticoagulant
#     combined                                mucositis
# 218 doc2vec                            spatial_memory
#     word2vec                        prefrontal_cortex
#     combined                           spatial_memory
# 219 doc2vec                             aminoaciduria
#     word2vec                                    human
#     combined                                 cortisol
# 220 doc2vec                         strength_training
#     word2vec                               capability
#     combined                          skeletal_muscle
# 221 doc2vec                        k-means_clustering
#     word2vec                               particular
#     combined                            data_analysis
# 222 doc2vec                          activated_carbon
#     word2vec                                   effect
#     combined                                 nitrogen
# 223 doc2vec                                     aphid
#     word2vec                                   thrips
# ...
#     combined                                    forceps
# 201 doc2vec                                  milacemide
#     word2vec                            pain_management
#     combined                                  addiction
# 202 doc2vec                                  fluparoxan
#     word2vec                             anticonvulsant
#     combined                             adverse_effect
# 203 doc2vec       behavioral_health_outcomes_management
#     word2vec                                     tested
#     combined                           personality_test
# 204 doc2vec                               microdialysis
#     word2vec                                   antibody
#     combined                                blood_sugar
# 205 doc2vec                  propofol_infusion_syndrome
#     word2vec                                   dementia
#     combined                    acute_coronary_syndrome
# 206 doc2vec                            infant_mortality
#     word2vec                               malnutrition
#     combined                       total_fertility_rate
# 207 doc2vec                                 vitamin_b12
#     word2vec                                  excretion
#     combined                                  estradiol
# 208 doc2vec                             dermatomyositis
#     word2vec                                  granuloma
#     combined                                   melanoma
# 209 doc2vec      product_software_implementation_method
#     word2vec                                  usability
#     combined                            data_collection
# 210 doc2vec                         hairy_cell_leukemia
#     word2vec                                    relapse
#     combined                                    therapy
# 211 doc2vec                            radiation_damage
#     word2vec                            sodium_chloride
#     combined                                       urea
# 212 doc2vec                         model_lipid_bilayer
#     word2vec                                  viscosity
#     combined                                  monolayer
# 213 doc2vec                            team_composition
#     word2vec                                 estimation
#     combined                                  causality
# 214 doc2vec                                      chst11
#     word2vec                                     sputum
#     combined                            genetic_testing
# 215 doc2vec                        central_facial_palsy
#     word2vec                              reaction_time
#     combined                          visual_perception
# 216 doc2vec                            adjuvant_therapy
#     word2vec                                 malignancy
#     combined                                     cancer
# 217 doc2vec                      impetigo_herpetiformis
#     word2vec                                     dosing
#     combined                                  ibuprofen
# 218 doc2vec                               consciousness
#     word2vec                             neurocognitive
#     combined                        executive_functions
# 219 doc2vec                  propofol_infusion_syndrome
#     word2vec                             responsiveness
#     combined                                      human
# 220 doc2vec                  591st_bombardment_squadron
#     word2vec                                  alertness
#     combined                           body_composition
# 221 doc2vec                        sensitivity_analysis
#     word2vec                                     system
#     combined                                     system
# 222 doc2vec            environmental_impact_of_concrete
#     word2vec                                    sulfate
#     combined                            bioavailability
# 223 doc2vec                 ophryocystis_elektroscirrha
#     word2vec                                   organism
#     combined                       asexual_reproduction
# 224 doc2vec                                 adolescence
#     word2vec                              social_skills
#     combined                     psychological_research
# 225 doc2vec                     cellular_neural_network
#     word2vec                                       form
#     combined                                  principle
# 226 doc2vec                               kalman_filter
#     word2vec                                 stochastic
#     combined                                  power_law
# 227 doc2vec                        wastewater_treatment
#     word2vec                                   salinity
#     combined                             eutrophication
#
#                                              label18
# 0   doc2vec                                      xen
#     word2vec                             scalability
#     combined                              postgresql
# 1   doc2vec                texas_senate,_district_16
#     word2vec                           state_senator
#     combined                          lindsey_graham
# 2   doc2vec                      red5_(media_server)
#     word2vec                       internet_explorer
#     combined                                    os_x
# 3   doc2vec                           expansion_card
#     word2vec                                  eeprom
#     combined                        operating_system
# 4   doc2vec                           nintendo_eshop
#     word2vec                                    sega
#     combined                                    xbox
# 5   doc2vec             swiss_federal_election,_1951
#     word2vec                           state_senator
#     combined                     leadership_election
# 6   doc2vec                           patient_safety
#     word2vec                            neurosurgery
#     combined                            primary_care
# 7   doc2vec                                  skirlie
#     word2vec                                   broth
#     combined                          barbecue_sauce
# 8   doc2vec                              catholicism
#     word2vec                        john_the_baptist
#     combined                   resurrection_of_jesus
# 9   doc2vec                    china_at_the_olympics
#     word2vec                    1988_summer_olympics
#     combined                      commonwealth_games
# 10  doc2vec     montana_gubernatorial_election,_2008
#     word2vec                   president_pro_tempore
#     combined           democratic_national_committee
# 11  doc2vec                        white-lipped_frog
#     word2vec                                   brown
#     combined                        shades_of_yellow
# 12  doc2vec                                    cedel
#     word2vec                            money_market
#     combined                             refinancing
# 13  doc2vec                         equine_nutrition
#     word2vec                        body_composition
#     combined                      dietary_supplement
# 14  doc2vec                       castoldi_(company)
#     word2vec                               the_front
#     combined                    pusher_configuration
# 15  doc2vec                                 internet
#     word2vec                               home_page
#     combined                              mobile_app
# 16  doc2vec                  renewable_energy_debate
#     word2vec                            cogeneration
#     combined                        alternative_fuel
# 17  doc2vec                      ceramide_synthase_4
#     word2vec                         dna_methylation
#     combined                         tyrosine_kinase
# 18  doc2vec                     multisync_(software)
#     word2vec                           windows_phone
#     combined                 mobile_operating_system
# 19  doc2vec                                 younique
#     word2vec                                musician
#     combined                           american_rock
# 20  doc2vec                               roy_corhan
#     word2vec                           all-star_game
#     combined                        starting_pitcher
# 21  doc2vec                      sisters_(tv_series)
#     word2vec                            two_brothers
#     combined                              son-in-law
# 22  doc2vec                         richard_malanjum
#     word2vec                                  lawyer
#     combined                              common_law
# 23  doc2vec                                 backpack
#     word2vec                                 padding
#     combined                               the_waist
# 24  doc2vec                    astronaut_high_school
#     word2vec                            of_education
#     combined                                 teacher
# 25  doc2vec        national_football_league_playoffs
#     word2vec                           football_team
#     combined                                    game
# 26  doc2vec                        los_angeles_salsa
#     word2vec                                    2002
#     combined                                 eduardo
# 27  doc2vec                         buffalo_exchange
#     word2vec                                customer
#     combined                          hardware_store
# 28  doc2vec              computer_business_solutions
#     word2vec                       management_system
#     combined                             engineering
# 29  doc2vec   45th_infantry_division_(united_states)
#     word2vec                                 militia
#     combined                             air_assault
# 30  doc2vec                           sandburg_halls
#     word2vec                                    hall
#     combined                                  closet
# 31  doc2vec                    ruddy_tody-flycatcher
#     word2vec                                   ratio
#     combined                             value_added
# 32  doc2vec             tiilikkajÃ¤rvi_national_park
#     word2vec                                squirrel
#     combined                                crayfish
# 33  doc2vec                          robert_wolveden
# ...                                              ...
# 194 combined                           acetylcholine
# 195 doc2vec                         arsenic_toxicity
#     word2vec                             hyperplasia
#     combined                            inflammation
# 196 doc2vec           female_sexual_arousal_disorder
#     word2vec                   recreational_drug_use
#     combined                                  incest
# 197 doc2vec              school-based_health_centers
#     word2vec                             foster_care
#     combined                                 toddler
# 198 doc2vec                          teaching_clinic
#     word2vec                          medical_degree
#     combined                            primary_care
# 199 doc2vec                          hypoxia_in_fish
#     word2vec                        active_transport
#     combined                        oxidative_stress
# 200 doc2vec                          vascular_bypass
#     word2vec                              be_used_to
#     combined                                 syringe
# 201 doc2vec                  antimalarial_medication
#     word2vec                       smoking_cessation
#     combined                           schizophrenia
# 202 doc2vec                               lorglumide
#     word2vec                       immunosuppression
#     combined                              anesthetic
# 203 doc2vec                      body_attitudes_test
#     word2vec                      standard_deviation
#     combined                      standard_deviation
# 204 doc2vec                      human_serum_albumin
#     word2vec                                 insulin
#     combined                             vitamin_b12
# 205 doc2vec   selective_serotonin_reuptake_inhibitor
#     word2vec                             the_patient
#     combined                     acute_liver_failure
# 206 doc2vec                          race_and_health
#     word2vec                               estimates
#     combined                           relative_risk
# 207 doc2vec                           benzodiazepine
#     word2vec                                efficacy
#     combined                              amiodarone
# 208 doc2vec        neuroendocrine_adenoma_middle_ear
#     word2vec                               infection
#     combined                                 adenoma
# 209 doc2vec                                usability
#     word2vec                             interfacing
#     combined                                computer
# 210 doc2vec                                virechana
#     word2vec                                efficacy
#     combined                              tapentadol
# 211 doc2vec                      supercritical_fluid
#     word2vec                          vapor_pressure
#     combined                     properties_of_water
# 212 doc2vec                        acoustic_tweezers
#     word2vec                           particle_size
#     combined                              surfactant
# 213 doc2vec                     item_response_theory
#     word2vec                                 example
#     combined                     logistic_regression
# 214 doc2vec      real-time_polymerase_chain_reaction
#     word2vec                                 albumin
#     combined                                 albumin
# 215 doc2vec       neural_correlates_of_consciousness
#     word2vec                              phenomenon
#     combined                           visual_memory
# 216 doc2vec                                 amphinex
#     word2vec                             the_patient
#     combined                       medical_diagnosis
# 217 doc2vec                     paracetamol_toxicity
#     word2vec                                systemic
#     combined                          corticosteroid
# 218 doc2vec                                   memory
#     word2vec                           motor_control
#     combined                         episodic_memory
# 219 doc2vec                    acanthocheilonemiasis
#     word2vec                           hyperglycemia
#     combined                           immune_system
# 220 doc2vec                    split_jump_(exercise)
#     word2vec                               stiffness
#     combined                         range_of_motion
# 221 doc2vec               discrete_fourier_transform
#     word2vec                              be_used_to
#     combined                        machine_learning
# 222 doc2vec                      properties_of_water
#     word2vec                           reaction_rate
#     combined                              alkalinity
# 223 doc2vec                               parasitism
#     word2vec                            invertebrate
#     combined                       sperm_competition
# 224 doc2vec                            child_neglect
#     word2vec                        social_isolation
#     combined                              well-being
# 225 doc2vec                     gasteranthus_timidus
#     word2vec                                    tool
#     combined                                dynamics
# 226 doc2vec        estimation_of_covariance_matrices
#     word2vec                                variance
#     combined                           data_analysis
# 227 doc2vec                     total_organic_carbon
#     word2vec                             evaporation
#     combined                                leaching
#
# [684 rows x 19 columns]

# %%
logger.info(f'Writing labels to {labels_file}')
labels.to_csv(labels_file + '.csv')
# Out:
# 2018-11-17 02:34:00,734 : INFO : Writing labels to NETL/model_run/output_candidates_topics_gen35_newimp
