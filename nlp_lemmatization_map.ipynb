# %%
from constants import DATA_BASE, ETL_PATH, DATASETS
from utils import load
import pandas as pd
from os import listdir
from os.path import isfile, join
import json
import re
import gc
from etl_wikipedia import split_title
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()

# %% [markdown]
# -----
#
# ### Create a lemmatization map from Wiktionary data
#
# (parsed by IWNLP wiktionary-parser)

# %%
iwnlp_file = join(DATA_BASE, 'IWNLP.Lemmatizer_20170501.json')
with open(iwnlp_file, 'r') as fp:
    iwnlp = json.load(fp)
    
iwnlp
# Out:
# [{'Form': 'hallo',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hallo', 'Lemma': 'Hallo'},
#    {'POS': 'X', 'Form': 'hallo', 'Lemma': 'hallo'}]},
#  {'Form': 'hallos',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hallos', 'Lemma': 'Hallo'}]},
#  {'Form': 'subfamilia',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subfamilia', 'Lemma': 'Subfamilia'}]},
#  {'Form': 'subfamiliae',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subfamiliae', 'Lemma': 'Subfamilia'}]},
#  {'Form': 'subregnum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subregnum', 'Lemma': 'Subregnum'}]},
#  {'Form': 'subregna',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subregna', 'Lemma': 'Subregnum'}]},
#  {'Form': 'subregnums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subregnums', 'Lemma': 'Subregnum'}]},
#  {'Form': 'subdivisio',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subdivisio', 'Lemma': 'Subdivisio'}]},
#  {'Form': 'subdivisiones',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subdivisiones', 'Lemma': 'Subdivisio'}]},
#  {'Form': 'phylum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Phylum', 'Lemma': 'Phylum'}]},
#  {'Form': 'phyla',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Phyla', 'Lemma': 'Phylum'}]},
#  {'Form': 'phylums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Phylums', 'Lemma': 'Phylum'}]},
#  {'Form': 'superphylum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Superphylum', 'Lemma': 'Superphylum'}]},
#  {'Form': 'superphyla',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Superphyla', 'Lemma': 'Superphylum'}]},
#  {'Form': 'superphylums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Superphylums', 'Lemma': 'Superphylum'}]},
#  {'Form': 'subphylum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subphylum', 'Lemma': 'Subphylum'}]},
#  {'Form': 'subphyla',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subphyla', 'Lemma': 'Subphylum'}]},
#  {'Form': 'subordo',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subordo', 'Lemma': 'Subordo'}]},
#  {'Form': 'subordines',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subordines', 'Lemma': 'Subordo'}]},
#  {'Form': 'subgenus',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subgenus', 'Lemma': 'Subgenus'}]},
#  {'Form': 'subgenera',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subgenera', 'Lemma': 'Subgenus'}]},
#  {'Form': 'subspezies',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Subspezies', 'Lemma': 'Subspezies'}]},
#  {'Form': 'varietas',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Varietas', 'Lemma': 'Varietas'}]},
#  {'Form': 'varietates',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Varietates', 'Lemma': 'Varietas'}]},
#  {'Form': 'tribus',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tribus', 'Lemma': 'Tribus'}]},
#  {'Form': 'triben',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Triben', 'Lemma': 'Tribus'}]},
#  {'Form': 'infraordo',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Infraordo', 'Lemma': 'Infraordo'}]},
#  {'Form': 'infraordines',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Infraordines', 'Lemma': 'Infraordo'}]},
#  {'Form': 'dezember',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Dezember', 'Lemma': 'Dezember'}]},
#  {'Form': 'dezembers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Dezembers', 'Lemma': 'Dezember'}]},
#  {'Form': 'dezembern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Dezembern', 'Lemma': 'Dezember'}]},
#  {'Form': 'januar',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Januar', 'Lemma': 'Januar'}]},
#  {'Form': 'januare',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Januare', 'Lemma': 'Januar'}]},
#  {'Form': 'januars',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Januars', 'Lemma': 'Januar'}]},
#  {'Form': 'januaren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Januaren', 'Lemma': 'Januar'}]},
#  {'Form': 'februar',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Februar', 'Lemma': 'Februar'}]},
#  {'Form': 'februare',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Februare', 'Lemma': 'Februar'}]},
#  {'Form': 'februars',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Februars', 'Lemma': 'Februar'}]},
#  {'Form': 'februaren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Februaren', 'Lemma': 'Februar'}]},
#  {'Form': 'märz',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'März', 'Lemma': 'März'}]},
#  {'Form': 'märze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Märze', 'Lemma': 'März'}]},
#  {'Form': 'märzes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Märzes', 'Lemma': 'März'}]},
#  {'Form': 'märzen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Märzen', 'Lemma': 'März'}]},
#  {'Form': 'april',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'April', 'Lemma': 'April'}]},
#  {'Form': 'aprile',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aprile', 'Lemma': 'April'}]},
#  {'Form': 'aprils',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aprils', 'Lemma': 'April'}]},
#  {'Form': 'aprilen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aprilen', 'Lemma': 'April'}]},
#  {'Form': 'mai', 'Lemmas': [{'POS': 'Noun', 'Form': 'Mai', 'Lemma': 'Mai'}]},
#  {'Form': 'maie', 'Lemmas': [{'POS': 'Noun', 'Form': 'Maie', 'Lemma': 'Mai'}]},
#  {'Form': 'mais',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mais', 'Lemma': 'Mai'},
#    {'POS': 'Noun', 'Form': 'Mais', 'Lemma': 'Mais'}]},
#  {'Form': 'maien',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Maien', 'Lemma': 'Mai'}]},
#  {'Form': 'juni',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Juni', 'Lemma': 'Juni'}]},
#  {'Form': 'junis',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Junis', 'Lemma': 'Juni'}]},
#  {'Form': 'juli',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Juli', 'Lemma': 'Juli'}]},
#  {'Form': 'julis',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Julis', 'Lemma': 'Juli'}]},
#  {'Form': 'august',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'August', 'Lemma': 'August'}]},
#  {'Form': 'auguste',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Auguste', 'Lemma': 'August'}]},
#  {'Form': 'augusts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Augusts', 'Lemma': 'August'}]},
#  {'Form': 'augustes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Augustes', 'Lemma': 'August'}]},
#  {'Form': 'augusten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Augusten', 'Lemma': 'August'}]},
#  {'Form': 'september',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'September', 'Lemma': 'September'}]},
#  {'Form': 'septembers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Septembers', 'Lemma': 'September'}]},
#  {'Form': 'septembern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Septembern', 'Lemma': 'September'}]},
#  {'Form': 'oktober',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Oktober', 'Lemma': 'Oktober'}]},
#  {'Form': 'oktobers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Oktobers', 'Lemma': 'Oktober'}]},
#  {'Form': 'oktobern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Oktobern', 'Lemma': 'Oktober'}]},
#  {'Form': 'november',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'November', 'Lemma': 'November'}]},
#  {'Form': 'novembers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Novembers', 'Lemma': 'November'}]},
#  {'Form': 'novembern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Novembern', 'Lemma': 'November'}]},
#  {'Form': 'ich',
#   'Lemmas': [{'POS': 'Pronoun', 'Form': 'ich', 'Lemma': 'ich'},
#    {'POS': 'Noun', 'Form': 'Ich', 'Lemma': 'Ich'}]},
#  {'Form': 'du',
#   'Lemmas': [{'POS': 'Pronoun', 'Form': 'du', 'Lemma': 'du'},
#    {'POS': 'Noun', 'Form': 'Du', 'Lemma': 'Du'},
#    {'POS': 'X', 'Form': 'DU', 'Lemma': 'DU'}]},
#  {'Form': 'lieben',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'lieben', 'Lemma': 'lieben'},
#    {'POS': 'Noun', 'Form': 'Lieben', 'Lemma': 'Liebe'},
#    {'POS': 'Adjective', 'Form': 'lieben', 'Lemma': 'lieb'}]},
#  {'Form': 'liebe',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'liebe', 'Lemma': 'lieben'},
#    {'POS': 'Noun', 'Form': 'Liebe', 'Lemma': 'Liebe'},
#    {'POS': 'Adjective', 'Form': 'liebe', 'Lemma': 'lieb'}]},
#  {'Form': 'liebst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'liebst', 'Lemma': 'lieben'}]},
#  {'Form': 'liebt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'liebt', 'Lemma': 'lieben'}]},
#  {'Form': 'liebte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'liebte', 'Lemma': 'lieben'}]},
#  {'Form': 'geliebt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'geliebt', 'Lemma': 'lieben'}]},
#  {'Form': 'milliarde',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Milliarde', 'Lemma': 'Milliarde'}]},
#  {'Form': 'milliarden',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Milliarden', 'Lemma': 'Milliarde'}]},
#  {'Form': 'billion',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Billion', 'Lemma': 'Billion'}]},
#  {'Form': 'billionen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Billionen', 'Lemma': 'Billion'}]},
#  {'Form': 'er',
#   'Lemmas': [{'POS': 'Pronoun', 'Form': 'er', 'Lemma': 'er'},
#    {'POS': 'Noun', 'Form': 'Er', 'Lemma': 'Er'},
#    {'POS': 'Pronoun', 'Form': 'Er', 'Lemma': 'Er'},
#    {'POS': 'X', 'Form': 'ER', 'Lemma': 'ER'}]},
#  {'Form': 'aal',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aal', 'Lemma': 'Aal'},
#    {'POS': 'Verb', 'Form': 'aal', 'Lemma': 'aalen'}]},
#  {'Form': 'aale',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aale', 'Lemma': 'Aal'},
#    {'POS': 'Verb', 'Form': 'aale', 'Lemma': 'aalen'}]},
#  {'Form': 'aals', 'Lemmas': [{'POS': 'Noun', 'Form': 'Aals', 'Lemma': 'Aal'}]},
#  {'Form': 'aales',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aales', 'Lemma': 'Aal'}]},
#  {'Form': 'aalen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aalen', 'Lemma': 'Aal'},
#    {'POS': 'Verb', 'Form': 'aalen', 'Lemma': 'aalen'}]},
#  {'Form': 'litschi',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Litschi', 'Lemma': 'Litschi'}]},
#  {'Form': 'litschis',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Litschis', 'Lemma': 'Litschi'}]},
#  {'Form': 'zitrone',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zitrone', 'Lemma': 'Zitrone'}]},
#  {'Form': 'zitronen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zitronen', 'Lemma': 'Zitrone'}]},
#  {'Form': 'pittoresk',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'pittoresk', 'Lemma': 'pittoresk'}]},
#  {'Form': 'pittoresker',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'pittoresker', 'Lemma': 'pittoresk'},
#    {'POS': 'X', 'Form': 'pittoresker', 'Lemma': 'pittoresker'}]},
#  {'Form': 'pittoreskesten',
#   'Lemmas': [{'POS': 'Adjective',
#     'Form': 'pittoreskesten',
#     'Lemma': 'pittoresk'},
#    {'POS': 'X', 'Form': 'pittoreskesten', 'Lemma': 'pittoreskesten'}]},
#  {'Form': 'mensch',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mensch', 'Lemma': 'Mensch'},
#    {'POS': 'X', 'Form': 'Mensch', 'Lemma': 'Mensch'},
#    {'POS': 'Pronoun', 'Form': 'mensch', 'Lemma': 'mensch'}]},
#  {'Form': 'menschen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Menschen', 'Lemma': 'Mensch'}]},
#  {'Form': 'menscher',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Menscher', 'Lemma': 'Mensch'}]},
#  {'Form': 'menschs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Menschs', 'Lemma': 'Mensch'}]},
#  {'Form': 'mensches',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mensches', 'Lemma': 'Mensch'}]},
#  {'Form': 'mensche',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mensche', 'Lemma': 'Mensch'}]},
#  {'Form': 'menschern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Menschern', 'Lemma': 'Mensch'}]},
#  {'Form': 'sein',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'sein', 'Lemma': 'sein'},
#    {'POS': 'Pronoun', 'Form': 'sein', 'Lemma': 'sein'},
#    {'POS': 'Noun', 'Form': 'Sein', 'Lemma': 'Sein'}]},
#  {'Form': 'gewesen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gewesen', 'Lemma': 'sein'},
#    {'POS': 'Adjective', 'Form': 'gewesen', 'Lemma': 'gewesen'},
#    {'POS': 'Noun', 'Form': 'Gewesen', 'Lemma': 'Gewese'}]},
#  {'Form': 'bin',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'bin', 'Lemma': 'sein'},
#    {'POS': 'X', 'Form': 'BIN', 'Lemma': 'BIN'}]},
#  {'Form': 'bist',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'bist', 'Lemma': 'sein'}]},
#  {'Form': 'ist',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'ist', 'Lemma': 'sein'},
#    {'POS': 'Noun', 'Form': 'Ist', 'Lemma': 'Ist'}]},
#  {'Form': 'sind',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'sind', 'Lemma': 'sein'}]},
#  {'Form': 'seid',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'seid', 'Lemma': 'sein'}]},
#  {'Form': 'war', 'Lemmas': [{'POS': 'Verb', 'Form': 'war', 'Lemma': 'sein'}]},
#  {'Form': 'warst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'warst', 'Lemma': 'sein'}]},
#  {'Form': 'waren',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'waren', 'Lemma': 'sein'},
#    {'POS': 'Noun', 'Form': 'Waren', 'Lemma': 'Ware'}]},
#  {'Form': 'wart',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wart', 'Lemma': 'sein'},
#    {'POS': 'Noun', 'Form': 'Wart', 'Lemma': 'Wart'}]},
#  {'Form': 'sei', 'Lemmas': [{'POS': 'Verb', 'Form': 'sei', 'Lemma': 'sein'}]},
#  {'Form': 'seiest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'seiest', 'Lemma': 'sein'}]},
#  {'Form': 'seist',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'seist', 'Lemma': 'sein'}]},
#  {'Form': 'seien',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'seien', 'Lemma': 'sein'}]},
#  {'Form': 'seiet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'seiet', 'Lemma': 'sein'}]},
#  {'Form': 'wäre',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wäre', 'Lemma': 'sein'}]},
#  {'Form': 'wärest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wärest', 'Lemma': 'sein'}]},
#  {'Form': 'wärst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wärst', 'Lemma': 'sein'}]},
#  {'Form': 'wären',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wären', 'Lemma': 'sein'}]},
#  {'Form': 'wäret',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wäret', 'Lemma': 'sein'}]},
#  {'Form': 'wärt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wärt', 'Lemma': 'sein'}]},
#  {'Form': 'machen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machen', 'Lemma': 'machen'}]},
#  {'Form': 'gemacht',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gemacht', 'Lemma': 'machen'}]},
#  {'Form': 'mache',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'mache', 'Lemma': 'machen'}]},
#  {'Form': 'machst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machst', 'Lemma': 'machen'}]},
#  {'Form': 'machest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machest', 'Lemma': 'machen'}]},
#  {'Form': 'macht',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'macht', 'Lemma': 'machen'},
#    {'POS': 'Noun', 'Form': 'Macht', 'Lemma': 'Macht'}]},
#  {'Form': 'machet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machet', 'Lemma': 'machen'}]},
#  {'Form': 'machte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machte', 'Lemma': 'machen'}]},
#  {'Form': 'machtest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machtest', 'Lemma': 'machen'}]},
#  {'Form': 'machten',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machten', 'Lemma': 'machen'}]},
#  {'Form': 'machtet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'machtet', 'Lemma': 'machen'}]},
#  {'Form': 'wiedersehen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wiedersehen', 'Lemma': 'Wiedersehen'},
#    {'POS': 'Verb', 'Form': 'wiedersehen', 'Lemma': 'wiedersehen'}]},
#  {'Form': 'wiedersehens',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wiedersehens', 'Lemma': 'Wiedersehen'}]},
#  {'Form': 'bank',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bank', 'Lemma': 'Bank'}]},
#  {'Form': 'bänke',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bänke', 'Lemma': 'Bank'}]},
#  {'Form': 'bänken',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bänken', 'Lemma': 'Bank'}]},
#  {'Form': 'banken',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Banken', 'Lemma': 'Bank'}]},
#  {'Form': 'wörterbuch',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbuch', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'wörterbücher',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbücher', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'wörterbuches',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbuches', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'wörterbuchs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbuchs', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'wörterbuche',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbuche', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'wörterbüchern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörterbüchern', 'Lemma': 'Wörterbuch'}]},
#  {'Form': 'fundort',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Fundort', 'Lemma': 'Fundort'}]},
#  {'Form': 'fundorte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Fundorte', 'Lemma': 'Fundort'}]},
#  {'Form': 'fundortes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Fundortes', 'Lemma': 'Fundort'}]},
#  {'Form': 'fundorts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Fundorts', 'Lemma': 'Fundort'}]},
#  {'Form': 'fundorten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Fundorten', 'Lemma': 'Fundort'}]},
#  {'Form': 'unterseeboot',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Unterseeboot',
#     'Lemma': 'Unterseeboot'}]},
#  {'Form': 'unterseeboote',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Unterseeboote',
#     'Lemma': 'Unterseeboot'}]},
#  {'Form': 'unterseebootes',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Unterseebootes',
#     'Lemma': 'Unterseeboot'}]},
#  {'Form': 'unterseeboots',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Unterseeboots',
#     'Lemma': 'Unterseeboot'}]},
#  {'Form': 'unterseebooten',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Unterseebooten',
#     'Lemma': 'Unterseeboot'}]},
#  {'Form': 'software',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Software', 'Lemma': 'Software'}]},
#  {'Form': 'softwares',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Softwares', 'Lemma': 'Software'}]},
#  {'Form': 'kind',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kind', 'Lemma': 'Kind'}]},
#  {'Form': 'kinder',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kinder', 'Lemma': 'Kind'}]},
#  {'Form': 'kindes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kindes', 'Lemma': 'Kind'}]},
#  {'Form': 'kinds',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kinds', 'Lemma': 'Kind'}]},
#  {'Form': 'kinde',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kinde', 'Lemma': 'Kind'}]},
#  {'Form': 'kindern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kindern', 'Lemma': 'Kind'}]},
#  {'Form': 'angebot',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Angebot', 'Lemma': 'Angebot'}]},
#  {'Form': 'angebote',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Angebote', 'Lemma': 'Angebot'}]},
#  {'Form': 'angebots',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Angebots', 'Lemma': 'Angebot'}]},
#  {'Form': 'angebotes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Angebotes', 'Lemma': 'Angebot'}]},
#  {'Form': 'angeboten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Angeboten', 'Lemma': 'Angebot'},
#    {'POS': 'Verb', 'Form': 'angeboten', 'Lemma': 'anbieten'}]},
#  {'Form': 'gelb',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gelb', 'Lemma': 'Gelb'},
#    {'POS': 'Adjective', 'Form': 'gelb', 'Lemma': 'gelb'}]},
#  {'Form': 'gelbs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gelbs', 'Lemma': 'Gelb'}]},
#  {'Form': 'gelbtöne',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gelbtöne', 'Lemma': 'Gelb'},
#    {'POS': 'Noun', 'Form': 'Gelbtöne', 'Lemma': 'Gelbton'}]},
#  {'Form': 'gelbtönen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gelbtönen', 'Lemma': 'Gelb'},
#    {'POS': 'Noun', 'Form': 'Gelbtönen', 'Lemma': 'Gelbton'}]},
#  {'Form': 'computer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Computer', 'Lemma': 'Computer'}]},
#  {'Form': 'computers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Computers', 'Lemma': 'Computer'}]},
#  {'Form': 'computern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Computern', 'Lemma': 'Computer'}]},
#  {'Form': 'wortschatz',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortschatz', 'Lemma': 'Wortschatz'}]},
#  {'Form': 'wortschätze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortschätze', 'Lemma': 'Wortschatz'}]},
#  {'Form': 'wortschatzes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortschatzes', 'Lemma': 'Wortschatz'}]},
#  {'Form': 'wortschatze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortschatze', 'Lemma': 'Wortschatz'}]},
#  {'Form': 'wortschätzen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortschätzen', 'Lemma': 'Wortschatz'}]},
#  {'Form': 'intention',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Intention', 'Lemma': 'Intention'}]},
#  {'Form': 'intentionen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Intentionen', 'Lemma': 'Intention'}]},
#  {'Form': 'infinitesimal',
#   'Lemmas': [{'POS': 'Adjective',
#     'Form': 'infinitesimal',
#     'Lemma': 'infinitesimal'}]},
#  {'Form': 'lieb',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'lieb', 'Lemma': 'lieb'}]},
#  {'Form': 'lieber',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'lieber', 'Lemma': 'lieb'},
#    {'POS': 'X', 'Form': 'lieber', 'Lemma': 'lieber'}]},
#  {'Form': 'liebsten',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'liebsten', 'Lemma': 'lieb'},
#    {'POS': 'X', 'Form': 'liebsten', 'Lemma': 'liebsten'}]},
#  {'Form': 'esperanto',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Esperanto', 'Lemma': 'Esperanto'}]},
#  {'Form': 'esperantos',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Esperantos', 'Lemma': 'Esperanto'}]},
#  {'Form': 'imponderabilie',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Imponderabilie',
#     'Lemma': 'Imponderabilie'}]},
#  {'Form': 'imponderabilien',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Imponderabilien',
#     'Lemma': 'Imponderabilie'}]},
#  {'Form': 'krieg',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Krieg', 'Lemma': 'Krieg'},
#    {'POS': 'Verb', 'Form': 'krieg', 'Lemma': 'kriegen'}]},
#  {'Form': 'kriege',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kriege', 'Lemma': 'Krieg'},
#    {'POS': 'Verb', 'Form': 'kriege', 'Lemma': 'kriegen'}]},
#  {'Form': 'krieges',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Krieges', 'Lemma': 'Krieg'}]},
#  {'Form': 'kriegs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kriegs', 'Lemma': 'Krieg'}]},
#  {'Form': 'kriegen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kriegen', 'Lemma': 'Krieg'},
#    {'POS': 'Noun', 'Form': 'Kriegen', 'Lemma': 'Kriegen'},
#    {'POS': 'Verb', 'Form': 'kriegen', 'Lemma': 'kriegen'}]},
#  {'Form': 'feuer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Feuer', 'Lemma': 'Feuer'},
#    {'POS': 'Verb', 'Form': 'feuer', 'Lemma': 'feuern'}]},
#  {'Form': 'feuers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Feuers', 'Lemma': 'Feuer'}]},
#  {'Form': 'feuern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Feuern', 'Lemma': 'Feuer'},
#    {'POS': 'Verb', 'Form': 'feuern', 'Lemma': 'feuern'}]},
#  {'Form': 'hammer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hammer', 'Lemma': 'Hammer'},
#    {'POS': 'Adjective', 'Form': 'Hammer', 'Lemma': 'Hammer'}]},
#  {'Form': 'hämmer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hämmer', 'Lemma': 'Hammer'},
#    {'POS': 'Verb', 'Form': 'hämmer', 'Lemma': 'hämmern'}]},
#  {'Form': 'hammers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hammers', 'Lemma': 'Hammer'}]},
#  {'Form': 'hämmern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hämmern', 'Lemma': 'Hammer'},
#    {'POS': 'Verb', 'Form': 'hämmern', 'Lemma': 'hämmern'}]},
#  {'Form': 'hammern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hammern', 'Lemma': 'Hammer'}]},
#  {'Form': 'montag',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Montag', 'Lemma': 'Montag'}]},
#  {'Form': 'montage',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Montage', 'Lemma': 'Montag'},
#    {'POS': 'Noun', 'Form': 'Montage', 'Lemma': 'Montage'}]},
#  {'Form': 'montags',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Montags', 'Lemma': 'Montag'},
#    {'POS': 'X', 'Form': 'montags', 'Lemma': 'montags'}]},
#  {'Form': 'montages',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Montages', 'Lemma': 'Montag'}]},
#  {'Form': 'montagen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Montagen', 'Lemma': 'Montag'},
#    {'POS': 'Noun', 'Form': 'Montagen', 'Lemma': 'Montage'}]},
#  {'Form': 'hahn',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hahn', 'Lemma': 'Hahn'}]},
#  {'Form': 'hähne',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hähne', 'Lemma': 'Hahn'}]},
#  {'Form': 'hahnes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hahnes', 'Lemma': 'Hahn'}]},
#  {'Form': 'hahns',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hahns', 'Lemma': 'Hahn'}]},
#  {'Form': 'hahne',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hahne', 'Lemma': 'Hahn'}]},
#  {'Form': 'hähnen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hähnen', 'Lemma': 'Hahn'}]},
#  {'Form': 'klöppel',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klöppel', 'Lemma': 'Klöppel'},
#    {'POS': 'Verb', 'Form': 'klöppel', 'Lemma': 'klöppeln'}]},
#  {'Form': 'klöppels',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klöppels', 'Lemma': 'Klöppel'}]},
#  {'Form': 'klöppeln',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klöppeln', 'Lemma': 'Klöppel'},
#    {'POS': 'Verb', 'Form': 'klöppeln', 'Lemma': 'klöppeln'}]},
#  {'Form': 'hand',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hand', 'Lemma': 'Hand'}]},
#  {'Form': 'hände',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hände', 'Lemma': 'Hand'}]},
#  {'Form': 'händen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Händen', 'Lemma': 'Hand'}]},
#  {'Form': 'wort',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wort', 'Lemma': 'Wort'}]},
#  {'Form': 'wörter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörter', 'Lemma': 'Wort'}]},
#  {'Form': 'worts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Worts', 'Lemma': 'Wort'}]},
#  {'Form': 'wortes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wortes', 'Lemma': 'Wort'}]},
#  {'Form': 'worte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Worte', 'Lemma': 'Wort'}]},
#  {'Form': 'wörtern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wörtern', 'Lemma': 'Wort'}]},
#  {'Form': 'worten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Worten', 'Lemma': 'Wort'}]},
#  {'Form': 'niederländisch',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Niederländisch',
#     'Lemma': 'Niederländisch'},
#    {'POS': 'Adjective', 'Form': 'niederländisch', 'Lemma': 'niederländisch'}]},
#  {'Form': 'niederländische',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Niederländische',
#     'Lemma': 'Niederländisch'},
#    {'POS': 'Adjective',
#     'Form': 'niederländische',
#     'Lemma': 'niederländisch'}]},
#  {'Form': 'niederländischs',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Niederländischs',
#     'Lemma': 'Niederländisch'}]},
#  {'Form': 'niederländischen',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Niederländischen',
#     'Lemma': 'Niederländisch'},
#    {'POS': 'Adjective',
#     'Form': 'niederländischen',
#     'Lemma': 'niederländisch'}]},
#  {'Form': 'klieben',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'klieben', 'Lemma': 'klieben'}]},
#  {'Form': 'kliebe',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kliebe', 'Lemma': 'klieben'}]},
#  {'Form': 'kliebst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kliebst', 'Lemma': 'klieben'}]},
#  {'Form': 'kliebt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kliebt', 'Lemma': 'klieben'}]},
#  {'Form': 'klob',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'klob', 'Lemma': 'klieben'}]},
#  {'Form': 'kliebte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kliebte', 'Lemma': 'klieben'}]},
#  {'Form': 'klöbe',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'klöbe', 'Lemma': 'klieben'}]},
#  {'Form': 'gekloben',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gekloben', 'Lemma': 'klieben'}]},
#  {'Form': 'gekliebt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gekliebt', 'Lemma': 'klieben'}]},
#  {'Form': 'belfern',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'belfern', 'Lemma': 'belfern'}]},
#  {'Form': 'belfere',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'belfere', 'Lemma': 'belfern'}]},
#  {'Form': 'belferst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'belferst', 'Lemma': 'belfern'}]},
#  {'Form': 'belfert',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'belfert', 'Lemma': 'belfern'}]},
#  {'Form': 'belferte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'belferte', 'Lemma': 'belfern'}]},
#  {'Form': 'gebelfert',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gebelfert', 'Lemma': 'belfern'}]},
#  {'Form': 'mutter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mutter', 'Lemma': 'Mutter'}]},
#  {'Form': 'mütter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mütter', 'Lemma': 'Mutter'}]},
#  {'Form': 'müttern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Müttern', 'Lemma': 'Mutter'}]},
#  {'Form': 'muttern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Muttern', 'Lemma': 'Mutter'}]},
#  {'Form': 'buch',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Buch', 'Lemma': 'Buch'},
#    {'POS': 'Verb', 'Form': 'buch', 'Lemma': 'buchen'}]},
#  {'Form': 'bücher',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bücher', 'Lemma': 'Buch'}]},
#  {'Form': 'buchs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Buchs', 'Lemma': 'Buch'},
#    {'POS': 'Noun', 'Form': 'Buchs', 'Lemma': 'Buchs'}]},
#  {'Form': 'buches',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Buches', 'Lemma': 'Buch'}]},
#  {'Form': 'buche',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Buche', 'Lemma': 'Buch'},
#    {'POS': 'Noun', 'Form': 'Buche', 'Lemma': 'Buche'},
#    {'POS': 'Verb', 'Form': 'buche', 'Lemma': 'buchen'}]},
#  {'Form': 'büchern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Büchern', 'Lemma': 'Buch'}]},
#  {'Form': 'see', 'Lemmas': [{'POS': 'Noun', 'Form': 'See', 'Lemma': 'See'}]},
#  {'Form': 'seen', 'Lemmas': [{'POS': 'Noun', 'Form': 'Seen', 'Lemma': 'See'}]},
#  {'Form': 'sees', 'Lemmas': [{'POS': 'Noun', 'Form': 'Sees', 'Lemma': 'See'}]},
#  {'Form': 'hi',
#   'Lemmas': [{'POS': 'X', 'Form': 'HI', 'Lemma': 'HI'},
#    {'POS': 'X', 'Form': 'hi', 'Lemma': 'hi'}]},
#  {'Form': 'boot',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Boot', 'Lemma': 'Boot'},
#    {'POS': 'Verb', 'Form': 'boot', 'Lemma': 'booten'}]},
#  {'Form': 'boote',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Boote', 'Lemma': 'Boot'},
#    {'POS': 'Verb', 'Form': 'boote', 'Lemma': 'booten'}]},
#  {'Form': 'böte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Böte', 'Lemma': 'Boot'},
#    {'POS': 'Verb', 'Form': 'böte', 'Lemma': 'bieten'}]},
#  {'Form': 'boots',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Boots', 'Lemma': 'Boot'}]},
#  {'Form': 'bootes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bootes', 'Lemma': 'Boot'}]},
#  {'Form': 'booten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Booten', 'Lemma': 'Boot'},
#    {'POS': 'Verb', 'Form': 'booten', 'Lemma': 'booten'}]},
#  {'Form': 'böten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Böten', 'Lemma': 'Boot'},
#    {'POS': 'Verb', 'Form': 'böten', 'Lemma': 'bieten'}]},
#  {'Form': 'seite',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Seite', 'Lemma': 'Seite'}]},
#  {'Form': 'seiten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Seiten', 'Lemma': 'Seite'}]},
#  {'Form': 'schatz',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schatz', 'Lemma': 'Schatz'}]},
#  {'Form': 'schätze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schätze', 'Lemma': 'Schatz'},
#    {'POS': 'Verb', 'Form': 'schätze', 'Lemma': 'schätzen'}]},
#  {'Form': 'schatzes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schatzes', 'Lemma': 'Schatz'}]},
#  {'Form': 'schatze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schatze', 'Lemma': 'Schatz'}]},
#  {'Form': 'schätzen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schätzen', 'Lemma': 'Schatz'},
#    {'POS': 'Verb', 'Form': 'schätzen', 'Lemma': 'schätzen'}]},
#  {'Form': 'kampf',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kampf', 'Lemma': 'Kampf'}]},
#  {'Form': 'kämpfe',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kämpfe', 'Lemma': 'Kampf'},
#    {'POS': 'Verb', 'Form': 'kämpfe', 'Lemma': 'kämpfen'}]},
#  {'Form': 'kampfs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kampfs', 'Lemma': 'Kampf'}]},
#  {'Form': 'kampfes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kampfes', 'Lemma': 'Kampf'}]},
#  {'Form': 'kampfe',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kampfe', 'Lemma': 'Kampf'}]},
#  {'Form': 'kämpfen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kämpfen', 'Lemma': 'Kampf'},
#    {'POS': 'Verb', 'Form': 'kämpfen', 'Lemma': 'kämpfen'}]},
#  {'Form': 'licht',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Licht', 'Lemma': 'Licht'},
#    {'POS': 'Adjective', 'Form': 'licht', 'Lemma': 'licht'},
#    {'POS': 'Verb', 'Form': 'licht', 'Lemma': 'lichten'}]},
#  {'Form': 'lichter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichter', 'Lemma': 'Licht'},
#    {'POS': 'Adjective', 'Form': 'lichter', 'Lemma': 'licht'},
#    {'POS': 'X', 'Form': 'lichter', 'Lemma': 'lichter'}]},
#  {'Form': 'lichte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichte', 'Lemma': 'Licht'},
#    {'POS': 'Verb', 'Form': 'lichte', 'Lemma': 'lichten'},
#    {'POS': 'Adjective', 'Form': 'lichte', 'Lemma': 'licht'}]},
#  {'Form': 'lichts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichts', 'Lemma': 'Licht'}]},
#  {'Form': 'lichtes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichtes', 'Lemma': 'Licht'},
#    {'POS': 'Adjective', 'Form': 'lichtes', 'Lemma': 'licht'}]},
#  {'Form': 'lichtern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichtern', 'Lemma': 'Licht'}]},
#  {'Form': 'lichten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lichten', 'Lemma': 'Licht'},
#    {'POS': 'Verb', 'Form': 'lichten', 'Lemma': 'lichten'},
#    {'POS': 'Adjective', 'Form': 'lichten', 'Lemma': 'licht'}]},
#  {'Form': 'schatten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schatten', 'Lemma': 'Schatten'}]},
#  {'Form': 'schattens',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schattens', 'Lemma': 'Schatten'}]},
#  {'Form': 'luft',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Luft', 'Lemma': 'Luft'}]},
#  {'Form': 'lüfte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lüfte', 'Lemma': 'Luft'},
#    {'POS': 'Verb', 'Form': 'lüfte', 'Lemma': 'lüften'}]},
#  {'Form': 'lüften',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Lüften', 'Lemma': 'Luft'},
#    {'POS': 'Noun', 'Form': 'Lüften', 'Lemma': 'Lüften'},
#    {'POS': 'Verb', 'Form': 'lüften', 'Lemma': 'lüften'}]},
#  {'Form': 'zeit',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zeit', 'Lemma': 'Zeit'},
#    {'POS': 'X', 'Form': 'zeit', 'Lemma': 'zeit'}]},
#  {'Form': 'zeiten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zeiten', 'Lemma': 'Zeit'}]},
#  {'Form': 'raum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Raum', 'Lemma': 'Raum'}]},
#  {'Form': 'räume',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Räume', 'Lemma': 'Raum'},
#    {'POS': 'Verb', 'Form': 'räume', 'Lemma': 'räumen'}]},
#  {'Form': 'raums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Raums', 'Lemma': 'Raum'}]},
#  {'Form': 'raumes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Raumes', 'Lemma': 'Raum'}]},
#  {'Form': 'raume',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Raume', 'Lemma': 'Raum'}]},
#  {'Form': 'räumen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Räumen', 'Lemma': 'Raum'},
#    {'POS': 'Verb', 'Form': 'räumen', 'Lemma': 'räumen'}]},
#  {'Form': 'chatten',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'chatten', 'Lemma': 'chatten'},
#    {'POS': 'Noun', 'Form': 'Chatten', 'Lemma': 'Chatte'}]},
#  {'Form': 'chatte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'chatte', 'Lemma': 'chatten'},
#    {'POS': 'Noun', 'Form': 'Chatte', 'Lemma': 'Chatte'}]},
#  {'Form': 'chattest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'chattest', 'Lemma': 'chatten'}]},
#  {'Form': 'chattet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'chattet', 'Lemma': 'chatten'}]},
#  {'Form': 'chattete',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'chattete', 'Lemma': 'chatten'}]},
#  {'Form': 'gechattet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gechattet', 'Lemma': 'chatten'}]},
#  {'Form': 'denken',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Denken', 'Lemma': 'Denken'},
#    {'POS': 'Verb', 'Form': 'denken', 'Lemma': 'denken'}]},
#  {'Form': 'denkens',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Denkens', 'Lemma': 'Denken'}]},
#  {'Form': 'herzog',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzog', 'Lemma': 'Herzog'},
#    {'POS': 'Verb', 'Form': 'herzog', 'Lemma': 'herziehen'}]},
#  {'Form': 'herzöge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzöge', 'Lemma': 'Herzog'},
#    {'POS': 'Verb', 'Form': 'herzöge', 'Lemma': 'herziehen'}]},
#  {'Form': 'herzoge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzoge', 'Lemma': 'Herzog'}]},
#  {'Form': 'herzogs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzogs', 'Lemma': 'Herzog'}]},
#  {'Form': 'herzoges',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzoges', 'Lemma': 'Herzog'}]},
#  {'Form': 'herzögen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzögen', 'Lemma': 'Herzog'},
#    {'POS': 'Verb', 'Form': 'herzögen', 'Lemma': 'herziehen'}]},
#  {'Form': 'herzogen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herzogen', 'Lemma': 'Herzog'},
#    {'POS': 'Verb', 'Form': 'herzogen', 'Lemma': 'herziehen'}]},
#  {'Form': 'kartoffel',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kartoffel', 'Lemma': 'Kartoffel'}]},
#  {'Form': 'kartoffeln',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Kartoffeln', 'Lemma': 'Kartoffel'}]},
#  {'Form': 'woche',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Woche', 'Lemma': 'Woche'}]},
#  {'Form': 'wochen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochen', 'Lemma': 'Woche'}]},
#  {'Form': 'stein',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Stein', 'Lemma': 'Stein'}]},
#  {'Form': 'steine',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Steine', 'Lemma': 'Stein'}]},
#  {'Form': 'steins',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Steins', 'Lemma': 'Stein'}]},
#  {'Form': 'steines',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Steines', 'Lemma': 'Stein'}]},
#  {'Form': 'steinen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Steinen', 'Lemma': 'Stein'}]},
#  {'Form': 'straßenbahn',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Straßenbahn', 'Lemma': 'Straßenbahn'}]},
#  {'Form': 'straßenbahnen',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Straßenbahnen',
#     'Lemma': 'Straßenbahn'}]},
#  {'Form': 'sonntag',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sonntag', 'Lemma': 'Sonntag'}]},
#  {'Form': 'sonntage',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sonntage', 'Lemma': 'Sonntag'}]},
#  {'Form': 'sonntags',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sonntags', 'Lemma': 'Sonntag'},
#    {'POS': 'X', 'Form': 'sonntags', 'Lemma': 'sonntags'}]},
#  {'Form': 'sonntages',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sonntages', 'Lemma': 'Sonntag'}]},
#  {'Form': 'sonntagen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sonntagen', 'Lemma': 'Sonntag'}]},
#  {'Form': 'wasser',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wasser', 'Lemma': 'Wasser'},
#    {'POS': 'Verb', 'Form': 'wasser', 'Lemma': 'wassern'}]},
#  {'Form': 'wässer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wässer', 'Lemma': 'Wasser'},
#    {'POS': 'Verb', 'Form': 'wässer', 'Lemma': 'wässern'}]},
#  {'Form': 'wassers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wassers', 'Lemma': 'Wasser'}]},
#  {'Form': 'wassern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wassern', 'Lemma': 'Wasser'},
#    {'POS': 'Noun', 'Form': 'Wassern', 'Lemma': 'Wassern'},
#    {'POS': 'Verb', 'Form': 'wassern', 'Lemma': 'wassern'}]},
#  {'Form': 'wässern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wässern', 'Lemma': 'Wasser'},
#    {'POS': 'Verb', 'Form': 'wässern', 'Lemma': 'wässern'},
#    {'POS': 'Noun', 'Form': 'Wässern', 'Lemma': 'Wässern'}]},
#  {'Form': 'blut',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blut', 'Lemma': 'Blut'}]},
#  {'Form': 'blute',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blute', 'Lemma': 'Blut'},
#    {'POS': 'Verb', 'Form': 'blute', 'Lemma': 'bluten'}]},
#  {'Form': 'bluts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bluts', 'Lemma': 'Blut'}]},
#  {'Form': 'blutes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blutes', 'Lemma': 'Blut'}]},
#  {'Form': 'bluten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bluten', 'Lemma': 'Blut'},
#    {'POS': 'Verb', 'Form': 'bluten', 'Lemma': 'bluten'}]},
#  {'Form': 'vice versa',
#   'Lemmas': [{'POS': 'X', 'Form': 'vice versa', 'Lemma': 'vice versa'}]},
#  {'Form': 'berg',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Berg', 'Lemma': 'Berg'}]},
#  {'Form': 'berge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Berge', 'Lemma': 'Berg'},
#    {'POS': 'Verb', 'Form': 'berge', 'Lemma': 'bergen'}]},
#  {'Form': 'bergs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bergs', 'Lemma': 'Berg'}]},
#  {'Form': 'berges',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Berges', 'Lemma': 'Berg'}]},
#  {'Form': 'bergen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bergen', 'Lemma': 'Berg'},
#    {'POS': 'Verb', 'Form': 'bergen', 'Lemma': 'bergen'}]},
#  {'Form': 'garçonnière',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Garçonnière', 'Lemma': 'Garçonnière'}]},
#  {'Form': 'garçonnièren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Garçonnièren', 'Lemma': 'Garçonnière'}]},
#  {'Form': 'haus',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Haus', 'Lemma': 'Haus'}]},
#  {'Form': 'häuser',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Häuser', 'Lemma': 'Haus'}]},
#  {'Form': 'hauses',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hauses', 'Lemma': 'Haus'}]},
#  {'Form': 'hause',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Hause', 'Lemma': 'Haus'},
#    {'POS': 'Verb', 'Form': 'hause', 'Lemma': 'hausen'}]},
#  {'Form': 'häusern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Häusern', 'Lemma': 'Haus'}]},
#  {'Form': 'familie',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Familie', 'Lemma': 'Familie'}]},
#  {'Form': 'familien',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Familien', 'Lemma': 'Familie'}]},
#  {'Form': 'quelle',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Quelle', 'Lemma': 'Quelle'},
#    {'POS': 'Verb', 'Form': 'quelle', 'Lemma': 'quellen'},
#    {'POS': 'Noun', 'Form': 'Quelle', 'Lemma': 'Quell'}]},
#  {'Form': 'quellen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Quellen', 'Lemma': 'Quelle'},
#    {'POS': 'Verb', 'Form': 'quellen', 'Lemma': 'quellen'},
#    {'POS': 'Noun', 'Form': 'Quellen', 'Lemma': 'Quell'}]},
#  {'Form': 'schloss',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schloss', 'Lemma': 'Schloss'},
#    {'POS': 'Verb', 'Form': 'schloss', 'Lemma': 'schließen'}]},
#  {'Form': 'schlösser',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlösser', 'Lemma': 'Schloss'}]},
#  {'Form': 'schlosses',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlosses', 'Lemma': 'Schloss'}]},
#  {'Form': 'schlosse',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlosse', 'Lemma': 'Schloss'}]},
#  {'Form': 'schlössern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlössern', 'Lemma': 'Schloss'}]},
#  {'Form': 'burg',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Burg', 'Lemma': 'Burg'}]},
#  {'Form': 'burgen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Burgen', 'Lemma': 'Burg'}]},
#  {'Form': 'bürge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bürge', 'Lemma': 'Burg'},
#    {'POS': 'Noun', 'Form': 'Bürge', 'Lemma': 'Bürge'},
#    {'POS': 'Verb', 'Form': 'bürge', 'Lemma': 'bürgen'}]},
#  {'Form': 'bürgen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bürgen', 'Lemma': 'Burg'},
#    {'POS': 'Noun', 'Form': 'Bürgen', 'Lemma': 'Bürge'},
#    {'POS': 'Verb', 'Form': 'bürgen', 'Lemma': 'bürgen'}]},
#  {'Form': 'frieden',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Frieden', 'Lemma': 'Frieden'},
#    {'POS': 'Noun', 'Form': 'Frieden', 'Lemma': 'Friede'}]},
#  {'Form': 'friedens',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedens', 'Lemma': 'Frieden'},
#    {'POS': 'Noun', 'Form': 'Friedens', 'Lemma': 'Friede'}]},
#  {'Form': 'wiktionary',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wiktionary', 'Lemma': 'Wiktionary'}]},
#  {'Form': 'wiktionarys',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wiktionarys', 'Lemma': 'Wiktionary'}]},
#  {'Form': 'geschlecht',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlecht', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'geschlechter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlechter', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'geschlechts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlechts', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'geschlechtes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlechtes', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'geschlechte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlechte', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'geschlechtern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Geschlechtern', 'Lemma': 'Geschlecht'}]},
#  {'Form': 'rot',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'rot', 'Lemma': 'rot'},
#    {'POS': 'Noun', 'Form': 'Rot', 'Lemma': 'Rot'}]},
#  {'Form': 'röter',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'röter', 'Lemma': 'rot'},
#    {'POS': 'X', 'Form': 'röter', 'Lemma': 'röter'}]},
#  {'Form': 'roter',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'roter', 'Lemma': 'rot'},
#    {'POS': 'X', 'Form': 'roter', 'Lemma': 'roter'}]},
#  {'Form': 'rötesten',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'rötesten', 'Lemma': 'rot'},
#    {'POS': 'X', 'Form': 'rötesten', 'Lemma': 'rötesten'}]},
#  {'Form': 'rotesten',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'rotesten', 'Lemma': 'rot'},
#    {'POS': 'X', 'Form': 'rotesten', 'Lemma': 'rotesten'}]},
#  {'Form': 'klärschlamm',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärschlamm', 'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlamme',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärschlamme', 'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlämme',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärschlämme', 'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlamms',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärschlamms', 'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlammes',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Klärschlammes',
#     'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlammen',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Klärschlammen',
#     'Lemma': 'Klärschlamm'}]},
#  {'Form': 'klärschlämmen',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Klärschlämmen',
#     'Lemma': 'Klärschlamm'}]},
#  {'Form': 'schlamm',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlamm', 'Lemma': 'Schlamm'}]},
#  {'Form': 'schlämme',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlämme', 'Lemma': 'Schlamm'},
#    {'POS': 'Verb', 'Form': 'schlämme', 'Lemma': 'schlämmen'}]},
#  {'Form': 'schlamms',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlamms', 'Lemma': 'Schlamm'}]},
#  {'Form': 'schlammes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlammes', 'Lemma': 'Schlamm'}]},
#  {'Form': 'schlamme',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlamme', 'Lemma': 'Schlamm'}]},
#  {'Form': 'schlämmen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schlämmen', 'Lemma': 'Schlamm'},
#    {'POS': 'Verb', 'Form': 'schlämmen', 'Lemma': 'schlämmen'}]},
#  {'Form': 'klärung',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärung', 'Lemma': 'Klärung'}]},
#  {'Form': 'klärungen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Klärungen', 'Lemma': 'Klärung'}]},
#  {'Form': 'aufklärung',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aufklärung', 'Lemma': 'Aufklärung'}]},
#  {'Form': 'aufklärungen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Aufklärungen', 'Lemma': 'Aufklärung'}]},
#  {'Form': 'bildung',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bildung', 'Lemma': 'Bildung'}]},
#  {'Form': 'bildungen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bildungen', 'Lemma': 'Bildung'}]},
#  {'Form': 'wissen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wissen', 'Lemma': 'wissen'},
#    {'POS': 'Noun', 'Form': 'Wissen', 'Lemma': 'Wissen'}]},
#  {'Form': 'weiß',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'weiß', 'Lemma': 'wissen'},
#    {'POS': 'Adjective', 'Form': 'weiß', 'Lemma': 'weiß'},
#    {'POS': 'Noun', 'Form': 'Weiß', 'Lemma': 'Weiß'},
#    {'POS': 'Verb', 'Form': 'weiß', 'Lemma': 'weißen'}]},
#  {'Form': 'weißt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'weißt', 'Lemma': 'wissen'},
#    {'POS': 'Verb', 'Form': 'weißt', 'Lemma': 'weißen'}]},
#  {'Form': 'wusste',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wusste', 'Lemma': 'wissen'}]},
#  {'Form': 'wüsste',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wüsste', 'Lemma': 'wissen'}]},
#  {'Form': 'wisse',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wisse', 'Lemma': 'wissen'}]},
#  {'Form': 'wisset',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wisset', 'Lemma': 'wissen'}]},
#  {'Form': 'wisst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wisst', 'Lemma': 'wissen'}]},
#  {'Form': 'gewusst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gewusst', 'Lemma': 'wissen'}]},
#  {'Form': 'mächte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mächte', 'Lemma': 'Macht'}]},
#  {'Form': 'mächten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Mächten', 'Lemma': 'Macht'}]},
#  {'Form': 'besitz',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Besitz', 'Lemma': 'Besitz'},
#    {'POS': 'Verb', 'Form': 'besitz', 'Lemma': 'besitzen'}]},
#  {'Form': 'besitze',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Besitze', 'Lemma': 'Besitz'},
#    {'POS': 'Verb', 'Form': 'besitze', 'Lemma': 'besitzen'}]},
#  {'Form': 'besitzes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Besitzes', 'Lemma': 'Besitz'}]},
#  {'Form': 'besitzen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Besitzen', 'Lemma': 'Besitz'},
#    {'POS': 'Verb', 'Form': 'besitzen', 'Lemma': 'besitzen'}]},
#  {'Form': 'vater',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Vater', 'Lemma': 'Vater'}]},
#  {'Form': 'väter',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Väter', 'Lemma': 'Vater'}]},
#  {'Form': 'vaters',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Vaters', 'Lemma': 'Vater'}]},
#  {'Form': 'vätern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Vätern', 'Lemma': 'Vater'}]},
#  {'Form': 'eigentum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eigentum', 'Lemma': 'Eigentum'}]},
#  {'Form': 'eigentume',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eigentume', 'Lemma': 'Eigentum'}]},
#  {'Form': 'eigentums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eigentums', 'Lemma': 'Eigentum'}]},
#  {'Form': 'eigentumes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eigentumes', 'Lemma': 'Eigentum'}]},
#  {'Form': 'eigentumen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eigentumen', 'Lemma': 'Eigentum'}]},
#  {'Form': 'eltern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eltern', 'Lemma': 'Eltern'},
#    {'POS': 'Noun', 'Form': 'Eltern', 'Lemma': 'Elter'}]},
#  {'Form': 'auto',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Auto', 'Lemma': 'Auto'}]},
#  {'Form': 'autos',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Autos', 'Lemma': 'Auto'}]},
#  {'Form': 'auto-',
#   'Lemmas': [{'POS': 'X', 'Form': 'auto-', 'Lemma': 'auto-'}]},
#  {'Form': 'gemütlichkeit',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Gemütlichkeit',
#     'Lemma': 'Gemütlichkeit'}]},
#  {'Form': 'baum',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Baum', 'Lemma': 'Baum'}]},
#  {'Form': 'bäume',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bäume', 'Lemma': 'Baum'},
#    {'POS': 'Verb', 'Form': 'bäume', 'Lemma': 'bäumen'}]},
#  {'Form': 'baums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Baums', 'Lemma': 'Baum'}]},
#  {'Form': 'baumes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Baumes', 'Lemma': 'Baum'}]},
#  {'Form': 'baume',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Baume', 'Lemma': 'Baum'}]},
#  {'Form': 'bäumen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Bäumen', 'Lemma': 'Baum'},
#    {'POS': 'Verb', 'Form': 'bäumen', 'Lemma': 'bäumen'}]},
#  {'Form': 'muschi',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Muschi', 'Lemma': 'Muschi'}]},
#  {'Form': 'muschis',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Muschis', 'Lemma': 'Muschi'}]},
#  {'Form': 'man',
#   'Lemmas': [{'POS': 'Pronoun', 'Form': 'man', 'Lemma': 'man'},
# ...
#  {'Form': 'untersuche',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'untersuche', 'Lemma': 'untersuchen'}]},
#  {'Form': 'untersuchst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'untersuchst', 'Lemma': 'untersuchen'}]},
#  {'Form': 'untersucht',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'untersucht', 'Lemma': 'untersuchen'},
#    {'POS': 'Adjective', 'Form': 'untersucht', 'Lemma': 'untersucht'}]},
#  {'Form': 'untersuchte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'untersuchte', 'Lemma': 'untersuchen'},
#    {'POS': 'Adjective', 'Form': 'untersuchte', 'Lemma': 'untersucht'}]},
#  {'Form': 'rabauke',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Rabauke', 'Lemma': 'Rabauke'}]},
#  {'Form': 'rabauken',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Rabauken', 'Lemma': 'Rabauke'}]},
#  {'Form': 'wein',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wein', 'Lemma': 'Wein'},
#    {'POS': 'Verb', 'Form': 'wein', 'Lemma': 'weinen'}]},
#  {'Form': 'weine',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Weine', 'Lemma': 'Wein'},
#    {'POS': 'Verb', 'Form': 'weine', 'Lemma': 'weinen'}]},
#  {'Form': 'weins',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Weins', 'Lemma': 'Wein'}]},
#  {'Form': 'weines',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Weines', 'Lemma': 'Wein'}]},
#  {'Form': 'weinen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Weinen', 'Lemma': 'Wein'},
#    {'POS': 'Verb', 'Form': 'weinen', 'Lemma': 'weinen'}]},
#  {'Form': 'eieruhr',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eieruhr', 'Lemma': 'Eieruhr'}]},
#  {'Form': 'eieruhren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Eieruhren', 'Lemma': 'Eieruhr'}]},
#  {'Form': 'sanduhr',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sanduhr', 'Lemma': 'Sanduhr'}]},
#  {'Form': 'sanduhren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sanduhren', 'Lemma': 'Sanduhr'}]},
#  {'Form': 'flugzeug',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flugzeug', 'Lemma': 'Flugzeug'}]},
#  {'Form': 'flugzeuge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flugzeuge', 'Lemma': 'Flugzeug'}]},
#  {'Form': 'flugzeuges',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flugzeuges', 'Lemma': 'Flugzeug'}]},
#  {'Form': 'flugzeugs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flugzeugs', 'Lemma': 'Flugzeug'}]},
#  {'Form': 'flugzeugen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flugzeugen', 'Lemma': 'Flugzeug'}]},
#  {'Form': 'grafschaft',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Grafschaft', 'Lemma': 'Grafschaft'}]},
#  {'Form': 'grafschaften',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Grafschaften', 'Lemma': 'Grafschaft'}]},
#  {'Form': 'landkreis',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Landkreis', 'Lemma': 'Landkreis'}]},
#  {'Form': 'landkreise',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Landkreise', 'Lemma': 'Landkreis'}]},
#  {'Form': 'landkreises',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Landkreises', 'Lemma': 'Landkreis'}]},
#  {'Form': 'landkreisen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Landkreisen', 'Lemma': 'Landkreis'}]},
#  {'Form': 'flughafen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flughafen', 'Lemma': 'Flughafen'}]},
#  {'Form': 'flughäfen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flughäfen', 'Lemma': 'Flughafen'}]},
#  {'Form': 'flughafens',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Flughafens', 'Lemma': 'Flughafen'}]},
#  {'Form': 'zebra',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zebra', 'Lemma': 'Zebra'}]},
#  {'Form': 'zebras',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Zebras', 'Lemma': 'Zebra'}]},
#  {'Form': 'schach',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schach', 'Lemma': 'Schach'}]},
#  {'Form': 'schachs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schachs', 'Lemma': 'Schach'}]},
#  {'Form': 'schwefelsäure',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Schwefelsäure',
#     'Lemma': 'Schwefelsäure'}]},
#  {'Form': 'friedhof',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhof', 'Lemma': 'Friedhof'}]},
#  {'Form': 'friedhöfe',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhöfe', 'Lemma': 'Friedhof'}]},
#  {'Form': 'friedhofs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhofs', 'Lemma': 'Friedhof'}]},
#  {'Form': 'friedhofes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhofes', 'Lemma': 'Friedhof'}]},
#  {'Form': 'friedhofe',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhofe', 'Lemma': 'Friedhof'}]},
#  {'Form': 'friedhöfen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Friedhöfen', 'Lemma': 'Friedhof'}]},
#  {'Form': 'luftfahrt',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Luftfahrt', 'Lemma': 'Luftfahrt'}]},
#  {'Form': 'utopie',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Utopie', 'Lemma': 'Utopie'}]},
#  {'Form': 'utopien',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Utopien', 'Lemma': 'Utopie'}]},
#  {'Form': 'stadt',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Stadt', 'Lemma': 'Stadt'}]},
#  {'Form': 'städte',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Städte', 'Lemma': 'Stadt'}]},
#  {'Form': 'städten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Städten', 'Lemma': 'Stadt'}]},
#  {'Form': 'gräuel',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gräuel', 'Lemma': 'Gräuel'}]},
#  {'Form': 'gräuels',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gräuels', 'Lemma': 'Gräuel'}]},
#  {'Form': 'gräueln',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Gräueln', 'Lemma': 'Gräuel'}]},
#  {'Form': 'beispiel',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Beispiel', 'Lemma': 'Beispiel'}]},
#  {'Form': 'beispiele',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Beispiele', 'Lemma': 'Beispiel'}]},
#  {'Form': 'beispieles',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Beispieles', 'Lemma': 'Beispiel'}]},
#  {'Form': 'beispiels',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Beispiels', 'Lemma': 'Beispiel'}]},
#  {'Form': 'beispielen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Beispielen', 'Lemma': 'Beispiel'}]},
#  {'Form': 'humide',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'humide', 'Lemma': 'humide'},
#    {'POS': 'Adjective', 'Form': 'humide', 'Lemma': 'humid'}]},
#  {'Form': 'humider',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'humider', 'Lemma': 'humide'},
#    {'POS': 'Adjective', 'Form': 'humider', 'Lemma': 'humid'},
#    {'POS': 'X', 'Form': 'humider', 'Lemma': 'humider'}]},
#  {'Form': 'humidesten',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'humidesten', 'Lemma': 'humide'},
#    {'POS': 'Adjective', 'Form': 'humidesten', 'Lemma': 'humid'},
#    {'POS': 'X', 'Form': 'humidesten', 'Lemma': 'humidesten'}]},
#  {'Form': 'frühling',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Frühling', 'Lemma': 'Frühling'}]},
#  {'Form': 'frühlinge',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Frühlinge', 'Lemma': 'Frühling'}]},
#  {'Form': 'frühlings',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Frühlings', 'Lemma': 'Frühling'}]},
#  {'Form': 'frühlingen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Frühlingen', 'Lemma': 'Frühling'}]},
#  {'Form': 'jahreszeit',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Jahreszeit', 'Lemma': 'Jahreszeit'}]},
#  {'Form': 'jahreszeiten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Jahreszeiten', 'Lemma': 'Jahreszeit'}]},
#  {'Form': 'sommer',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sommer', 'Lemma': 'Sommer'}]},
#  {'Form': 'sommers',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sommers', 'Lemma': 'Sommer'},
#    {'POS': 'X', 'Form': 'sommers', 'Lemma': 'sommers'}]},
#  {'Form': 'sommern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Sommern', 'Lemma': 'Sommer'}]},
#  {'Form': 'vulgär',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'vulgär', 'Lemma': 'vulgär'}]},
#  {'Form': 'vulgärer',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'vulgärer', 'Lemma': 'vulgär'},
#    {'POS': 'X', 'Form': 'vulgärer', 'Lemma': 'vulgärer'}]},
#  {'Form': 'vulgärsten',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'vulgärsten', 'Lemma': 'vulgär'},
#    {'POS': 'X', 'Form': 'vulgärsten', 'Lemma': 'vulgärsten'}]},
#  {'Form': 'herbst',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herbst', 'Lemma': 'Herbst'}]},
#  {'Form': 'herbste',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herbste', 'Lemma': 'Herbst'},
#    {'POS': 'Adjective', 'Form': 'herbste', 'Lemma': 'herb'},
#    {'POS': 'Verb', 'Form': 'herbste', 'Lemma': 'herbsten'}]},
#  {'Form': 'herbsts',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herbsts', 'Lemma': 'Herbst'}]},
#  {'Form': 'herbstes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herbstes', 'Lemma': 'Herbst'},
#    {'POS': 'Adjective', 'Form': 'herbstes', 'Lemma': 'herb'}]},
#  {'Form': 'herbsten',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Herbsten', 'Lemma': 'Herbst'},
#    {'POS': 'Adjective', 'Form': 'herbsten', 'Lemma': 'herb'},
#    {'POS': 'Verb', 'Form': 'herbsten', 'Lemma': 'herbsten'},
#    {'POS': 'X', 'Form': 'herbsten', 'Lemma': 'herbsten'}]},
#  {'Form': 'figur',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Figur', 'Lemma': 'Figur'}]},
#  {'Form': 'figuren',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Figuren', 'Lemma': 'Figur'}]},
#  {'Form': 'brachst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brachst', 'Lemma': 'brechen'}]},
#  {'Form': 'brachen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brachen', 'Lemma': 'brechen'},
#    {'POS': 'Noun', 'Form': 'Brachen', 'Lemma': 'Brache'},
#    {'POS': 'Adjective', 'Form': 'brachen', 'Lemma': 'brach'}]},
#  {'Form': 'bracht',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'bracht', 'Lemma': 'brechen'}]},
#  {'Form': 'brechest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brechest', 'Lemma': 'brechen'}]},
#  {'Form': 'brechet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brechet', 'Lemma': 'brechen'}]},
#  {'Form': 'brächest',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brächest', 'Lemma': 'brechen'}]},
#  {'Form': 'brächst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brächst', 'Lemma': 'brechen'}]},
#  {'Form': 'brächen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brächen', 'Lemma': 'brechen'}]},
#  {'Form': 'brächet',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brächet', 'Lemma': 'brechen'}]},
#  {'Form': 'brächt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'brächt', 'Lemma': 'brechen'}]},
#  {'Form': 'schachfigur',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Schachfigur', 'Lemma': 'Schachfigur'}]},
#  {'Form': 'schachfiguren',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Schachfiguren',
#     'Lemma': 'Schachfigur'}]},
#  {'Form': 'million',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Million', 'Lemma': 'Million'}]},
#  {'Form': 'millionen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Millionen', 'Lemma': 'Million'}]},
#  {'Form': 'kaufen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kaufen', 'Lemma': 'kaufen'}]},
#  {'Form': 'kaufe',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kaufe', 'Lemma': 'kaufen'},
#    {'POS': 'Noun', 'Form': 'Kaufe', 'Lemma': 'Kauf'}]},
#  {'Form': 'kaufst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kaufst', 'Lemma': 'kaufen'}]},
#  {'Form': 'kauft',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kauft', 'Lemma': 'kaufen'}]},
#  {'Form': 'kaufte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kaufte', 'Lemma': 'kaufen'}]},
#  {'Form': 'kauf',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'kauf', 'Lemma': 'kaufen'},
#    {'POS': 'Noun', 'Form': 'Kauf', 'Lemma': 'Kauf'}]},
#  {'Form': 'gekauft',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gekauft', 'Lemma': 'kaufen'}]},
#  {'Form': 'wohnung',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wohnung', 'Lemma': 'Wohnung'}]},
#  {'Form': 'wohnungen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wohnungen', 'Lemma': 'Wohnung'}]},
#  {'Form': 'wohnen',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohnen', 'Lemma': 'wohnen'},
#    {'POS': 'Noun', 'Form': 'Wohnen', 'Lemma': 'Wohnen'}]},
#  {'Form': 'wohne',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohne', 'Lemma': 'wohnen'}]},
#  {'Form': 'wohnst',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohnst', 'Lemma': 'wohnen'}]},
#  {'Form': 'wohnt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohnt', 'Lemma': 'wohnen'}]},
#  {'Form': 'wohnte',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohnte', 'Lemma': 'wohnen'}]},
#  {'Form': 'wohn',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'wohn', 'Lemma': 'wohnen'}]},
#  {'Form': 'gewohnt',
#   'Lemmas': [{'POS': 'Verb', 'Form': 'gewohnt', 'Lemma': 'wohnen'},
#    {'POS': 'Adjective', 'Form': 'gewohnt', 'Lemma': 'gewohnt'}]},
#  {'Form': 'wasserstoff',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wasserstoff', 'Lemma': 'Wasserstoff'}]},
#  {'Form': 'wasserstoffes',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Wasserstoffes',
#     'Lemma': 'Wasserstoff'}]},
#  {'Form': 'wasserstoffs',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wasserstoffs', 'Lemma': 'Wasserstoff'}]},
#  {'Form': 'wasserstoffe',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wasserstoffe', 'Lemma': 'Wasserstoff'}]},
#  {'Form': 'helium',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Helium', 'Lemma': 'Helium'}]},
#  {'Form': 'heliums',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Heliums', 'Lemma': 'Helium'}]},
#  {'Form': 'aalartig',
#   'Lemmas': [{'POS': 'Adjective', 'Form': 'aalartig', 'Lemma': 'aalartig'}]},
#  {'Form': 'tag',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tag', 'Lemma': 'Tag'},
#    {'POS': 'Verb', 'Form': 'tag', 'Lemma': 'tagen'}]},
#  {'Form': 'tage',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tage', 'Lemma': 'Tag'},
#    {'POS': 'Verb', 'Form': 'tage', 'Lemma': 'tagen'}]},
#  {'Form': 'tages',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tages', 'Lemma': 'Tag'}]},
#  {'Form': 'tags',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tags', 'Lemma': 'Tag'},
#    {'POS': 'X', 'Form': 'tags', 'Lemma': 'tags'}]},
#  {'Form': 'tagen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Tagen', 'Lemma': 'Tag'},
#    {'POS': 'Verb', 'Form': 'tagen', 'Lemma': 'tagen'}]},
#  {'Form': 'arterie',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Arterie', 'Lemma': 'Arterie'}]},
#  {'Form': 'arterien',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Arterien', 'Lemma': 'Arterie'}]},
#  {'Form': 'vene',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Vene', 'Lemma': 'Vene'}]},
#  {'Form': 'venen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Venen', 'Lemma': 'Vene'}]},
#  {'Form': 'blutgefäß',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blutgefäß', 'Lemma': 'Blutgefäß'}]},
#  {'Form': 'blutgefäße',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blutgefäße', 'Lemma': 'Blutgefäß'}]},
#  {'Form': 'blutgefäßes',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blutgefäßes', 'Lemma': 'Blutgefäß'}]},
#  {'Form': 'blutgefäßen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Blutgefäßen', 'Lemma': 'Blutgefäß'}]},
#  {'Form': 'ader',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Ader', 'Lemma': 'Ader'}]},
#  {'Form': 'adern',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Adern', 'Lemma': 'Ader'}]},
#  {'Form': 'x', 'Lemmas': [{'POS': 'X', 'Form': 'X', 'Lemma': 'X'}]},
#  {'Form': 'naturwissenschaft',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Naturwissenschaft',
#     'Lemma': 'Naturwissenschaft'}]},
#  {'Form': 'naturwissenschaften',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Naturwissenschaften',
#     'Lemma': 'Naturwissenschaft'}]},
#  {'Form': 'geisteswissenschaft',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Geisteswissenschaft',
#     'Lemma': 'Geisteswissenschaft'}]},
#  {'Form': 'geisteswissenschaften',
#   'Lemmas': [{'POS': 'Noun',
#     'Form': 'Geisteswissenschaften',
#     'Lemma': 'Geisteswissenschaft'}]},
#  {'Form': 'afrikaans',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Afrikaans', 'Lemma': 'Afrikaans'},
#    {'POS': 'Adjective', 'Form': 'afrikaans', 'Lemma': 'afrikaans'}]},
#  {'Form': 'afrikaans’',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Afrikaans’', 'Lemma': 'Afrikaans'}]},
#  {'Form': 'chlor',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Chlor', 'Lemma': 'Chlor'}]},
#  {'Form': 'chlors',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Chlors', 'Lemma': 'Chlor'}]},
#  {'Form': 'wochentag',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochentag', 'Lemma': 'Wochentag'}]},
#  {'Form': 'wochentage',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochentage', 'Lemma': 'Wochentag'}]},
#  {'Form': 'wochentags',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochentags', 'Lemma': 'Wochentag'},
#    {'POS': 'X', 'Form': 'wochentags', 'Lemma': 'wochentags'}]},
#  {'Form': 'wochentages',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochentages', 'Lemma': 'Wochentag'}]},
#  {'Form': 'wochentagen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Wochentagen', 'Lemma': 'Wochentag'}]},
#  {'Form': 'werktag',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Werktag', 'Lemma': 'Werktag'}]},
#  {'Form': 'werktage',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Werktage', 'Lemma': 'Werktag'}]},
#  {'Form': 'werktages',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Werktages', 'Lemma': 'Werktag'}]},
#  {'Form': 'werktags',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Werktags', 'Lemma': 'Werktag'},
#    {'POS': 'X', 'Form': 'werktags', 'Lemma': 'werktags'}]},
#  {'Form': 'werktagen',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Werktagen', 'Lemma': 'Werktag'}]},
#  {'Form': 'informatik',
#   'Lemmas': [{'POS': 'Noun', 'Form': 'Informatik', 'Lemma': 'Informatik'}]},
#  ...]

# %%
df = pd.DataFrame.from_records(iwnlp)
x = df.Lemmas.apply(pd.Series)
df = (
    df
    .join(x)
    .set_index('Form', append=True)
    .drop('Lemmas', axis=1)
    .stack()
)

forms = pd.DataFrame.from_records(df.values).astype({'POS':'category'})
forms.index = df.index
forms

forms.to_pickle(join(ETL_PATH, 'wiktionary_lemmatization_map.pickle'))

# %%
load('wikt', 'lemmap')
# Out:
# Reading ../data/preprocessed/wiktionary_lemmatization_map.pickle
#                                          Form             Lemma        POS
#        Form
# 0      hallo             0              Hallo             Hallo       Noun
#                          1              hallo             hallo          X
# 1      hallos            0             Hallos             Hallo       Noun
# 2      subfamilia        0         Subfamilia        Subfamilia       Noun
# 3      subfamiliae       0        Subfamiliae        Subfamilia       Noun
# 4      subregnum         0          Subregnum         Subregnum       Noun
# 5      subregna          0           Subregna         Subregnum       Noun
# 6      subregnums        0         Subregnums         Subregnum       Noun
# 7      subdivisio        0         Subdivisio        Subdivisio       Noun
# 8      subdivisiones     0      Subdivisiones        Subdivisio       Noun
# 9      phylum            0             Phylum            Phylum       Noun
# 10     phyla             0              Phyla            Phylum       Noun
# 11     phylums           0            Phylums            Phylum       Noun
# 12     superphylum       0        Superphylum       Superphylum       Noun
# 13     superphyla        0         Superphyla       Superphylum       Noun
# 14     superphylums      0       Superphylums       Superphylum       Noun
# 15     subphylum         0          Subphylum         Subphylum       Noun
# 16     subphyla          0           Subphyla         Subphylum       Noun
# 17     subordo           0            Subordo           Subordo       Noun
# 18     subordines        0         Subordines           Subordo       Noun
# 19     subgenus          0           Subgenus          Subgenus       Noun
# 20     subgenera         0          Subgenera          Subgenus       Noun
# 21     subspezies        0         Subspezies        Subspezies       Noun
# 22     varietas          0           Varietas          Varietas       Noun
# 23     varietates        0         Varietates          Varietas       Noun
# 24     tribus            0             Tribus            Tribus       Noun
# 25     triben            0             Triben            Tribus       Noun
# 26     infraordo         0          Infraordo         Infraordo       Noun
# 27     infraordines      0       Infraordines         Infraordo       Noun
# 28     dezember          0           Dezember          Dezember       Noun
# ...                                       ...               ...        ...
# 409084 verkneifend       0        verkneifend       verkneifend          X
# 409085 geschehen lassen  0   geschehen lassen  geschehen lassen       Verb
# 409086 lasse geschehen   0    lasse geschehen  geschehen lassen       Verb
# 409087 lässt geschehen   0    lässt geschehen  geschehen lassen       Verb
# 409088 ließ geschehen    0     ließ geschehen  geschehen lassen       Verb
# 409089 ließe geschehen   0    ließe geschehen  geschehen lassen       Verb
# 409090 lass geschehen    0     lass geschehen  geschehen lassen       Verb
# 409091 lasst geschehen   0    lasst geschehen  geschehen lassen       Verb
# 409092 lasset geschehen  0   lasset geschehen  geschehen lassen       Verb
# 409093 lass zurück       0        lass zurück      zurücklassen       Verb
# 409094 zurückgelasssen   0    zurückgelasssen      zurücklassen       Verb
# 409095 zurücklassend     0      zurücklassend     zurücklassend          X
# 409096 zurückzulassen    0     zurückzulassen    zurückzulassen          X
# 409097 scheelsüchtig     0      scheelsüchtig     scheelsüchtig  Adjective
# 409098 quadratdezimeter  0   Quadratdezimeter  Quadratdezimeter       Noun
# 409099 quadratdezimeters 0  Quadratdezimeters  Quadratdezimeter       Noun
# 409100 quadratdezimetern 0  Quadratdezimetern  Quadratdezimeter       Noun
# 409101 schnappfinger     0      Schnappfinger     Schnappfinger       Noun
# 409102 schnappfingers    0     Schnappfingers     Schnappfinger       Noun
# 409103 schnappfingern    0     Schnappfingern     Schnappfinger       Noun
# 409104 quälerei          0           Quälerei          Quälerei       Noun
# 409105 quälereien        0         Quälereien          Quälerei       Noun
# 409106 springfinger      0       Springfinger      Springfinger       Noun
# 409107 springfingers     0      Springfingers      Springfinger       Noun
# 409108 springfingern     0      Springfingern      Springfinger       Noun
# 409109 doku              0               Doku              Doku       Noun
# 409110 dokus             0              Dokus              Doku       Noun
# 409111 plärrer           0            Plärrer           Plärrer       Noun
# 409112 plärrers          0           Plärrers           Plärrer       Noun
# 409113 plärrern          0           Plärrern           Plärrer       Noun
#
# [427380 rows x 3 columns]

# %% [markdown]
# -----
#
# ### Create lemmatization maps for all datasets
#
# they will be used to greadily undo lemmatization

# %%
pat = re.compile(r'^[A-Za-zÄÖÜäöü].*')

# %%
datasets = ['dewa1', 'E', 'FA', 'FO', 'O', 'P']

for dataset in datasets:
    df = load(dataset, 'nlp')
    df = df[df.token.str.match(pat)]
    df = df.groupby('token').apply(lambda x: x.text.value_counts())
    df.to_pickle(join(ETL_PATH, f'{DATASETS[dataset]}_lemmatization_map.pickle'))

# %%
load('dewac1', 'lemmap')
# Out:
# Reading ../data/preprocessed/dewac_nbfiles01_lemmatization_map.pickle
# token
# A                        a                          12868
#                          A                           5891
# A"-                      A"-                            1
# A"-Land                  A"-Land                        1
#                          A"-Landes                      1
# A$                       A$                            15
# A&A                      A&A                           45
# A&D                      A&D                            5
# A&E                      A&E                            3
# A&E-Abteilung            A&E-Abteilung                  1
# A&F                      A&F                            1
# A&M                      A&M                            5
# A&O                      A&O                            6
# A&P                      A&P                            1
# A&R                      A&R                           56
# A&R-                     A&R-                           5
# A&R-(Artist              A&R-(Artist                    1
# A&R-Arbeit               A&R-Arbeit                     1
# A&R-Management           A&R-Management                 1
# A&R-Manager              A&R-Manager                    4
#                          A&R-Managers                   1
# A&R-Mitarbeiter          A&R-Mitarbeiter                1
# A&R-Verantwortliche      A&R-Verantwortliche            1
# A'B'C                    A'B'C                          1
# A'Hearn                  A'Hearn                       11
# A'Rosa                   A'Rosa                         2
# A'er                     A'er                           3
# A'isa                    A'isa                          1
# A'rosa                   A'rosa                         1
# A(-2|0|0                 A(-2|0|0                       1
#                                                     ...
# üppig                    üppigerer                      1
# üppig-exotischen         üppig-exotischen               1
# üppigst                  üppigst                        1
# ür                       ür                            28
# ürbiegn                  ürbiegn                        1
# ürbige                   ürbige                         1
# ürde                     ürde                           1
# ürgen                    ürgen                          1
# ürgerin                  ürgerin                        1
# ürich                    ürich                          1
# ürigens                  ürigens                        3
# ürkisch                  ürkisch                        1
# üro                      üro                            3
# üros                     üros                           2
# ürztegesetzes            ürztegesetzes                  1
# ürzten                   ürzten                         1
# üs                       üs                             1
# üssen                    üssen                          1
# üssige                   üssige                         1
# üstra                    üstra                          1
# üterbeförderung          üterbeförderung                1
# üwer                     üwer                           1
# üßen                     üßen                           1
# üßte                     üßte                           1
# üüber                    üüber                          4
# üüberall                 üüberall                       1
# üüwel                    üüwel                          1
# üüüber                   üüüber                         1
# üüüberall                üüüberall                      1
# üüüüüiiiiiiiiiüüüüüühhh  üüüüüiiiiiiiiiüüüüüühhh        1
# Name: text, Length: 1463511, dtype: int64

# %% [markdown]
# -----
#
# ### Create disambiguation and redicrect mappings

# %%
phrases = load('phrases')

# %%
meta = load('meta')
# Out:
# Reading ../data/preprocessed/dewiki_metadata.pickle

# %%
links = load('links')

# %%
cat = load('categories')
# Out:
# Reading ../data/preprocessed/dewiki_phrases_lemmatized.pickle
# Reading ../data/preprocessed/dewiki_metadata.pickle
# Reading ../data/preprocessed/dewiki_links.pickle
# Reading ../data/preprocessed/dewiki_categories.pickle

# %%
# this cell corrects a bug that occured when generating the links table (the original code has already been fixed)
linklenmask = (links.link.str.len() == 1)
links_fix = links[linklenmask]

def re_join(column):
    if column.name in {'norm', 'category', 'hash_nlp'}:
        return column.values[0]
    else:
        return ''.join(column)

links_fix = links_fix.groupby('hash_nlp', sort=False, as_index=False).agg(re_join)
links = links[~linklenmask]
links = links.append(links_fix, sort=False)
links.to_pickle(join(ETL_PATH, 'dewiki_links.pickle'))
links
# Out:
# /home/andreas/bin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#              category             hash_nlp  \
# 0                None  8952056961092092653
# 1                None  8952056961092092653
# 2                None  8952056961092092653
# 3                None  8952056961092092653
# 4                None  8952056961092092653
# 5                None  8952056961092092653
# 6                None  8952056961092092653
# 7                None  8952056961092092653
# 8                Stil  8952056961092092653
# 9                None  8952056961092092653
# 10               None  8952056961092092653
# 11               None  8952056961092092653
# 12          Regisseur  8952056961092092653
# 13               None  8952056961092092653
# 14               2000  8952056961092092653
# 15               None  8952056961092092653
# 16          Regisseur  8952056961092092653
# 17               None  8952056961092092653
# 18               None  8952056961092092653
# 19       Fernsehserie  8952056961092092653
# 20          Regisseur  8952056961092092653
# 21               None  8952056961092092653
# 22               None  8952056961092092653
# 23               None  8952056961092092653
# 24               None  8952056961092092653
# 25               Film  8952056961092092653
# 26               None  8952056961092092653
# 27               None  8952056961092092653
# 28               None  8952056961092092653
# 29               None  8952056961092092653
# ...               ...                  ...
# 1487634          None -8634347307086293270
# 1487635          None  6526299568519682593
# 1487636          None -1558588825235581077
# 1487637          None   937850690077902243
# 1487638          None -8481986653954043425
# 1487639          None  3488271282962549764
# 1487640          None -1378870023040376397
# 1487641          None   952524110806626511
# 1487642          None -1095614526939030304
# 1487643          None  5327693088788792036
# 1487644          None -2996930536963429111
# 1487645          None -7479203926197086043
# 1487646          None  1037377827871571997
# 1487647          None -2904413705787908079
# 1487648          None   107052717691146915
# 1487649          None -4213651237560569711
# 1487650          None   123740418911869579
# 1487651          None -7089720860594299274
# 1487652          None  4497515924437025816
# 1487653          None -4301140832683696261
# 1487654          None -8680149934560995660
# 1487655          None   367712986359490897
# 1487656          None  7768484994666731783
# 1487657          None  -384496654864442133
# 1487658          None  1777092912164859284
# 1487659          None -3967889763639852990
# 1487660          None -2879351910942464333
# 1487661          None   456869017385410680
# 1487662          None -6262223792270522246
# 1487663          None -3298530758791153454
#
#                                              link    norm
# 0                                       Pseudonym    None
# 1                                       Regisseur    None
# 2                      Directors Guild of America    None
# 3                         Internet Movie Database    None
# 4        Frank Patch – Deine Stunden sind gezählt    None
# 5                                   Robert Totten    None
# 6                                 Richard Widmark    None
# 7                                      Don Siegel    None
# 8                                     Handschrift  Manier
# 9                                        Anagramm    None
# 10                                    Roger Ebert    None
# 11                       Fahr zur Hölle Hollywood    None
# 12                                  Arthur Hiller    None
# 13                               Goldene Himbeere    None
# 14                                      Supernova    None
# 15                                    Walter Hill    None
# 16                                      Tony Kaye    None
# 17                             American History X    None
# 18                                      Pilotfilm    None
# 19                                   Schulmädchen    None
# 20                                 Stephan Wagner    None
# 21                                     Don Siegel    None
# 22                                  Robert Totten    None
# 23       Frank Patch – Deine Stunden sind gezählt    None
# 24                                    David Lynch    None
# 25                               Der Wüstenplanet    None
# 26                              Chris Christensen    None
# 27                               Gianni Bozzacchi    None
# 28                               Stuart Rosenberg    None
# 29                            Richard C. Sarafian    None
# ...                                           ...     ...
# 1487634                    Karl-Georg Emil Heubel    None
# 1487635                    Karl-Georg Emil Heubel    None
# 1487636                        ASF Bobo-Dioulasso    None
# 1487637                    Karl-Georg Emil Heubel    None
# 1487638                Bobo Sports Bobo-Dioulasso    None
# 1487639                Racing Club Bobo-Dioulasso    None
# 1487640                Bobo Sports Bobo-Dioulasso    None
# 1487641                            US Ouagadougou    None
# 1487642                Étoile Filante Ouagadougou    None
# 1487643                          USFA Ouagadougou    None
# 1487644                    AS-SONABEL Ouagadougou    None
# 1487645                                  Domașnea    None
# 1487646                        Christof Angermair    None
# 1487647                                Wasserkalb    None
# 1487648       Gewöhnliche Kutscherpeitschennatter    None
# 1487649                         Muellers Erdviper    None
# 1487650                         Rauschuppenpython    None
# 1487651                                    Lennep    None
# 1487652                              Rautenpython    None
# 1487653                              Rautenpython    None
# 1487654               Canon de 240 mm modèle 1884    None
# 1487655        Obusier de 400 mm modèle 1915/1916    None
# 1487656                Obusier de 520 modèle 1916    None
# 1487657                                  Kapkobra    None
# 1487658                      Philippinische Kobra    None
# 1487659                         Rabštejnská Lhota    None
# 1487660                    Iberische Ringelnatter    None
# 1487661                               Vipernatter    None
# 1487662                      Braune Schwimmnatter    None
# 1487663                             Flaschenspiel    None
#
# [60928945 rows x 4 columns]

# %%
def restore_orig_title(row):
    if row.description is None:
        return row.title
    else:
        return f'{row.title} ({row.description})'

meta_orig_title = meta[['title', 'description']].apply(restore_orig_title, axis=1)
meta_orig_title_swap = pd.Series(meta_orig_title.index.values, index=meta_orig_title)

# %%
import spacy
from spacy.tokens import Token
from lemmatizer_plus import LemmatizerPlus

lemmatizer_path='../data/IWNLP.Lemmatizer_20170501.json'
nlp = spacy.load('de', disable=['parser'])
lemmatizer = LemmatizerPlus(lemmatizer_path, nlp)
nlp.add_pipe(lemmatizer)

def lemmatize(title):
    if not ' ' in title:
        return title, title
    else:
        doc = nlp(title)
        text = []
        token = []
        for t in doc:
            text.append(str(t.text))
            if t._.iwnlp_lemmas is not None:
                token.append(t._.iwnlp_lemmas)
            elif t.lemma_ is not None:
                token.append(t.lemma_)
            else:
                token.append(t.text)
        return '_'.join(text), '_'.join(token)

# %%
# building a disambiguation map. Can be used for synonyms
disamb = meta[meta.description == 'Begriffsklärung']
disamb = links.join(disamb, on='hash_nlp', how='inner').drop(['doc_id', 'description', 'length', 'doc_subid'], axis=1)
disamb = disamb.rename(columns={'hash_nlp': 'hash_disamb_page'})
disamb = disamb[['title', 'hash_disamb_page', 'link', 'norm', 'category']]
disamb['hash_link'] = disamb.link.map(lambda x: meta_orig_title_swap[x] if x in meta_orig_title_swap.index else 0)
disamb = disamb.set_index(['title', 'hash_disamb_page'])
tmp = disamb.link.apply(lambda x: pd.Series(split_title(x)))
disamb['title'], disamb['category'] = tmp[0], tmp[1]
disamb = disamb[['title', 'category', 'hash_link']]
disamb = disamb.rename(columns={'title': 'link_to'})
disamb = disamb.reset_index(drop=False)
tmp = disamb.title.apply(lambda x: pd.Series(lemmatize(x)))
disamb['title'], disamb['token'] = tmp[0], tmp[1]
disamb = disamb.set_index(['hash_disamb_page', 'title', 'token'])
disamb['idx'] = disamb.groupby(['hash_disamb_page', 'title', 'token']).cumcount()
disamb = disamb.set_index('idx', append=True)
disamb.to_pickle(join(ETL_PATH, 'dewiki_disambiguation.pickle'))
disamb

# %%
# removes null values from categories
cat = cat[~cat.category.isnull()]
cat = cat.set_index('hash_nlp')
cat.to_pickle(join(ETL_PATH, 'dewiki_categories.pickle'))
load('categories')

# %% [markdown]
# -----

# %%
def collect_redirects(x):
    redir = x[x.subset == 'REDIRECT']
    redir = redir[['doc_id', 'title', 'description', 'tags']]

    def restore_title(tpl):
        if tpl[1] is None:
            return tpl[0]
        else:
            return f'{tpl[0]} ({tpl[1]})'

    redir['directs_to'] = redir.tags.map(restore_title)
    redir['hash_directs_to'] = redir.directs_to.map(lambda x: meta_orig_title_swap[x] if x in meta_orig_title_swap.index else 0)
    redir = redir.drop('tags', axis=1)
    return redir

dep_path = join(ETL_PATH, 'deprecated')
pattern = re.compile(r'dewiki_\d')
files = sorted([f for f in listdir(dep_path) if (isfile(join(dep_path, f)) and pattern.match(f))])
redirects = []
for file in files:
    gc.collect()
    f = join(dep_path, file)
    print('Reading', f)
    df = pd.read_pickle(f)
    df = collect_redirects(df)
    redirects.append(df)
    gc.collect()
redirects = pd.concat(redirects)
rtmp = redirects.title.progress_apply(lambda x: pd.Series(lemmatize(x)))
redirects.title, redirects['token'] = rtmp[0], rtmp[1]
redirects = redirects[['doc_id', 'title', 'token', 'description', 'directs_to', 'hash_directs_to']]
redirects.to_pickle(join(ETL_PATH, 'dewiki_redirects.pickle'))
